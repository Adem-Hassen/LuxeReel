# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
import matplotlib.pyplot as plt
from torch.utils.data import Dataset,DataLoader

# %%
ratings=pd.read_csv("dataset/ratings.csv")
movies=pd.read_csv("dataset/movies.csv")
link=pd.read_csv("dataset/link.csv")

# %%
x=ratings.rating.value_counts().sort_index()
x
# Out:
# rating
# 0.5     1370
# 1.0     2811
# 1.5     1791
# 2.0     7551
# 2.5     5550
# 3.0    20047
# 3.5    13136
# 4.0    26818
# 4.5     8551
# 5.0    13211
# Name: count, dtype: int64

# %%
link
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
movies=pd.merge(movies,link,on="movieId")

# %%
movies
# Out:
#        Unnamed: 0  movieId                               title  \
# 0               0        1                    Toy Story (1995)
# 1               1        2                      Jumanji (1995)
# 2               2        3             Grumpier Old Men (1995)
# 3               3        4            Waiting to Exhale (1995)
# 4               4        5  Father of the Bride Part II (1995)
# ...           ...      ...                                 ...
# 27273       27273   131254        Kein Bund für's Leben (2007)
# 27274       27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275       27275   131258                  The Pirates (2014)
# 27276       27276   131260                 Rentun Ruusu (2001)
# 27277       27277   131262                    Innocence (2014)
#
#                                             genres   imdbId    tmdbId
# 0      Adventure|Animation|Children|Comedy|Fantasy   114709     862.0
# 1                       Adventure|Children|Fantasy   113497    8844.0
# 2                                   Comedy|Romance   113228   15602.0
# 3                             Comedy|Drama|Romance   114885   31357.0
# 4                                           Comedy   113041   11862.0
# ...                                            ...      ...       ...
# 27273                                       Comedy   466713    4436.0
# 27274                                       Comedy   277703    9274.0
# 27275                                    Adventure  3485166  285213.0
# 27276                           (no genres listed)   249110   32099.0
# 27277                     Adventure|Fantasy|Horror  1724965  286971.0
#
# [27278 rows x 6 columns]

# %%
ratings=ratings.drop(columns=["Unnamed: 0"])

# %%
ratings
# Out:
#         userId  movieId  rating
# 0            0        0     4.0
# 1            0        2     4.0
# 2            0        5     4.0
# 3            0       43     5.0
# 4            0       46     5.0
# ...        ...      ...     ...
# 100831     609     9416     4.0
# 100832     609     9443     5.0
# 100833     609     9444     5.0
# 100834     609     9445     5.0
# 100835     609     9485     3.0
#
# [100836 rows x 3 columns]

# %%
class MovieDataSet:
    def __init__(self,users,movies,ratings):
        self.users=users
        self.movies=movies
        self.ratings=ratings
    
    def __len__(self):
        return len(self.users)
    
    def __getitem__(self,item):
        users=self.users[item]
        movies=self.movies[item]
        ratings=self.ratings[item]
        return {"users":torch.tensor(users,dtype=torch.long),
               "movies":torch.tensor(movies,dtype=torch.long),
               "ratings":torch.tensor(ratings,dtype=torch.float)}

# %%
class RecModel(nn.Module):
    def __init__(self,n_users,n_movies):
        super().__init__()
        self.users=nn.Embedding(n_users,128)
        self.movies=nn.Embedding(n_movies,128)
        
        self.out=nn.Linear(256,1)
    def forward(self,users,movies):
        users_embed=self.users(users)
        movies_embed=self.movies(movies)
        output=torch.cat([users_embed,movies_embed],dim=1)
        
        return self.out(output)

# %%
from sklearn import model_selection,preprocessing,metrics

users_label=preprocessing.LabelEncoder()
movies_label=preprocessing.LabelEncoder()

ratings.userId=users_label.fit_transform(ratings.userId.values)
ratings.movieId=movies_label.fit_transform(ratings.movieId.values)

train_data,test_data=model_selection.train_test_split(ratings,test_size=0.2,random_state=42,stratify=ratings.rating.values)

train_dataset=MovieDataSet(users=train_data.userId.values,movies=train_data.movieId.values,ratings=train_data.rating.values)

test_dataset=MovieDataSet(users=test_data.userId.values,movies=test_data.movieId.values,ratings=test_data.rating.values)

# %%
train_loader=DataLoader(dataset=train_dataset,batch_size=4,shuffle=True,num_workers=0)
test_loader=DataLoader(dataset=test_dataset,batch_size=4,shuffle=True,num_workers=0)

# %%
model=RecModel(n_users=len(users_label.classes_),n_movies=len(movies_label.classes_))

optimizer=torch.optim.Adam(model.parameters(),lr=0.001)

loss_func=nn.MSELoss()

# %%
epochs =10
plot_steps = 5000  
all_losses = []

model.train()
for epoch in range(epochs):
    total_loss = 0
    step_count = 0
    
    for i, train_batch in enumerate(train_loader):
        users_ = train_batch["users"]
        movies_ = train_batch["movies"]
        ratings_ = train_batch["ratings"].view(4,-1).to(torch.float)
        
        output = model(users_, movies_)
        
        
        optimizer.zero_grad()
        
     
        loss = loss_func(output, ratings_)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        step_count += len(users_)

        if step_count % plot_steps == 0:
            avg_loss = total_loss / plot_steps
            print(f"Epoch {epoch} - Step {step_count}: Loss = {avg_loss:.4f}")
            all_losses.append(avg_loss)
            total_loss = 0  

print("Training complete ✅")
# Out:
# Epoch 0 - Step 5000: Loss = 1.6530
# Epoch 0 - Step 10000: Loss = 0.5249
# Epoch 0 - Step 15000: Loss = 0.3379
# Epoch 0 - Step 20000: Loss = 0.2858
# Epoch 0 - Step 25000: Loss = 0.2571
# Epoch 0 - Step 30000: Loss = 0.2471
# Epoch 0 - Step 35000: Loss = 0.2341
# Epoch 0 - Step 40000: Loss = 0.2257
# Epoch 0 - Step 45000: Loss = 0.2363
# Epoch 0 - Step 50000: Loss = 0.2231
# Epoch 0 - Step 55000: Loss = 0.2369
# Epoch 0 - Step 60000: Loss = 0.2175
# Epoch 0 - Step 65000: Loss = 0.2251
# Epoch 0 - Step 70000: Loss = 0.2147
# Epoch 0 - Step 75000: Loss = 0.2187
# Epoch 0 - Step 80000: Loss = 0.2195
# Epoch 1 - Step 5000: Loss = 0.2041
# Epoch 1 - Step 10000: Loss = 0.2031
# Epoch 1 - Step 15000: Loss = 0.2055
# Epoch 1 - Step 20000: Loss = 0.1994
# Epoch 1 - Step 25000: Loss = 0.2068
# Epoch 1 - Step 30000: Loss = 0.2053
# Epoch 1 - Step 35000: Loss = 0.2155
# Epoch 1 - Step 40000: Loss = 0.1995
# Epoch 1 - Step 45000: Loss = 0.2067
# Epoch 1 - Step 50000: Loss = 0.1986
# Epoch 1 - Step 55000: Loss = 0.2015
# Epoch 1 - Step 60000: Loss = 0.2008
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 23
#      21 loss = loss_func(output, ratings_)
#      22 loss.backward()
# ---> 23 optimizer.step()
#      25 total_loss += loss.item()
#      26 step_count += len(users_)
#
# File ~\anaconda3\Lib\site-packages\torch\optim\optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     482         else:
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#     490 # call optimizer step post hooks
#
# File ~\anaconda3\Lib\site-packages\torch\optim\optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File ~\anaconda3\Lib\site-packages\torch\optim\adam.py:223, in Adam.step(self, closure)
#     211     beta1, beta2 = group["betas"]
#     213     has_complex = self._init_group(
#     214         group,
#     215         params_with_grad,
#    (...)
#     220         state_steps,
#     221     )
# --> 223     adam(
#     224         params_with_grad,
#     225         grads,
#     226         exp_avgs,
#     227         exp_avg_sqs,
#     228         max_exp_avg_sqs,
#     229         state_steps,
#     230         amsgrad=group["amsgrad"],
#     231         has_complex=has_complex,
#     232         beta1=beta1,
#     233         beta2=beta2,
#     234         lr=group["lr"],
#     235         weight_decay=group["weight_decay"],
#     236         eps=group["eps"],
#     237         maximize=group["maximize"],
#     238         foreach=group["foreach"],
#     239         capturable=group["capturable"],
#     240         differentiable=group["differentiable"],
#     241         fused=group["fused"],
#     242         grad_scale=getattr(self, "grad_scale", None),
#     243         found_inf=getattr(self, "found_inf", None),
#     244     )
#     246 return loss
#
# File ~\anaconda3\Lib\site-packages\torch\optim\optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\optim\adam.py:784, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     781 else:
#     782     func = _single_tensor_adam
# --> 784 func(
#     785     params,
#     786     grads,
#     787     exp_avgs,
#     788     exp_avg_sqs,
#     789     max_exp_avg_sqs,
#     790     state_steps,
#     791     amsgrad=amsgrad,
#     792     has_complex=has_complex,
#     793     beta1=beta1,
#     794     beta2=beta2,
#     795     lr=lr,
#     796     weight_decay=weight_decay,
#     797     eps=eps,
#     798     maximize=maximize,
#     799     capturable=capturable,
#     800     differentiable=differentiable,
#     801     grad_scale=grad_scale,
#     802     found_inf=found_inf,
#     803 )
#
# File ~\anaconda3\Lib\site-packages\torch\optim\adam.py:432, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     429     else:
#     430         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 432     param.addcdiv_(exp_avg, denom, value=-step_size)
#     434 # Lastly, switch back to complex view
#     435 if amsgrad and torch.is_complex(params[i]):
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(all_losses)
plt.show()

# %%
from sklearn.metrics import mean_squared_error

model_outputs=[]
target_outputs=[]

model.eval()

with torch.no_grad():
    for i,test_batch in enumerate(test_loader):
        output=model(test_batch["users"],test_batch["movies"])
        target=test_batch["ratings"]
        
        model_outputs.append(output.sum().item()/(len(test_batch["users"])))
        target_outputs.append(target.sum().item()/(len(test_batch["users"])))
        
        print(f"model output:{output}, target:{target}")
rms=mean_squared_error(target_outputs,model_outputs,squared=False)
print("RMS",rms)
# Out:
# model output:tensor([[3.6171],
#         [4.3453],
#         [3.8235],
#         [3.6598]]), target:tensor([4.0000, 4.5000, 3.0000, 5.0000])
# model output:tensor([[3.2309],
#         [3.6760],
#         [4.1195],
#         [3.8942]]), target:tensor([2.5000, 4.0000, 3.5000, 4.0000])
# model output:tensor([[4.1643],
#         [3.6473],
#         [3.4127],
#         [3.3806]]), target:tensor([4.0000, 4.0000, 3.5000, 3.0000])
# model output:tensor([[4.8349],
#         [3.0560],
#         [3.1177],
#         [1.8762]]), target:tensor([4., 3., 3., 2.])
# model output:tensor([[3.6307],
#         [2.7000],
#         [3.2158],
#         [3.7184]]), target:tensor([4.5000, 3.0000, 3.0000, 4.0000])
# model output:tensor([[3.9040],
#         [3.7737],
#         [3.6783],
#         [3.3204]]), target:tensor([4., 3., 4., 4.])
# model output:tensor([[4.1635],
#         [2.9821],
#         [3.9361],
#         [3.5147]]), target:tensor([4.5000, 2.5000, 4.0000, 3.5000])
# model output:tensor([[4.4088],
#         [3.3865],
#         [2.9341],
#         [3.3864]]), target:tensor([4.5000, 1.0000, 2.0000, 3.0000])
# model output:tensor([[3.5398],
#         [2.4783],
#         [3.3684],
#         [3.8139]]), target:tensor([3.0000, 0.5000, 3.0000, 4.0000])
# model output:tensor([[3.4046],
#         [2.6256],
#         [3.3299],
#         [3.7955]]), target:tensor([2.0000, 5.0000, 4.0000, 4.5000])
# model output:tensor([[4.1963],
#         [3.7179],
#         [2.9207],
#         [3.2249]]), target:tensor([4.0000, 5.0000, 2.5000, 3.0000])
# model output:tensor([[2.9786],
#         [3.9270],
#         [2.7530],
#         [3.4200]]), target:tensor([4., 3., 3., 4.])
# model output:tensor([[3.7268],
#         [2.6985],
#         [3.8597],
#         [3.3726]]), target:tensor([3.5000, 1.0000, 5.0000, 3.5000])
# model output:tensor([[4.0025],
#         [3.3376],
#         [3.3947],
#         [3.4036]]), target:tensor([3.5000, 2.0000, 3.0000, 4.5000])
# model output:tensor([[2.3326],
#         [4.5997],
#         [3.4400],
#         [2.7904]]), target:tensor([4.0000, 4.5000, 4.5000, 4.0000])
# model output:tensor([[3.4526],
#         [3.6831],
#         [3.4679],
#         [3.9965]]), target:tensor([3.0000, 3.5000, 3.5000, 4.0000])
# model output:tensor([[2.5847],
#         [3.7630],
#         [4.1956],
#         [2.4923]]), target:tensor([3., 4., 4., 2.])
# model output:tensor([[4.0872],
#         [2.7374],
#         [3.1721],
#         [1.7923]]), target:tensor([4.0000, 3.0000, 3.0000, 2.5000])
# model output:tensor([[3.4459],
#         [3.8260],
#         [2.9019],
#         [3.2126]]), target:tensor([4., 3., 1., 4.])
# model output:tensor([[4.0898],
#         [3.3298],
#         [4.0328],
#         [3.4491]]), target:tensor([3.5000, 1.0000, 4.0000, 4.0000])
# model output:tensor([[3.5152],
#         [3.8913],
#         [5.2045],
#         [3.8251]]), target:tensor([3., 5., 4., 4.])
# model output:tensor([[3.5510],
#         [3.2901],
#         [4.0792],
#         [3.8379]]), target:tensor([3.5000, 3.0000, 3.0000, 4.0000])
# model output:tensor([[3.7538],
#         [3.2742],
#         [2.8531],
#         [2.2042]]), target:tensor([4.0000, 4.0000, 0.5000, 2.0000])
# model output:tensor([[3.5351],
#         [3.4115],
#         [3.5872],
#         [4.7044]]), target:tensor([5., 3., 5., 5.])
# model output:tensor([[2.5521],
#         [3.0759],
#         [3.2740],
#         [3.2686]]), target:tensor([3.5000, 3.0000, 4.0000, 4.0000])
# model output:tensor([[3.2544],
#         [4.0612],
#         [2.8352],
#         [4.2840]]), target:tensor([5., 5., 1., 4.])
# model output:tensor([[3.4149],
#         [3.7854],
#         [2.8583],
#         [3.6197]]), target:tensor([4.0000, 4.5000, 3.0000, 4.5000])
# model output:tensor([[3.9555],
#         [2.7118],
#         [4.2481],
#         [4.3584]]), target:tensor([4.5000, 3.0000, 4.5000, 4.5000])
# model output:tensor([[3.7791],
#         [3.9162],
#         [4.1879],
#         [3.8378]]), target:tensor([3.5000, 4.0000, 4.0000, 4.0000])
# model output:tensor([[3.5567],
#         [3.7599],
#         [3.2995],
#         [3.5268]]), target:tensor([4.0000, 4.5000, 5.0000, 3.5000])
# model output:tensor([[3.3326],
#         [3.7571],
#         [2.7257],
#         [4.1773]]), target:tensor([4.5000, 3.5000, 4.0000, 4.0000])
# model output:tensor([[3.6877],
#         [3.9965],
#         [3.3489],
#         [3.4925]]), target:tensor([3.5000, 4.0000, 5.0000, 3.0000])
# model output:tensor([[4.2552],
#         [2.8791],
#         [3.3163],
#         [3.0899]]), target:tensor([4.0000, 2.0000, 3.5000, 2.5000])
# model output:tensor([[4.3757],
#         [3.3992],
#         [3.0474],
#         [2.8413]]), target:tensor([4.0000, 5.0000, 4.5000, 3.0000])
# model output:tensor([[3.6697],
#         [3.4119],
#         [3.3864],
#         [3.2584]]), target:tensor([1.0000, 4.5000, 3.5000, 3.0000])
# model output:tensor([[3.3933],
#         [3.0384],
#         [3.5292],
#         [3.4808]]), target:tensor([5.0000, 2.0000, 2.5000, 4.0000])
# model output:tensor([[3.4169],
#         [3.8607],
#         [3.7434],
#         [4.4019]]), target:tensor([3.0000, 3.0000, 4.0000, 4.5000])
# model output:tensor([[3.6053],
#         [2.6352],
#         [3.6659],
#         [3.4891]]), target:tensor([4.0000, 0.5000, 3.0000, 4.0000])
# model output:tensor([[3.0919],
#         [2.1775],
#         [2.6364],
#         [3.8033]]), target:tensor([1.0000, 2.5000, 3.0000, 5.0000])
# model output:tensor([[3.3262],
#         [3.3825],
#         [3.1853],
#         [3.9350]]), target:tensor([4.5000, 3.5000, 4.0000, 4.0000])
# model output:tensor([[3.8882],
#         [2.3842],
#         [1.9893],
#         [3.8884]]), target:tensor([4.0000, 2.0000, 1.5000, 4.5000])
# model output:tensor([[2.4806],
#         [2.6304],
#         [3.6749],
#         [4.1681]]), target:tensor([2., 3., 3., 3.])
# model output:tensor([[3.0953],
#         [2.7917],
#         [4.8622],
#         [3.2837]]), target:tensor([4.5000, 3.0000, 5.0000, 3.0000])
# model output:tensor([[2.1227],
#         [3.7364],
#         [4.2389],
#         [3.4277]]), target:tensor([1., 3., 4., 4.])
# model output:tensor([[3.2251],
#         [3.1287],
#         [2.8991],
#         [2.9819]]), target:tensor([2.5000, 4.5000, 4.0000, 4.5000])
# model output:tensor([[3.0380],
#         [2.7731],
#         [3.0548],
#         [3.3084]]), target:tensor([2., 3., 2., 4.])
# model output:tensor([[3.7388],
#         [3.1925],
#         [3.4801],
#         [4.6135]]), target:tensor([4.0000, 3.5000, 3.5000, 4.5000])
# model output:tensor([[3.2312],
#         [3.3302],
#         [2.9128],
#         [4.2893]]), target:tensor([3.5000, 3.0000, 3.5000, 4.0000])
# model output:tensor([[2.8171],
#         [3.9615],
#         [3.9723],
#         [4.2624]]), target:tensor([3.5000, 2.0000, 4.0000, 5.0000])
# model output:tensor([[2.6729],
#         [3.6603],
#         [3.2800],
#         [3.7645]]), target:tensor([3.0000, 1.0000, 3.5000, 2.0000])
# model output:tensor([[2.9157],
#         [3.4253],
#         [4.5510],
#         [1.7510]]), target:tensor([5., 4., 5., 1.])
# model output:tensor([[3.9219],
#         [4.1005],
#         [3.2032],
#         [4.5720]]), target:tensor([4.5000, 5.0000, 3.0000, 4.5000])
# model output:tensor([[3.6912],
#         [3.2596],
#         [3.4868],
#         [3.6374]]), target:tensor([2., 3., 4., 4.])
# model output:tensor([[2.6541],
#         [2.8337],
#         [4.0666],
#         [2.2927]]), target:tensor([3., 4., 4., 2.])
# model output:tensor([[4.0918],
#         [3.2527],
#         [4.1723],
#         [3.6643]]), target:tensor([5., 3., 5., 4.])
# model output:tensor([[4.2596],
#         [3.5772],
#         [3.8111],
#         [2.6496]]), target:tensor([4., 4., 3., 3.])
# model output:tensor([[2.0942],
#         [3.4575],
#         [4.2615],
#         [4.4990]]), target:tensor([2., 4., 5., 4.])
# model output:tensor([[3.4114],
#         [3.4120],
#         [3.6380],
#         [3.3174]]), target:tensor([2.5000, 3.5000, 0.5000, 2.5000])
# model output:tensor([[2.9995],
#         [4.1081],
#         [4.1131],
#         [3.6441]]), target:tensor([3.0000, 3.5000, 4.0000, 4.5000])
# model output:tensor([[4.1438],
#         [3.8815],
#         [2.5093],
#         [4.5056]]), target:tensor([4., 4., 3., 5.])
# model output:tensor([[3.3342],
#         [3.3038],
#         [2.8604],
#         [4.2435]]), target:tensor([4.0000, 1.5000, 4.0000, 4.0000])
# model output:tensor([[3.1784],
#         [3.3218],
#         [4.4552],
#         [3.5978]]), target:tensor([4., 4., 5., 3.])
# model output:tensor([[2.7198],
#         [4.2467],
#         [4.3590],
#         [3.1263]]), target:tensor([4., 2., 5., 3.])
# model output:tensor([[4.0392],
#         [4.2265],
#         [4.0758],
#         [3.7218]]), target:tensor([4.0000, 4.0000, 4.0000, 3.5000])
# model output:tensor([[3.6435],
#         [4.0358],
#         [3.6676],
#         [4.1185]]), target:tensor([4.0000, 3.5000, 4.0000, 3.0000])
# model output:tensor([[4.5490],
#         [4.4978],
#         [2.9745],
#         [4.9644]]), target:tensor([5.0000, 5.0000, 3.0000, 3.5000])
# model output:tensor([[3.5506],
#         [3.5562],
#         [2.2302],
#         [3.0557]]), target:tensor([2.0000, 3.5000, 1.5000, 4.0000])
# model output:tensor([[4.0353],
#         [2.9371],
#         [3.1830],
#         [3.8323]]), target:tensor([3.0000, 3.0000, 3.5000, 3.5000])
# model output:tensor([[3.9167],
#         [3.1698],
#         [2.9349],
#         [3.9521]]), target:tensor([4.0000, 2.5000, 3.5000, 4.0000])
# model output:tensor([[4.0084],
#         [2.7296],
#         [3.1048],
#         [3.0864]]), target:tensor([3.5000, 3.0000, 2.5000, 4.0000])
# model output:tensor([[3.1891],
#         [4.1327],
#         [3.3953],
#         [2.6683]]), target:tensor([5., 4., 4., 3.])
# model output:tensor([[3.1829],
#         [2.9159],
#         [3.8094],
#         [3.4031]]), target:tensor([3.5000, 2.0000, 2.0000, 3.0000])
# model output:tensor([[4.3420],
#         [3.6565],
#         [2.6451],
#         [4.2817]]), target:tensor([3.5000, 2.0000, 2.5000, 4.5000])
# model output:tensor([[3.7785],
#         [4.2179],
#         [3.1389],
#         [3.3545]]), target:tensor([0.5000, 4.5000, 1.5000, 3.0000])
# model output:tensor([[4.3508],
#         [2.4506],
#         [3.7006],
#         [3.6331]]), target:tensor([4.5000, 2.5000, 3.0000, 2.0000])
# model output:tensor([[3.8390],
#         [3.2534],
#         [3.8210],
#         [2.7349]]), target:tensor([4.0000, 2.0000, 4.0000, 3.5000])
# model output:tensor([[2.4131],
#         [3.0330],
#         [3.8991],
#         [4.2467]]), target:tensor([3., 3., 3., 4.])
# model output:tensor([[3.5187],
#         [3.5473],
#         [3.6286],
#         [2.4493]]), target:tensor([3.5000, 3.5000, 4.5000, 2.0000])
# model output:tensor([[3.3524],
#         [2.9139],
#         [3.8126],
#         [4.3513]]), target:tensor([4.0000, 1.5000, 5.0000, 3.5000])
# model output:tensor([[3.7126],
#         [2.9589],
#         [3.4844],
#         [4.6915]]), target:tensor([3.5000, 3.5000, 1.5000, 4.0000])
# model output:tensor([[1.9503],
#         [4.1073],
#         [2.3432],
#         [3.6501]]), target:tensor([2.0000, 4.0000, 2.5000, 3.0000])
# model output:tensor([[3.1965],
#         [3.3599],
#         [3.6184],
#         [3.9105]]), target:tensor([3., 1., 4., 4.])
# model output:tensor([[3.2281],
#         [3.3304],
#         [3.2678],
#         [2.9097]]), target:tensor([4., 4., 3., 4.])
# model output:tensor([[2.7188],
#         [3.8810],
#         [3.4760],
#         [3.7571]]), target:tensor([2.0000, 4.0000, 4.0000, 3.5000])
# model output:tensor([[3.4391],
#         [2.8870],
#         [3.6184],
#         [4.8184]]), target:tensor([4.5000, 2.0000, 3.5000, 4.0000])
# model output:tensor([[3.4159],
#         [3.5266],
#         [4.0835],
#         [3.5770]]), target:tensor([3.5000, 3.0000, 3.5000, 1.0000])
# model output:tensor([[3.4189],
#         [3.5761],
#         [3.0691],
#         [4.1390]]), target:tensor([3.0000, 2.5000, 4.0000, 4.0000])
# model output:tensor([[4.0649],
#         [3.4786],
#         [2.6940],
#         [3.3985]]), target:tensor([5.0000, 4.0000, 0.5000, 4.0000])
# model output:tensor([[4.1214],
#         [3.6643],
#         [3.4410],
#         [2.9901]]), target:tensor([3., 4., 4., 3.])
# model output:tensor([[4.2888],
#         [3.0600],
#         [2.6107],
#         [3.1888]]), target:tensor([5., 4., 3., 3.])
# model output:tensor([[4.0596],
#         [1.4809],
#         [4.1241],
#         [4.1220]]), target:tensor([4.5000, 0.5000, 5.0000, 3.0000])
# model output:tensor([[4.0119],
#         [3.4818],
#         [4.0563],
#         [3.6355]]), target:tensor([3., 4., 4., 4.])
# model output:tensor([[4.3415],
#         [3.5321],
#         [3.1826],
#         [4.0086]]), target:tensor([5.0000, 3.0000, 3.5000, 4.0000])
# model output:tensor([[2.9860],
#         [4.3504],
#         [3.1584],
#         [3.7500]]), target:tensor([3.5000, 3.0000, 3.0000, 3.5000])
# model output:tensor([[3.6879],
#         [3.7723],
#         [4.2870],
#         [3.1614]]), target:tensor([4.0000, 4.0000, 3.5000, 2.5000])
# model output:tensor([[4.4511],
#         [4.0916],
#         [2.6798],
#         [3.5244]]), target:tensor([5., 4., 3., 3.])
# model output:tensor([[4.1557],
#         [4.1777],
#         [3.0492],
#         [3.5857]]), target:tensor([3.5000, 5.0000, 3.0000, 3.5000])
# model output:tensor([[4.0695],
#         [4.9365],
#         [3.4171],
#         [3.5962]]), target:tensor([4.5000, 4.0000, 4.0000, 4.0000])
# model output:tensor([[3.3267],
#         [2.2284],
#         [3.4455],
#         [2.8769]]), target:tensor([3.0000, 4.5000, 3.0000, 2.0000])
# model output:tensor([[3.5407],
#         [3.6071],
#         [3.1397],
#         [2.7258]]), target:tensor([4., 3., 2., 3.])
# model output:tensor([[3.8089],
#         [3.3150],
#         [2.8648],
#         [4.3136]]), target:tensor([3.0000, 4.0000, 3.5000, 4.0000])
# model output:tensor([[4.0036],
#         [4.2657],
#         [3.7835],
#         [3.6984]]), target:tensor([2., 4., 4., 4.])
# model output:tensor([[2.8924],
#         [3.2112],
#         [3.5864],
#         [3.5157]]), target:tensor([3.0000, 4.0000, 4.5000, 2.5000])
# model output:tensor([[3.3401],
#         [3.3456],
#         [3.6912],
#         [3.9718]]), target:tensor([4.5000, 4.5000, 4.0000, 4.0000])
# model output:tensor([[3.1746],
#         [4.2140],
#         [3.5823],
#         [4.1878]]), target:tensor([4.0000, 4.5000, 4.0000, 5.0000])
# model output:tensor([[4.9060],
#         [4.2018],
#         [3.8983],
#         [2.4311]]), target:tensor([5.0000, 4.0000, 3.5000, 1.0000])
# model output:tensor([[4.0430],
#         [2.9840],
#         [2.8415],
#         [4.0789]]), target:tensor([1.0000, 3.0000, 3.5000, 3.5000])
# model output:tensor([[4.2918],
#         [3.9609],
#         [3.3499],
#         [3.8106]]), target:tensor([4., 4., 3., 5.])
# model output:tensor([[3.8687],
#         [2.4845],
#         [3.9563],
#         [3.1616]]), target:tensor([4.0000, 2.0000, 5.0000, 3.5000])
# model output:tensor([[3.4110],
#         [3.2315],
#         [2.0421],
#         [3.4308]]), target:tensor([3.0000, 3.5000, 2.0000, 4.5000])
# model output:tensor([[2.9326],
#         [1.9388],
#         [2.9095],
#         [3.1118]]), target:tensor([3.0000, 2.0000, 3.5000, 3.5000])
# model output:tensor([[3.0421],
#         [1.7090],
#         [3.5481],
#         [3.4844]]), target:tensor([3.0000, 3.0000, 4.5000, 3.0000])
# model output:tensor([[3.1119],
#         [3.3745],
#         [3.9704],
#         [3.5457]]), target:tensor([4.0000, 4.0000, 3.5000, 4.0000])
# model output:tensor([[2.9268],
#         [4.3487],
#         [3.2668],
#         [3.1797]]), target:tensor([2.0000, 4.5000, 2.0000, 4.0000])
# model output:tensor([[3.0764],
#         [3.9069],
#         [3.5105],
#         [3.2862]]), target:tensor([4.0000, 2.0000, 3.5000, 3.0000])
# model output:tensor([[3.9779],
#         [4.4351],
#         [3.7518],
#         [3.5293]]), target:tensor([3.5000, 4.5000, 3.5000, 3.5000])
# model output:tensor([[3.2807],
#         [3.9838],
#         [4.1446],
#         [3.1527]]), target:tensor([3.0000, 3.5000, 4.0000, 3.0000])
# model output:tensor([[2.8533],
#         [3.6023],
#         [4.0343],
#         [3.1863]]), target:tensor([3., 3., 5., 4.])
# model output:tensor([[3.3405],
#         [3.2220],
#         [2.9463],
#         [4.4019]]), target:tensor([4.0000, 2.5000, 3.0000, 4.5000])
# model output:tensor([[3.3973],
#         [2.5884],
#         [3.5479],
#         [3.5975]]), target:tensor([4., 3., 4., 4.])
# model output:tensor([[2.6342],
#         [3.7078],
#         [3.3534],
#         [3.8133]]), target:tensor([3., 4., 3., 4.])
# model output:tensor([[2.8397],
#         [4.2863],
#         [4.1913],
#         [2.4660]]), target:tensor([2.5000, 4.5000, 4.0000, 4.0000])
# model output:tensor([[3.9489],
#         [3.3674],
#         [3.1846],
#         [4.0458]]), target:tensor([4., 4., 2., 4.])
# model output:tensor([[3.1918],
#         [3.6012],
#         [3.2419],
#         [3.4263]]), target:tensor([3.5000, 4.0000, 2.0000, 4.0000])
# model output:tensor([[4.4347],
#         [3.2818],
#         [3.6660],
#         [3.0321]]), target:tensor([4.0000, 4.0000, 2.0000, 2.5000])
# model output:tensor([[3.8194],
#         [3.3185],
#         [4.0123],
#         [4.0772]]), target:tensor([3.5000, 3.5000, 4.0000, 5.0000])
# model output:tensor([[3.4838],
#         [4.0259],
#         [1.8151],
#         [3.6952]]), target:tensor([2.5000, 4.0000, 2.5000, 3.0000])
# model output:tensor([[3.7808],
#         [3.0501],
#         [4.0541],
#         [4.0607]]), target:tensor([3.5000, 3.5000, 3.0000, 4.5000])
# model output:tensor([[2.2985],
#         [2.8118],
#         [3.9615],
#         [3.4955]]), target:tensor([3.0000, 4.0000, 3.0000, 3.5000])
# model output:tensor([[2.3836],
#         [3.5018],
#         [3.3742],
#         [2.9909]]), target:tensor([2.0000, 2.0000, 3.0000, 2.5000])
# model output:tensor([[2.8200],
#         [1.9017],
#         [3.4650],
#         [4.0596]]), target:tensor([4.0000, 2.0000, 3.5000, 5.0000])
# model output:tensor([[4.0071],
#         [3.4329],
#         [4.7931],
#         [2.5403]]), target:tensor([4.5000, 4.5000, 5.0000, 3.5000])
# model output:tensor([[3.9400],
#         [3.6583],
#         [2.8884],
#         [2.9154]]), target:tensor([4.0000, 4.0000, 1.0000, 1.5000])
# model output:tensor([[3.2533],
#         [3.6748],
#         [2.9522],
#         [2.8064]]), target:tensor([4., 4., 4., 3.])
# model output:tensor([[3.7575],
#         [3.3247],
#         [3.3650],
#         [3.5713]]), target:tensor([4.5000, 3.0000, 2.5000, 3.5000])
# model output:tensor([[3.5909],
#         [4.8584],
#         [4.1496],
#         [2.9040]]), target:tensor([4.5000, 5.0000, 5.0000, 2.5000])
# model output:tensor([[3.0843],
#         [3.6334],
#         [3.8168],
#         [3.0477]]), target:tensor([3., 4., 4., 1.])
# model output:tensor([[3.6945],
#         [3.1580],
#         [3.5218],
#         [3.1512]]), target:tensor([4., 3., 4., 4.])
# model output:tensor([[3.8408],
#         [3.6336],
#         [3.0065],
#         [4.2350]]), target:tensor([4., 4., 4., 5.])
# model output:tensor([[4.1029],
#         [2.4275],
#         [3.6834],
#         [2.1803]]), target:tensor([4.5000, 2.0000, 3.5000, 1.0000])
# model output:tensor([[3.1231],
#         [4.0690],
#         [3.7269],
#         [4.0469]]), target:tensor([3.5000, 3.5000, 4.5000, 3.0000])
# model output:tensor([[2.8958],
#         [3.3381],
#         [4.0456],
#         [2.9019]]), target:tensor([4., 2., 5., 3.])
# model output:tensor([[3.5427],
#         [3.0713],
#         [3.7011],
#         [3.6746]]), target:tensor([4.0000, 3.0000, 3.5000, 2.0000])
# model output:tensor([[2.3554],
#         [3.0556],
#         [2.5249],
#         [2.7216]]), target:tensor([2.0000, 3.5000, 3.5000, 2.0000])
# model output:tensor([[2.2486],
#         [4.4190],
#         [3.8045],
#         [4.4458]]), target:tensor([2., 5., 4., 4.])
# model output:tensor([[3.1445],
#         [3.6310],
#         [4.4587],
#         [3.7543]]), target:tensor([2.5000, 3.0000, 3.0000, 2.0000])
# model output:tensor([[3.0195],
#         [4.0776],
#         [3.8429],
#         [3.1646]]), target:tensor([2.0000, 2.5000, 5.0000, 3.5000])
# model output:tensor([[2.9140],
#         [3.4333],
#         [3.1746],
#         [2.7131]]), target:tensor([4., 5., 4., 3.])
# model output:tensor([[2.4535],
#         [3.0475],
#         [3.2268],
#         [3.7335]]), target:tensor([3.0000, 1.5000, 3.5000, 4.0000])
# model output:tensor([[3.7093],
#         [2.8101],
#         [3.8750],
#         [3.0156]]), target:tensor([3., 3., 5., 3.])
# model output:tensor([[3.3629],
#         [3.4860],
#         [3.0814],
#         [3.6509]]), target:tensor([3.0000, 4.5000, 2.5000, 4.0000])
# model output:tensor([[2.5686],
#         [3.2760],
#         [2.5949],
#         [2.7604]]), target:tensor([3.5000, 3.0000, 2.5000, 3.0000])
# model output:tensor([[4.8604],
#         [4.1627],
#         [2.9724],
#         [3.0503]]), target:tensor([5.0000, 3.5000, 2.5000, 2.0000])
# model output:tensor([[4.0111],
#         [3.6243],
#         [2.2449],
#         [3.1056]]), target:tensor([3.0000, 3.5000, 1.5000, 2.0000])
# model output:tensor([[2.2322],
#         [3.4034],
#         [2.0828],
#         [3.8069]]), target:tensor([2.0000, 3.5000, 3.0000, 4.0000])
# model output:tensor([[3.9095],
#         [3.7160],
#         [3.1042],
#         [3.5474]]), target:tensor([2.5000, 5.0000, 3.0000, 4.5000])
# model output:tensor([[2.5120],
#         [4.0665],
#         [3.4807],
#         [2.8491]]), target:tensor([0.5000, 4.0000, 4.0000, 3.0000])
# model output:tensor([[2.5709],
#         [3.2053],
#         [3.1743],
#         [3.0233]]), target:tensor([2.0000, 5.0000, 2.5000, 4.0000])
# model output:tensor([[4.4714],
#         [1.6661],
#         [3.6938],
#         [2.9281]]), target:tensor([4.0000, 2.0000, 4.0000, 4.5000])
# model output:tensor([[3.0413],
#         [3.1519],
#         [3.0848],
#         [4.0730]]), target:tensor([3.0000, 3.5000, 3.5000, 5.0000])
# model output:tensor([[3.7468],
#         [2.0205],
#         [3.8890],
#         [2.8719]]), target:tensor([3.0000, 2.0000, 3.5000, 4.0000])
# model output:tensor([[2.2367],
#         [2.9685],
#         [2.8897],
#         [2.4300]]), target:tensor([2.5000, 3.0000, 3.5000, 3.0000])
# model output:tensor([[2.5321],
#         [4.0968],
#         [3.8118],
#         [3.2354]]), target:tensor([1.0000, 4.5000, 5.0000, 2.0000])
# model output:tensor([[2.1981],
#         [3.4771],
#         [3.2848],
#         [4.0513]]), target:tensor([3.0000, 4.0000, 3.5000, 4.0000])
# model output:tensor([[2.7480],
#         [3.5237],
#         [3.5034],
#         [3.4732]]), target:tensor([5., 4., 2., 4.])
# model output:tensor([[4.5209],
#         [3.4308],
#         [3.8445],
#         [2.2208]]), target:tensor([5., 2., 5., 2.])
# model output:tensor([[3.7380],
#         [4.0680],
#         [2.5152],
#         [3.4503]]), target:tensor([3.0000, 4.0000, 4.0000, 2.5000])
# model output:tensor([[4.0764],
#         [3.9513],
#         [2.7995],
#         [4.3935]]), target:tensor([4.5000, 4.0000, 3.5000, 5.0000])
# model output:tensor([[3.6621],
#         [4.2289],
#         [3.8770],
#         [2.9429]]), target:tensor([5.0000, 4.0000, 2.5000, 3.5000])
# model output:tensor([[3.5260],
#         [3.3313],
#         [4.1299],
#         [4.2353]]), target:tensor([3.5000, 4.0000, 5.0000, 3.5000])
# model output:tensor([[3.4574],
#         [2.3860],
#         [1.7127],
#         [4.5260]]), target:tensor([3.5000, 3.0000, 2.5000, 4.5000])
# model output:tensor([[3.0128],
#         [4.3578],
#         [4.7259],
#         [3.9503]]), target:tensor([2., 5., 3., 4.])
# model output:tensor([[4.6055],
#         [3.5132],
#         [3.8554],
#         [4.3555]]), target:tensor([4.0000, 3.0000, 4.5000, 4.0000])
# model output:tensor([[3.4631],
#         [3.5877],
#         [3.6339],
#         [3.4524]]), target:tensor([3., 3., 4., 4.])
# model output:tensor([[3.9902],
#         [2.6959],
#         [2.4798],
#         [2.7503]]), target:tensor([2.5000, 3.0000, 2.0000, 3.0000])
# model output:tensor([[3.0389],
#         [2.9150],
#         [3.1875],
#         [3.4837]]), target:tensor([3.0000, 2.5000, 3.0000, 4.5000])
# model output:tensor([[3.6658],
#         [2.1616],
#         [2.7634],
#         [3.2069]]), target:tensor([0.5000, 3.5000, 3.5000, 3.0000])
# model output:tensor([[3.8923],
#         [3.2461],
#         [3.1255],
#         [3.8779]]), target:tensor([4.0000, 3.5000, 4.0000, 4.5000])
# model output:tensor([[3.2749],
#         [4.6106],
#         [3.4303],
#         [4.0612]]), target:tensor([3.5000, 5.0000, 4.0000, 4.0000])
# model output:tensor([[3.6857],
#         [3.8312],
#         [2.9074],
#         [2.6095]]), target:tensor([4.5000, 3.0000, 3.0000, 2.0000])
# model output:tensor([[2.8627],
#         [2.8864],
#         [4.4391],
#         [3.1991]]), target:tensor([4.0000, 2.5000, 4.0000, 2.5000])
# model output:tensor([[2.6811],
#         [3.2461],
#         [3.1976],
#         [3.6202]]), target:tensor([3.5000, 2.5000, 3.5000, 2.5000])
# model output:tensor([[3.4091],
#         [4.4048],
#         [3.7642],
#         [4.1047]]), target:tensor([4.5000, 5.0000, 5.0000, 5.0000])
# model output:tensor([[2.3476],
#         [3.8921],
#         [3.9070],
#         [3.6083]]), target:tensor([2., 5., 5., 4.])
# model output:tensor([[2.9960],
#         [2.8544],
#         [3.9246],
#         [4.4272]]), target:tensor([4.0000, 2.5000, 4.0000, 5.0000])
# model output:tensor([[3.9187],
#         [4.4657],
#         [2.5629],
#         [3.3036]]), target:tensor([3.0000, 3.5000, 3.0000, 3.5000])
# model output:tensor([[4.0761],
#         [3.1108],
#         [3.5925],
#         [3.2294]]), target:tensor([4., 3., 5., 4.])
# model output:tensor([[3.6846],
#         [3.6136],
#         [4.2585],
#         [2.1710]]), target:tensor([4.5000, 4.0000, 4.0000, 1.0000])
# model output:tensor([[3.2360],
#         [2.8011],
#         [3.2043],
#         [3.5240]]), target:tensor([3.0000, 3.0000, 3.5000, 4.0000])
# model output:tensor([[3.8963],
#         [3.6512],
#         [3.6542],
#         [3.5021]]), target:tensor([3.0000, 4.0000, 4.5000, 3.5000])
# model output:tensor([[3.0602],
#         [2.7543],
#         [3.9243],
#         [2.8102]]), target:tensor([2.0000, 2.0000, 4.5000, 2.5000])
# model output:tensor([[3.5257],
#         [3.4095],
#         [4.6038],
#         [3.9190]]), target:tensor([3.5000, 5.0000, 4.5000, 5.0000])
# model output:tensor([[4.2189],
#         [3.4830],
#         [2.9811],
#         [3.9858]]), target:tensor([5.0000, 4.0000, 2.5000, 4.0000])
# model output:tensor([[3.7031],
#         [2.4638],
#         [3.1539],
#         [3.7083]]), target:tensor([3.5000, 3.5000, 3.0000, 2.5000])
# model output:tensor([[3.4169],
#         [3.3658],
#         [4.3893],
#         [3.3778]]), target:tensor([2.5000, 3.5000, 4.5000, 3.0000])
# model output:tensor([[3.5690],
#         [3.6207],
#         [3.8140],
#         [3.5303]]), target:tensor([3.5000, 5.0000, 4.0000, 3.5000])
# model output:tensor([[2.7526],
#         [2.8240],
#         [3.9763],
#         [2.3975]]), target:tensor([4., 4., 5., 2.])
# model output:tensor([[3.3094],
#         [3.1764],
#         [3.1911],
#         [4.3753]]), target:tensor([3.5000, 1.0000, 2.0000, 3.5000])
# model output:tensor([[3.9549],
#         [3.0942],
#         [2.1680],
#         [4.2344]]), target:tensor([4., 3., 4., 4.])
# model output:tensor([[2.2970],
#         [2.8721],
#         [4.0851],
#         [3.2493]]), target:tensor([3.0000, 3.5000, 4.0000, 3.0000])
# model output:tensor([[3.6529],
#         [2.0790],
#         [2.3456],
#         [2.8240]]), target:tensor([4.0000, 0.5000, 1.0000, 2.5000])
# model output:tensor([[3.2755],
#         [4.1010],
#         [3.7906],
#         [3.1580]]), target:tensor([3.0000, 5.0000, 3.5000, 3.0000])
# model output:tensor([[3.0645],
#         [3.7957],
#         [3.2449],
#         [2.1656]]), target:tensor([2.5000, 5.0000, 3.0000, 3.0000])
# model output:tensor([[3.7605],
#         [3.8400],
#         [3.5812],
#         [4.3052]]), target:tensor([5.0000, 3.0000, 4.0000, 4.5000])
# model output:tensor([[3.9270],
#         [3.2028],
#         [3.4255],
#         [3.5179]]), target:tensor([5.0000, 3.5000, 4.0000, 2.0000])
# model output:tensor([[3.9901],
#         [3.4287],
#         [4.0111],
#         [4.3534]]), target:tensor([2.0000, 5.0000, 3.5000, 5.0000])
# model output:tensor([[3.4508],
#         [4.3072],
#         [3.0614],
#         [2.9131]]), target:tensor([3.5000, 4.0000, 2.5000, 3.0000])
# model output:tensor([[5.0619],
#         [4.6956],
#         [3.4933],
#         [3.7972]]), target:tensor([5.0000, 5.0000, 3.5000, 4.5000])
# model output:tensor([[1.9420],
#         [4.1158],
#         [3.6814],
#         [2.9028]]), target:tensor([2.5000, 4.0000, 3.5000, 2.5000])
# model output:tensor([[2.9630],
#         [3.9268],
#         [3.5092],
#         [3.6999]]), target:tensor([4., 4., 3., 3.])
# model output:tensor([[3.5714],
#         [3.4001],
#         [3.6650],
#         [3.9970]]), target:tensor([5., 4., 5., 2.])
# model output:tensor([[3.8214],
#         [2.9350],
#         [3.6936],
#         [3.0619]]), target:tensor([4., 4., 2., 2.])
# model output:tensor([[3.5135],
#         [3.7071],
#         [3.4598],
#         [3.2154]]), target:tensor([3.0000, 3.5000, 3.0000, 4.0000])
# model output:tensor([[4.1370],
#         [3.5790],
#         [2.8346],
#         [3.2115]]), target:tensor([4.0000, 3.5000, 2.5000, 2.0000])
# model output:tensor([[2.2545],
#         [3.5836],
#         [3.3057],
#         [3.0192]]), target:tensor([2., 5., 3., 3.])
# model output:tensor([[2.2614],
#         [3.4230],
#         [3.4698],
#         [2.7730]]), target:tensor([3.5000, 5.0000, 3.0000, 3.5000])
# model output:tensor([[3.8456],
#         [3.3038],
#         [2.6787],
#         [3.7980]]), target:tensor([2.5000, 2.0000, 3.0000, 4.0000])
# model output:tensor([[3.7735],
#         [4.0092],
#         [3.4319],
#         [3.1581]]), target:tensor([5.0000, 4.0000, 5.0000, 2.5000])
# model output:tensor([[3.9963],
#         [3.4672],
#         [4.1529],
#         [2.9178]]), target:tensor([5.0000, 4.0000, 4.5000, 2.0000])
# model output:tensor([[3.5925],
#         [2.5713],
#         [3.9095],
#         [3.0727]]), target:tensor([4.0000, 4.0000, 4.0000, 2.5000])
# model output:tensor([[3.4240],
#         [4.5535],
#         [3.9155],
#         [4.1131]]), target:tensor([5.0000, 5.0000, 4.0000, 4.5000])
# model output:tensor([[3.2234],
#         [3.9398],
#         [4.0951],
#         [2.7086]]), target:tensor([4., 5., 4., 3.])
# model output:tensor([[3.0486],
#         [3.6529],
#         [3.3226],
#         [3.8833]]), target:tensor([3.5000, 4.5000, 4.0000, 4.0000])
# model output:tensor([[3.1488],
#         [3.5737],
#         [2.8718],
#         [3.7061]]), target:tensor([2.0000, 2.5000, 5.0000, 4.0000])
# model output:tensor([[4.0786],
#         [2.3942],
#         [3.7805],
#         [3.0831]]), target:tensor([5.0000, 4.0000, 4.5000, 4.0000])
# model output:tensor([[2.7551],
#         [3.3862],
#         [3.1045],
#         [3.8592]]), target:tensor([3.0000, 3.5000, 3.0000, 4.5000])
# model output:tensor([[3.8339],
#         [3.1524],
#         [4.2948],
#         [4.1390]]), target:tensor([5.0000, 3.5000, 4.5000, 3.5000])
# model output:tensor([[3.4135],
#         [3.3427],
#         [3.6446],
#         [4.1578]]), target:tensor([3., 4., 4., 4.])
# model output:tensor([[3.2982],
#         [2.8346],
#         [2.5010],
#         [4.1281]]), target:tensor([5., 3., 4., 4.])
# model output:tensor([[3.0185],
#         [2.7393],
#         [4.1026],
#         [4.3181]]), target:tensor([4.0000, 4.5000, 4.0000, 4.0000])
# model output:tensor([[3.5015],
#         [4.5410],
#         [3.7018],
#         [3.2278]]), target:tensor([3.5000, 5.0000, 4.0000, 3.0000])
# model output:tensor([[3.5201],
#         [2.7219],
#         [3.8942],
#         [2.8783]]), target:tensor([3., 1., 3., 3.])
# model output:tensor([[3.3002],
#         [3.4278],
#         [4.3878],
#         [3.0084]]), target:tensor([4.0000, 5.0000, 3.0000, 3.5000])
# model output:tensor([[1.9561],
#         [4.1209],
#         [2.7191],
#         [3.9446]]), target:tensor([3.5000, 5.0000, 0.5000, 3.0000])
# model output:tensor([[2.3400],
#         [3.8348],
#         [3.9349],
#         [4.0299]]), target:tensor([3.0000, 5.0000, 3.5000, 4.0000])
# model output:tensor([[4.4414],
#         [4.0477],
#         [3.2697],
#         [3.1732]]), target:tensor([4.5000, 4.0000, 3.0000, 3.0000])
# model output:tensor([[3.8506],
#         [3.5573],
#         [3.5718],
#         [3.4884]]), target:tensor([4., 5., 3., 2.])
# model output:tensor([[3.6745],
#         [3.1046],
#         [3.4353],
#         [3.3529]]), target:tensor([4.0000, 3.5000, 4.0000, 4.0000])
# model output:tensor([[4.5352],
#         [3.5641],
#         [3.1886],
#         [2.7154]]), target:tensor([5.0000, 4.0000, 2.5000, 3.0000])
# model output:tensor([[2.4227],
#         [4.2011],
#         [3.4722],
#         [1.8768]]), target:tensor([2.0000, 4.0000, 4.5000, 1.0000])
# model output:tensor([[4.0825],
#         [3.5726],
#         [3.2834],
#         [2.7194]]), target:tensor([4.0000, 4.0000, 4.5000, 3.0000])
# model output:tensor([[3.3510],
#         [2.6474],
#         [3.9032],
#         [3.3735]]), target:tensor([2.5000, 1.0000, 3.0000, 3.0000])
# model output:tensor([[3.3441],
#         [3.6474],
#         [2.6383],
#         [3.4620]]), target:tensor([3.5000, 4.0000, 4.5000, 4.0000])
# model output:tensor([[3.0414],
#         [3.4994],
#         [2.2243],
#         [4.1485]]), target:tensor([4.0000, 4.0000, 2.0000, 4.5000])
# model output:tensor([[3.5738],
#         [3.5442],
#         [3.5302],
#         [3.2569]]), target:tensor([3.0000, 4.0000, 4.0000, 1.5000])
# model output:tensor([[4.1261],
#         [2.4603],
#         [4.5786],
#         [3.1967]]), target:tensor([4.5000, 3.0000, 5.0000, 3.0000])
# model output:tensor([[3.7327],
#         [2.8219],
#         [3.5875],
#         [3.9705]]), target:tensor([1.5000, 4.0000, 3.0000, 4.0000])
# model output:tensor([[2.8134],
#         [2.5371],
#         [3.9645],
#         [3.4016]]), target:tensor([4.5000, 2.0000, 4.0000, 3.0000])
# model output:tensor([[4.0667],
#         [4.7431],
#         [3.8273],
#         [4.0135]]), target:tensor([4.5000, 5.0000, 4.5000, 4.0000])
# model output:tensor([[2.4543],
#         [4.0254],
#         [3.6809],
#         [2.8274]]), target:tensor([2., 5., 3., 3.])
# model output:tensor([[3.0760],
#         [3.1074],
#         [2.4946],
#         [2.9537]]), target:tensor([2.0000, 3.5000, 2.0000, 1.0000])
# model output:tensor([[3.7925],
#         [3.3605],
#         [4.3641],
#         [2.9230]]), target:tensor([5.0000, 4.0000, 5.0000, 0.5000])
# model output:tensor([[2.6599],
#         [2.8518],
#         [3.6743],
#         [3.7015]]), target:tensor([3.5000, 3.5000, 4.5000, 5.0000])
# model output:tensor([[3.2186],
#         [3.3376],
#         [3.7055],
#         [2.6288]]), target:tensor([4.5000, 4.0000, 3.5000, 1.5000])
# model output:tensor([[2.7076],
#         [3.7014],
#         [3.1159],
#         [3.8015]]), target:tensor([3.5000, 3.5000, 3.5000, 5.0000])
# model output:tensor([[3.2087],
#         [3.4468],
#         [3.7436],
#         [3.1645]]), target:tensor([3.0000, 3.5000, 4.5000, 2.5000])
# model output:tensor([[3.2990],
#         [3.7422],
#         [3.6535],
#         [2.9488]]), target:tensor([2., 2., 4., 4.])
# model output:tensor([[3.1027],
#         [3.2206],
#         [3.0109],
#         [3.7378]]), target:tensor([2., 3., 2., 1.])
# model output:tensor([[3.8987],
#         [3.2195],
#         [3.0160],
#         [3.5893]]), target:tensor([4.0000, 2.0000, 4.5000, 4.0000])
# model output:tensor([[3.5754],
#         [3.6502],
#         [2.9220],
#         [2.9458]]), target:tensor([4.5000, 3.5000, 4.0000, 3.0000])
# model output:tensor([[2.9292],
#         [3.0570],
#         [4.3424],
#         [4.1286]]), target:tensor([5., 4., 3., 4.])
# model output:tensor([[3.7675],
#         [3.2807],
#         [4.3431],
#         [3.8502]]), target:tensor([5.0000, 1.0000, 3.0000, 4.5000])
# model output:tensor([[3.9225],
#         [4.4841],
#         [3.2391],
#         [2.9911]]), target:tensor([4.5000, 5.0000, 4.0000, 4.0000])
# model output:tensor([[3.2476],
#         [3.5170],
#         [4.5099],
#         [2.8060]]), target:tensor([5.0000, 5.0000, 3.5000, 4.0000])
# model output:tensor([[3.4506],
#         [3.4061],
#         [3.4264],
#         [3.0734]]), target:tensor([3.0000, 4.0000, 4.5000, 3.0000])
# model output:tensor([[3.4131],
#         [3.6880],
#         [3.2944],
#         [3.6465]]), target:tensor([2.5000, 3.0000, 4.0000, 4.0000])
# model output:tensor([[3.3619],
#         [3.4648],
#         [4.3682],
#         [2.6546]]), target:tensor([4.5000, 4.0000, 4.0000, 3.0000])
# model output:tensor([[3.0455],
#         [3.9789],
#         [3.6935],
#         [3.6610]]), target:tensor([2., 4., 4., 3.])
# model output:tensor([[5.0305],
#         [2.3186],
#         [2.9122],
#         [3.5018]]), target:tensor([4.0000, 2.5000, 1.5000, 4.0000])
# model output:tensor([[4.0552],
#         [3.3599],
#         [2.9826],
#         [3.2484]]), target:tensor([4.5000, 3.5000, 3.5000, 3.0000])
# model output:tensor([[3.6668],
#         [3.4920],
#         [3.3476],
#         [3.9484]]), target:tensor([2.0000, 3.5000, 3.5000, 2.5000])
# model output:tensor([[4.2542],
#         [4.0141],
#         [3.9944],
#         [4.6668]]), target:tensor([3.5000, 4.5000, 1.5000, 5.0000])
# model output:tensor([[3.5857],
#         [2.5993],
#         [2.6082],
#         [4.6274]]), target:tensor([3.5000, 2.0000, 2.5000, 5.0000])
# model output:tensor([[3.8744],
#         [3.5352],
#         [3.8233],
#         [4.0399]]), target:tensor([5.0000, 3.0000, 4.5000, 5.0000])
# model output:tensor([[3.1868],
#         [3.3046],
#         [3.9656],
#         [2.5549]]), target:tensor([4.0000, 3.5000, 5.0000, 3.0000])
# model output:tensor([[3.8614],
#         [3.5621],
#         [2.4208],
#         [3.4004]]), target:tensor([5.0000, 1.5000, 3.5000, 2.0000])
# model output:tensor([[3.1098],
#         [4.1333],
#         [3.5241],
#         [3.2495]]), target:tensor([2.5000, 4.0000, 2.0000, 3.5000])
# model output:tensor([[3.9784],
#         [3.9125],
#         [3.5297],
#         [3.8498]]), target:tensor([4., 3., 5., 2.])
# model output:tensor([[3.9456],
#         [3.2966],
#         [3.3968],
#         [3.9915]]), target:tensor([5.0000, 3.5000, 3.0000, 3.0000])
# model output:tensor([[2.4274],
#         [3.4124],
#         [4.1549],
#         [3.3727]]), target:tensor([1.5000, 3.0000, 4.0000, 3.5000])
# model output:tensor([[3.5864],
#         [3.4238],
#         [3.8672],
#         [3.6495]]), target:tensor([4.0000, 3.0000, 3.5000, 3.5000])
# model output:tensor([[4.0026],
#         [4.1997],
#         [2.9361],
#         [3.3212]]), target:tensor([2.5000, 4.0000, 3.0000, 3.0000])
# model output:tensor([[3.9881],
#         [3.3557],
#         [3.5370],
#         [3.5410]]), target:tensor([4.0000, 1.5000, 3.5000, 2.5000])
# model output:tensor([[2.5707],
#         [3.7514],
#         [3.4418],
#         [2.2423]]), target:tensor([3.0000, 4.0000, 3.5000, 3.0000])
# model output:tensor([[4.0659],
#         [3.4203],
#         [2.8200],
#         [3.3340]]), target:tensor([4.0000, 3.0000, 3.0000, 2.5000])
# model output:tensor([[3.2773],
#         [3.5396],
#         [4.2757],
#         [3.8921]]), target:tensor([4.5000, 3.0000, 5.0000, 3.5000])
# model output:tensor([[4.4128],
#         [3.5542],
#         [4.3108],
#         [3.0508]]), target:tensor([4.0000, 4.0000, 4.0000, 3.5000])
# model output:tensor([[4.5235],
#         [3.2219],
#         [2.9325],
#         [4.8076]]), target:tensor([4.0000, 4.0000, 2.5000, 5.0000])
# model output:tensor([[3.1204],
#         [4.4261],
#         [4.0544],
#         [4.2672]]), target:tensor([1.0000, 3.5000, 5.0000, 5.0000])
# model output:tensor([[3.3696],
#         [3.6717],
#         [4.0193],
#         [2.5983]]), target:tensor([4.0000, 4.5000, 4.5000, 2.0000])
# model output:tensor([[4.1829],
#         [3.8267],
#         [2.5376],
#         [3.6771]]), target:tensor([5., 4., 1., 4.])
# model output:tensor([[3.2748],
#         [3.2650],
#         [3.6162],
#         [3.6816]]), target:tensor([5.0000, 2.0000, 3.5000, 4.5000])
# model output:tensor([[4.3657],
#         [3.8548],
#         [3.1238],
#         [3.9510]]), target:tensor([3., 4., 4., 4.])
# model output:tensor([[3.7523],
#         [3.7338],
#         [3.2619],
#         [2.3396]]), target:tensor([0.5000, 3.0000, 3.5000, 3.0000])
# model output:tensor([[2.6893],
#         [2.3048],
#         [3.1868],
#         [4.1706]]), target:tensor([1.5000, 4.0000, 2.0000, 5.0000])
# model output:tensor([[2.5505],
#         [4.0312],
#         [2.5604],
#         [4.2460]]), target:tensor([3., 4., 3., 5.])
# model output:tensor([[4.0076],
#         [2.5728],
#         [3.0329],
#         [4.4974]]), target:tensor([4., 3., 3., 4.])
# model output:tensor([[4.0472],
#         [2.7637],
#         [3.4274],
#         [2.7340]]), target:tensor([5., 2., 4., 3.])
# model output:tensor([[3.6412],
#         [2.5666],
#         [2.8785],
#         [3.6244]]), target:tensor([4.0000, 2.5000, 4.0000, 4.0000])
# model output:tensor([[4.2608],
#         [2.8018],
#         [4.3515],
#         [3.4930]]), target:tensor([0.5000, 2.0000, 5.0000, 3.0000])
# model output:tensor([[3.4735],
#         [2.9265],
#         [3.8357],
#         [3.8582]]), target:tensor([4.0000, 3.5000, 0.5000, 4.0000])
# model output:tensor([[3.3806],
#         [3.7359],
#         [4.2998],
#         [2.3607]]), target:tensor([4., 4., 4., 2.])
# model output:tensor([[3.7529],
#         [2.3177],
#         [2.5954],
#         [2.9566]]), target:tensor([5.0000, 2.5000, 2.0000, 3.5000])
# model output:tensor([[3.3935],
#         [3.4187],
#         [3.4914],
#         [3.2829]]), target:tensor([3.0000, 4.5000, 3.5000, 3.0000])
# model output:tensor([[2.7042],
#         [3.3450],
#         [4.0405],
#         [3.0421]]), target:tensor([3.0000, 5.0000, 5.0000, 1.5000])
# model output:tensor([[3.0574],
#         [3.9415],
#         [3.2623],
#         [3.0110]]), target:tensor([3.5000, 4.5000, 3.5000, 1.0000])
# model output:tensor([[3.6263],
#         [4.2009],
#         [2.3936],
#         [4.2464]]), target:tensor([2.5000, 4.5000, 3.5000, 5.0000])
# model output:tensor([[3.5511],
#         [4.4172],
#         [4.0325],
#         [3.6518]]), target:tensor([3.5000, 4.0000, 5.0000, 2.5000])
# model output:tensor([[3.7400],
#         [3.4719],
#         [3.5243],
#         [4.2600]]), target:tensor([4.5000, 1.0000, 5.0000, 4.5000])
# model output:tensor([[3.3032],
#         [3.1454],
#         [4.3005],
#         [3.6394]]), target:tensor([3., 3., 1., 4.])
# model output:tensor([[3.4694],
#         [4.1019],
#         [2.8209],
#         [3.6942]]), target:tensor([4.0000, 3.0000, 2.5000, 4.0000])
# model output:tensor([[2.9375],
#         [4.4199],
#         [3.3546],
#         [2.7291]]), target:tensor([1.5000, 3.5000, 3.5000, 2.0000])
# model output:tensor([[3.6100],
#         [4.2038],
#         [4.1229],
#         [3.1588]]), target:tensor([3.5000, 4.0000, 5.0000, 4.0000])
# model output:tensor([[3.8400],
#         [4.0109],
#         [1.8937],
#         [4.1175]]), target:tensor([4.0000, 5.0000, 2.5000, 3.5000])
# model output:tensor([[3.4188],
#         [2.4983],
#         [4.2191],
#         [2.6598]]), target:tensor([3.0000, 4.0000, 4.0000, 3.5000])
# model output:tensor([[2.6699],
#         [3.2389],
#         [2.9325],
#         [3.2844]]), target:tensor([4.5000, 3.0000, 4.0000, 2.5000])
# model output:tensor([[3.4210],
#         [1.9743],
#         [2.5280],
#         [3.0441]]), target:tensor([4.0000, 0.5000, 2.5000, 3.0000])
# model output:tensor([[2.6869],
#         [3.9843],
#         [2.0126],
#         [3.2523]]), target:tensor([1., 3., 3., 4.])
# model output:tensor([[2.1600],
#         [2.5851],
#         [3.7434],
#         [3.0823]]), target:tensor([2.5000, 2.0000, 4.0000, 2.0000])
# model output:tensor([[3.9555],
#         [3.0721],
#         [4.2423],
#         [3.3941]]), target:tensor([3., 2., 4., 3.])
# model output:tensor([[3.0238],
#         [2.9701],
#         [3.4436],
#         [3.4139]]), target:tensor([2., 4., 4., 1.])
# model output:tensor([[3.9677],
#         [2.3324],
#         [2.5849],
#         [3.1729]]), target:tensor([2., 2., 3., 3.])
# model output:tensor([[3.2936],
#         [1.7401],
#         [3.7512],
#         [3.8359]]), target:tensor([4.0000, 2.5000, 4.0000, 3.0000])
# model output:tensor([[3.2933],
#         [3.5354],
#         [4.4696],
#         [4.2660]]), target:tensor([2.0000, 4.5000, 1.0000, 5.0000])
# model output:tensor([[3.8465],
#         [3.8504],
#         [3.6791],
#         [3.4400]]), target:tensor([5., 4., 5., 3.])
# model output:tensor([[3.4922],
#         [4.1447],
#         [2.4099],
#         [4.3152]]), target:tensor([4.5000, 4.0000, 3.0000, 5.0000])
# model output:tensor([[3.4169],
#         [3.6042],
#         [3.3041],
#         [4.0863]]), target:tensor([3.5000, 1.0000, 4.0000, 4.0000])
# model output:tensor([[2.7196],
#         [3.7868],
#         [3.3859],
#         [3.8563]]), target:tensor([4., 3., 5., 4.])
# model output:tensor([[3.4058],
#         [2.7622],
#         [3.4513],
#         [3.4285]]), target:tensor([4.5000, 1.0000, 4.0000, 3.0000])
# model output:tensor([[3.6935],
#         [3.6644],
#         [2.0236],
#         [4.5475]]), target:tensor([3., 4., 2., 4.])
# model output:tensor([[4.5208],
#         [2.6731],
#         [4.0724],
#         [2.4407]]), target:tensor([4.0000, 1.0000, 4.0000, 3.5000])
# model output:tensor([[3.4693],
#         [3.4583],
#         [3.8921],
#         [2.9057]]), target:tensor([4.0000, 3.0000, 3.0000, 3.5000])
# model output:tensor([[2.0782],
#         [3.3650],
#         [1.5503],
#         [2.7963]]), target:tensor([2.5000, 3.0000, 1.0000, 3.0000])
# model output:tensor([[3.1993],
#         [3.3158],
#         [3.7049],
#         [4.6739]]), target:tensor([4.0000, 4.5000, 3.5000, 4.0000])
# model output:tensor([[3.9841],
#         [3.1112],
#         [3.3049],
#         [3.4110]]), target:tensor([4.0000, 3.5000, 3.0000, 2.5000])
# model output:tensor([[3.5066],
#         [3.7201],
#         [4.1575],
#         [4.1584]]), target:tensor([4.0000, 4.0000, 3.5000, 3.0000])
# model output:tensor([[3.3621],
#         [3.3406],
#         [3.8590],
#         [2.2309]]), target:tensor([3.5000, 4.0000, 2.5000, 2.5000])
# model output:tensor([[2.9452],
#         [4.1331],
#         [4.4348],
#         [3.8313]]), target:tensor([3.0000, 3.5000, 4.5000, 4.5000])
# model output:tensor([[3.8472],
#         [3.2906],
#         [3.6889],
#         [2.1282]]), target:tensor([5.0000, 2.5000, 3.5000, 2.0000])
# model output:tensor([[3.6112],
#         [1.4407],
#         [3.6723],
#         [3.1455]]), target:tensor([4.5000, 1.0000, 4.0000, 1.0000])
# model output:tensor([[3.3527],
#         [3.0186],
#         [3.5545],
#         [2.9314]]), target:tensor([3.0000, 3.0000, 2.0000, 3.5000])
# model output:tensor([[3.5671],
#         [3.9436],
#         [2.7123],
#         [2.6364]]), target:tensor([3.5000, 4.0000, 1.0000, 3.5000])
# model output:tensor([[3.7669],
#         [2.9832],
#         [4.2339],
#         [3.2564]]), target:tensor([5.0000, 1.5000, 4.0000, 3.0000])
# model output:tensor([[3.3908],
#         [3.0087],
#         [2.8463],
#         [2.5931]]), target:tensor([3.0000, 4.0000, 1.5000, 2.5000])
# model output:tensor([[2.0839],
#         [3.5016],
#         [4.1426],
#         [1.9717]]), target:tensor([2.0000, 3.5000, 4.5000, 1.5000])
# model output:tensor([[2.5503],
#         [3.6635],
#         [3.0049],
#         [4.0230]]), target:tensor([3.0000, 3.0000, 3.5000, 4.5000])
# model output:tensor([[1.4834],
#         [4.7101],
#         [4.0834],
#         [3.8794]]), target:tensor([0.5000, 5.0000, 4.0000, 5.0000])
# model output:tensor([[3.8492],
#         [3.0413],
#         [3.2134],
#         [3.9239]]), target:tensor([4.0000, 0.5000, 4.0000, 3.5000])
# model output:tensor([[3.2098],
#         [3.4861],
#         [3.8832],
#         [3.4472]]), target:tensor([4.5000, 4.5000, 3.0000, 3.5000])
# model output:tensor([[3.0059],
#         [3.0970],
#         [2.5757],
#         [2.8757]]), target:tensor([2., 5., 1., 3.])
# model output:tensor([[3.4511],
#         [4.9677],
#         [3.6042],
#         [3.5139]]), target:tensor([3.5000, 5.0000, 4.5000, 5.0000])
# model output:tensor([[4.5695],
#         [3.6831],
#         [3.1299],
#         [2.4643]]), target:tensor([3.0000, 3.5000, 3.0000, 3.0000])
# model output:tensor([[3.1464],
#         [3.3838],
#         [3.4847],
#         [4.0879]]), target:tensor([4.0000, 5.0000, 0.5000, 5.0000])
# model output:tensor([[3.1513],
#         [3.2117],
#         [2.7906],
#         [1.8907]]), target:tensor([3.0000, 4.5000, 4.0000, 0.5000])
# model output:tensor([[2.9609],
#         [3.4103],
#         [3.5865],
#         [2.2581]]), target:tensor([2.5000, 4.0000, 4.0000, 2.0000])
# model output:tensor([[2.6960],
#         [2.9153],
#         [3.1355],
#         [3.1944]]), target:tensor([3.5000, 2.5000, 2.0000, 4.0000])
# model output:tensor([[3.3490],
#         [4.7621],
#         [3.7532],
#         [2.9770]]), target:tensor([3.0000, 4.0000, 4.0000, 3.5000])
# model output:tensor([[2.8736],
#         [4.1606],
#         [3.2353],
#         [3.4935]]), target:tensor([3.0000, 3.5000, 3.0000, 5.0000])
# model output:tensor([[3.0970],
#         [3.5868],
#         [2.9372],
#         [3.4456]]), target:tensor([4.0000, 3.5000, 1.0000, 2.5000])
# model output:tensor([[3.3426],
#         [3.6963],
#         [3.5558],
#         [3.8311]]), target:tensor([3.5000, 4.0000, 2.0000, 3.5000])
# model output:tensor([[4.1515],
#         [3.1921],
#         [3.5252],
#         [3.1726]]), target:tensor([5.0000, 3.5000, 4.0000, 4.5000])
# model output:tensor([[4.1782],
#         [2.9517],
#         [3.7382],
#         [2.5718]]), target:tensor([5.0000, 3.5000, 3.0000, 2.0000])
# model output:tensor([[2.3843],
#         [3.8446],
#         [3.4154],
#         [2.9050]]), target:tensor([3.0000, 4.5000, 4.0000, 2.0000])
# model output:tensor([[3.0205],
#         [2.7531],
#         [3.5678],
#         [3.0686]]), target:tensor([4.0000, 2.0000, 3.5000, 3.5000])
# model output:tensor([[2.3220],
#         [4.3852],
#         [3.0855],
#         [2.7285]]), target:tensor([2., 5., 4., 4.])
# model output:tensor([[3.6671],
# ...
#         [3.4146],
#         [4.0263],
#         [4.0217]]), target:tensor([3.5000, 5.0000, 4.5000, 3.0000])
# model output:tensor([[3.1495],
#         [4.3812],
#         [2.9211],
#         [3.6543]]), target:tensor([3.0000, 4.5000, 4.5000, 4.0000])
# model output:tensor([[3.8522],
#         [3.9308],
#         [3.5708],
#         [3.3070]]), target:tensor([3.0000, 4.0000, 3.5000, 3.0000])
# model output:tensor([[3.9740],
#         [3.4221],
#         [3.3136],
#         [2.9012]]), target:tensor([4.0000, 4.0000, 4.5000, 1.0000])
# model output:tensor([[4.4151],
#         [4.0811],
#         [4.0821],
#         [4.6617]]), target:tensor([4.5000, 1.0000, 2.0000, 5.0000])
# model output:tensor([[3.3962],
#         [3.3860],
#         [2.8571],
#         [3.2885]]), target:tensor([2.5000, 3.0000, 4.0000, 3.0000])
# model output:tensor([[2.9408],
#         [3.2115],
#         [2.4859],
#         [3.2710]]), target:tensor([1.0000, 3.0000, 1.5000, 3.0000])
# model output:tensor([[3.9416],
#         [4.1387],
#         [3.0537],
#         [3.7488]]), target:tensor([2., 4., 3., 4.])
# model output:tensor([[3.6726],
#         [3.3621],
#         [4.4176],
#         [3.5563]]), target:tensor([4.5000, 2.0000, 3.5000, 3.5000])
# model output:tensor([[2.8631],
#         [3.1865],
#         [3.2398],
#         [3.1557]]), target:tensor([2., 4., 4., 2.])
# model output:tensor([[3.6895],
#         [3.4791],
#         [3.8167],
#         [3.2829]]), target:tensor([3.0000, 3.0000, 3.5000, 3.5000])
# model output:tensor([[3.4208],
#         [4.2215],
#         [3.1713],
#         [4.3291]]), target:tensor([3., 4., 4., 3.])
# model output:tensor([[3.3282],
#         [3.9946],
#         [4.4027],
#         [2.9191]]), target:tensor([3.0000, 3.0000, 4.0000, 2.5000])
# model output:tensor([[2.9391],
#         [3.1808],
#         [2.8733],
#         [3.1160]]), target:tensor([1.5000, 4.0000, 4.0000, 1.5000])
# model output:tensor([[3.8194],
#         [3.3986],
#         [2.5722],
#         [3.9230]]), target:tensor([5.0000, 3.0000, 3.0000, 4.5000])
# model output:tensor([[3.5070],
#         [2.2776],
#         [3.1799],
#         [4.1388]]), target:tensor([2.0000, 2.0000, 1.0000, 2.5000])
# model output:tensor([[3.7018],
#         [3.2479],
#         [3.7056],
#         [3.1457]]), target:tensor([2.5000, 3.5000, 3.0000, 4.5000])
# model output:tensor([[2.8021],
#         [4.5032],
#         [4.5404],
#         [3.6334]]), target:tensor([3.0000, 5.0000, 3.0000, 2.5000])
# model output:tensor([[4.7565],
#         [2.5274],
#         [2.4454],
#         [3.3797]]), target:tensor([4.5000, 2.0000, 2.5000, 4.0000])
# model output:tensor([[4.3476],
#         [4.2121],
#         [3.3061],
#         [4.3608]]), target:tensor([5., 4., 2., 4.])
# model output:tensor([[3.8003],
#         [3.3069],
#         [2.9672],
#         [3.3250]]), target:tensor([1.0000, 3.5000, 4.0000, 4.0000])
# model output:tensor([[2.4903],
#         [2.9684],
#         [3.7594],
#         [3.0694]]), target:tensor([3.0000, 2.0000, 2.5000, 3.0000])
# model output:tensor([[2.8757],
#         [3.1958],
#         [3.5155],
#         [3.2959]]), target:tensor([3.0000, 2.0000, 5.0000, 1.5000])
# model output:tensor([[2.5855],
#         [2.4667],
#         [3.7138],
#         [3.8546]]), target:tensor([3.0000, 0.5000, 5.0000, 3.5000])
# model output:tensor([[3.4655],
#         [3.5665],
#         [3.0223],
#         [4.0948]]), target:tensor([4.5000, 3.0000, 2.0000, 3.0000])
# model output:tensor([[3.6704],
#         [3.3488],
#         [3.1962],
#         [3.7693]]), target:tensor([5.0000, 2.5000, 3.0000, 3.0000])
# model output:tensor([[3.0419],
#         [4.1579],
#         [4.3817],
#         [3.0134]]), target:tensor([4.5000, 4.5000, 4.0000, 2.0000])
# model output:tensor([[3.2831],
#         [3.5950],
#         [2.9373],
#         [4.0605]]), target:tensor([4.5000, 3.0000, 3.0000, 4.5000])
# model output:tensor([[3.3991],
#         [4.1186],
#         [4.1747],
#         [3.0280]]), target:tensor([5.0000, 4.0000, 3.5000, 1.5000])
# model output:tensor([[3.9750],
#         [3.0430],
#         [3.9785],
#         [3.5889]]), target:tensor([5.0000, 3.5000, 4.0000, 4.0000])
# model output:tensor([[4.3473],
#         [3.9825],
#         [2.6298],
#         [2.1808]]), target:tensor([4.0000, 3.5000, 3.0000, 2.5000])
# model output:tensor([[3.2014],
#         [3.5441],
#         [3.0389],
#         [3.7995]]), target:tensor([4., 4., 3., 4.])
# model output:tensor([[3.5715],
#         [3.2160],
#         [3.2674],
#         [2.6036]]), target:tensor([4.0000, 4.0000, 3.5000, 3.0000])
# model output:tensor([[2.7820],
#         [2.1489],
#         [2.5433],
#         [3.3103]]), target:tensor([3.0000, 3.0000, 2.0000, 3.5000])
# model output:tensor([[3.8180],
#         [4.2328],
#         [3.2030],
#         [3.6574]]), target:tensor([2.0000, 3.5000, 3.5000, 2.0000])
# model output:tensor([[3.3787],
#         [4.0809],
#         [3.4625],
#         [3.3784]]), target:tensor([5.0000, 5.0000, 2.0000, 2.5000])
# model output:tensor([[3.5631],
#         [2.0799],
#         [3.1213],
#         [3.3576]]), target:tensor([2.5000, 3.0000, 5.0000, 4.0000])
# model output:tensor([[2.1403],
#         [2.4138],
#         [2.7766],
#         [3.7989]]), target:tensor([3.0000, 1.5000, 2.5000, 4.5000])
# model output:tensor([[3.3876],
#         [3.6978],
#         [3.9340],
#         [3.4726]]), target:tensor([2.0000, 4.5000, 3.0000, 3.0000])
# model output:tensor([[4.0506],
#         [3.6714],
#         [3.0877],
#         [3.3682]]), target:tensor([4.0000, 5.0000, 3.5000, 3.0000])
# model output:tensor([[4.0141],
#         [3.6261],
#         [4.2390],
#         [3.9163]]), target:tensor([5.0000, 4.0000, 4.5000, 5.0000])
# model output:tensor([[3.6822],
#         [3.4122],
#         [2.7337],
#         [4.8248]]), target:tensor([2.0000, 2.0000, 4.5000, 4.5000])
# model output:tensor([[4.2869],
#         [4.1732],
#         [3.0741],
#         [3.9793]]), target:tensor([3.5000, 4.0000, 2.5000, 5.0000])
# model output:tensor([[3.9028],
#         [3.9202],
#         [3.6797],
#         [3.5392]]), target:tensor([4.0000, 4.5000, 2.0000, 2.0000])
# model output:tensor([[3.7369],
#         [3.9034],
#         [3.2546],
#         [2.5530]]), target:tensor([2.5000, 3.5000, 3.5000, 3.0000])
# model output:tensor([[3.9587],
#         [2.7285],
#         [2.2188],
#         [3.5902]]), target:tensor([4., 3., 2., 2.])
# model output:tensor([[3.2775],
#         [2.4525],
#         [3.7138],
#         [3.3968]]), target:tensor([3.0000, 3.0000, 2.5000, 5.0000])
# model output:tensor([[2.8649],
#         [2.4050],
#         [2.3123],
#         [3.2028]]), target:tensor([2.0000, 1.0000, 3.5000, 4.0000])
# model output:tensor([[4.0120],
#         [3.0734],
#         [3.7731],
#         [3.6599]]), target:tensor([5., 5., 3., 5.])
# model output:tensor([[3.4624],
#         [3.1582],
#         [3.7820],
#         [4.1616]]), target:tensor([4., 4., 2., 5.])
# model output:tensor([[3.7946],
#         [4.2164],
#         [3.7260],
#         [3.0815]]), target:tensor([4.5000, 4.5000, 3.0000, 3.5000])
# model output:tensor([[4.3809],
#         [3.4480],
#         [2.7178],
#         [4.4370]]), target:tensor([4.0000, 3.0000, 2.5000, 4.0000])
# model output:tensor([[4.0124],
#         [4.1256],
#         [2.5468],
#         [3.4802]]), target:tensor([5.0000, 3.5000, 3.0000, 3.0000])
# model output:tensor([[4.6569],
#         [4.4166],
#         [3.6106],
#         [2.7477]]), target:tensor([4.0000, 4.0000, 3.5000, 1.5000])
# model output:tensor([[4.2136],
#         [2.7885],
#         [3.2659],
#         [4.1052]]), target:tensor([4.5000, 2.0000, 3.0000, 4.5000])
# model output:tensor([[3.2383],
#         [2.8557],
#         [3.0854],
#         [3.6575]]), target:tensor([3.5000, 2.0000, 4.0000, 4.0000])
# model output:tensor([[3.0860],
#         [2.7430],
#         [2.7957],
#         [3.5645]]), target:tensor([2.5000, 4.0000, 3.0000, 1.5000])
# model output:tensor([[3.4992],
#         [2.8433],
#         [3.8595],
#         [3.7964]]), target:tensor([2.5000, 4.0000, 4.0000, 5.0000])
# model output:tensor([[4.6356],
#         [4.3680],
#         [3.6522],
#         [3.9254]]), target:tensor([5.0000, 5.0000, 3.5000, 3.0000])
# model output:tensor([[3.3973],
#         [3.7163],
#         [3.8626],
#         [3.6751]]), target:tensor([3.5000, 5.0000, 4.5000, 3.0000])
# model output:tensor([[3.5190],
#         [3.7153],
#         [3.2317],
#         [2.8671]]), target:tensor([2.0000, 2.0000, 2.0000, 2.5000])
# model output:tensor([[3.1924],
#         [3.9430],
#         [3.5488],
#         [3.6290]]), target:tensor([5.0000, 3.0000, 3.5000, 5.0000])
# model output:tensor([[3.4290],
#         [2.7729],
#         [4.2204],
#         [3.7383]]), target:tensor([4.0000, 2.0000, 1.5000, 3.0000])
# model output:tensor([[3.5796],
#         [4.1939],
#         [3.5400],
#         [4.2374]]), target:tensor([3., 4., 1., 4.])
# model output:tensor([[2.5660],
#         [3.8797],
#         [2.8947],
#         [3.7633]]), target:tensor([2., 4., 1., 4.])
# model output:tensor([[4.5546],
#         [3.8584],
#         [2.5501],
#         [2.6584]]), target:tensor([5., 3., 3., 3.])
# model output:tensor([[3.3524],
#         [3.3471],
#         [2.6412],
#         [2.5977]]), target:tensor([4.0000, 3.5000, 4.0000, 3.5000])
# model output:tensor([[2.6505],
#         [3.6183],
#         [4.2072],
#         [3.6920]]), target:tensor([4.0000, 2.5000, 4.0000, 4.0000])
# model output:tensor([[3.1116],
#         [3.8950],
#         [3.7589],
#         [3.6880]]), target:tensor([2., 4., 3., 3.])
# model output:tensor([[3.5765],
#         [3.0439],
#         [2.9364],
#         [4.0887]]), target:tensor([5.0000, 1.0000, 2.5000, 5.0000])
# model output:tensor([[3.9765],
#         [3.7594],
#         [3.1636],
#         [3.2906]]), target:tensor([3.0000, 4.5000, 4.0000, 1.5000])
# model output:tensor([[3.0391],
#         [3.7958],
#         [3.9117],
#         [3.3172]]), target:tensor([2.5000, 5.0000, 4.0000, 3.0000])
# model output:tensor([[4.0953],
#         [2.9301],
#         [3.6379],
#         [3.3873]]), target:tensor([4.5000, 2.0000, 3.5000, 3.0000])
# model output:tensor([[2.7703],
#         [3.9901],
#         [3.4765],
#         [4.1051]]), target:tensor([4.5000, 3.5000, 5.0000, 4.5000])
# model output:tensor([[4.2759],
#         [3.6897],
#         [3.6617],
#         [3.7106]]), target:tensor([3.0000, 4.0000, 4.5000, 3.5000])
# model output:tensor([[3.7706],
#         [3.8006],
#         [3.3000],
#         [4.2753]]), target:tensor([4., 5., 3., 4.])
# model output:tensor([[4.1004],
#         [3.2103],
#         [3.0842],
#         [3.7384]]), target:tensor([4.5000, 3.5000, 2.5000, 3.5000])
# model output:tensor([[3.6035],
#         [3.1762],
#         [4.1919],
#         [4.3066]]), target:tensor([4., 5., 4., 5.])
# model output:tensor([[2.7498],
#         [4.3064],
#         [2.6698],
#         [3.4465]]), target:tensor([3.0000, 4.5000, 2.0000, 3.0000])
# model output:tensor([[2.8376],
#         [2.6605],
#         [3.9937],
#         [3.0714]]), target:tensor([3.0000, 3.0000, 4.5000, 4.0000])
# model output:tensor([[2.9226],
#         [3.0455],
#         [4.0837],
#         [3.5212]]), target:tensor([2.0000, 2.5000, 3.0000, 3.0000])
# model output:tensor([[3.5033],
#         [4.3620],
#         [3.4465],
#         [2.9176]]), target:tensor([4.0000, 3.0000, 4.0000, 3.5000])
# model output:tensor([[2.9412],
#         [4.2031],
#         [3.9662],
#         [3.8733]]), target:tensor([3.5000, 4.0000, 3.0000, 3.0000])
# model output:tensor([[3.7158],
#         [3.1534],
#         [3.4959],
#         [3.5137]]), target:tensor([4.0000, 3.0000, 4.5000, 3.0000])
# model output:tensor([[3.7296],
#         [3.5924],
#         [3.6743],
#         [3.3280]]), target:tensor([4., 4., 4., 4.])
# model output:tensor([[3.7400],
#         [3.5894],
#         [4.3375],
#         [2.8512]]), target:tensor([4.5000, 3.0000, 5.0000, 3.5000])
# model output:tensor([[3.5901],
#         [4.1108],
#         [3.4634],
#         [3.7227]]), target:tensor([4.5000, 4.0000, 2.0000, 4.0000])
# model output:tensor([[3.7875],
#         [2.6756],
#         [3.4362],
#         [3.6470]]), target:tensor([3.0000, 3.0000, 4.0000, 0.5000])
# model output:tensor([[2.5664],
#         [4.2325],
#         [3.2160],
#         [3.7872]]), target:tensor([2.5000, 4.0000, 5.0000, 3.5000])
# model output:tensor([[2.3240],
#         [2.8624],
#         [4.5911],
#         [2.4134]]), target:tensor([0.5000, 2.0000, 5.0000, 3.0000])
# model output:tensor([[3.4204],
#         [4.0949],
#         [3.4193],
#         [3.3835]]), target:tensor([3.0000, 5.0000, 4.5000, 4.0000])
# model output:tensor([[3.6292],
#         [3.4303],
#         [3.7432],
#         [0.9908]]), target:tensor([5.0000, 2.5000, 3.5000, 0.5000])
# model output:tensor([[3.6992],
#         [4.0149],
#         [4.5662],
#         [3.3021]]), target:tensor([5.0000, 3.5000, 5.0000, 3.5000])
# model output:tensor([[3.2482],
#         [3.4781],
#         [3.9516],
#         [4.0378]]), target:tensor([0.5000, 4.0000, 4.0000, 2.5000])
# model output:tensor([[3.4319],
#         [4.0500],
#         [4.1198],
#         [3.1649]]), target:tensor([5.0000, 4.5000, 4.0000, 4.0000])
# model output:tensor([[3.2448],
#         [3.7227],
#         [3.4084],
#         [3.7147]]), target:tensor([3.5000, 5.0000, 3.0000, 3.0000])
# model output:tensor([[2.7129],
#         [3.1838],
#         [2.7211],
#         [4.2580]]), target:tensor([2.0000, 2.5000, 3.0000, 4.0000])
# model output:tensor([[2.6231],
#         [3.3640],
#         [2.4405],
#         [3.3698]]), target:tensor([2.5000, 3.0000, 2.0000, 4.0000])
# model output:tensor([[3.3398],
#         [3.1973],
#         [3.2387],
#         [4.4061]]), target:tensor([3., 5., 3., 5.])
# model output:tensor([[3.5250],
#         [3.6858],
#         [3.4294],
#         [2.4142]]), target:tensor([4.0000, 2.5000, 3.5000, 1.0000])
# model output:tensor([[3.6644],
#         [3.6811],
#         [3.9155],
#         [4.1774]]), target:tensor([3.5000, 5.0000, 4.0000, 5.0000])
# model output:tensor([[4.4385],
#         [3.8510],
#         [4.3735],
#         [4.0478]]), target:tensor([5., 3., 5., 4.])
# model output:tensor([[5.1416],
#         [3.2059],
#         [3.0770],
#         [3.9720]]), target:tensor([5., 4., 2., 5.])
# model output:tensor([[3.5385],
#         [3.3049],
#         [3.7099],
#         [2.7676]]), target:tensor([5.0000, 3.5000, 4.0000, 3.0000])
# model output:tensor([[3.0392],
#         [2.7017],
#         [4.2593],
#         [3.6127]]), target:tensor([4.5000, 4.5000, 4.5000, 5.0000])
# model output:tensor([[3.8544],
#         [3.4614],
#         [3.2973],
#         [3.9384]]), target:tensor([3., 4., 3., 4.])
# model output:tensor([[3.6519],
#         [3.2623],
#         [3.6962],
#         [3.5541]]), target:tensor([3.5000, 4.0000, 5.0000, 3.5000])
# model output:tensor([[3.4986],
#         [3.4220],
#         [3.6278],
#         [3.5925]]), target:tensor([3.5000, 3.0000, 2.5000, 4.0000])
# model output:tensor([[3.9830],
#         [2.8981],
#         [3.2608],
#         [3.5600]]), target:tensor([4.5000, 3.0000, 4.0000, 4.5000])
# model output:tensor([[3.3022],
#         [3.2809],
#         [3.5205],
#         [2.2825]]), target:tensor([3.5000, 3.0000, 0.5000, 3.0000])
# model output:tensor([[3.9918],
#         [3.2404],
#         [3.3971],
#         [3.6570]]), target:tensor([5.0000, 4.0000, 3.5000, 3.0000])
# model output:tensor([[3.5702],
#         [2.8450],
#         [3.2300],
#         [3.0844]]), target:tensor([3.5000, 3.0000, 4.0000, 4.0000])
# model output:tensor([[3.3607],
#         [2.3144],
#         [4.5365],
#         [3.8146]]), target:tensor([5., 3., 5., 5.])
# model output:tensor([[4.2920],
#         [3.6336],
#         [3.5261],
#         [3.7832]]), target:tensor([4.5000, 4.0000, 3.5000, 3.0000])
# model output:tensor([[3.7521],
#         [3.2987],
#         [3.9015],
#         [3.5973]]), target:tensor([3.5000, 3.0000, 4.0000, 3.0000])
# model output:tensor([[4.1307],
#         [1.9664],
#         [3.7992],
#         [2.7577]]), target:tensor([3.0000, 3.0000, 4.0000, 4.5000])
# model output:tensor([[3.6115],
#         [2.9280],
#         [2.2965],
#         [3.6381]]), target:tensor([3.5000, 3.0000, 3.5000, 3.0000])
# model output:tensor([[3.1425],
#         [3.5366],
#         [3.0389],
#         [2.8044]]), target:tensor([3., 4., 3., 2.])
# model output:tensor([[3.9797],
#         [2.9710],
#         [3.2281],
#         [3.1851]]), target:tensor([4.0000, 5.0000, 0.5000, 1.0000])
# model output:tensor([[3.7262],
#         [3.8628],
#         [3.2434],
#         [3.7086]]), target:tensor([1.5000, 4.0000, 3.0000, 5.0000])
# model output:tensor([[3.7875],
#         [3.6220],
#         [4.0159],
#         [3.5644]]), target:tensor([3.5000, 3.0000, 4.0000, 5.0000])
# RMS 0.4632153285491479

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            0        0     4.0   964982703
# 1            0        2     4.0   964981247
# 2            0        5     4.0   964982224
# 3            0       43     5.0   964983815
# 4            0       46     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     609     9416     4.0  1493848402
# 100832     609     9443     5.0  1493850091
# 100833     609     9444     5.0  1494273047
# 100834     609     9445     5.0  1493846352
# 100835     609     9485     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
from collections import defaultdict

users_dict=defaultdict(list)

with torch.no_grad():
    for i,test_batch in enumerate(test_loader):
        users_=test_batch['users']
        movies_=test_batch["movies"]
        ratings_=test_batch["ratings"]
        
        output=model(users_,movies_)
        
        for i in range(len(users_)):
            user_id=users_[i].item()
            movie_id=movies_[i].item()
            pred_rating=output[i][0].item()
            actual_rating=ratings_[i].item()
            print(f'userId:{user_id}, movieId:{movie_id}, pred rating:{pred_rating}, actual rating:{actual_rating}')
            users_dict[user_id].append((pred_rating,actual_rating))
# Out:
# userId:371, movieId:793, pred rating:3.4934844970703125, actual rating:5.0
# userId:368, movieId:3623, pred rating:3.501201629638672, actual rating:3.5
# userId:524, movieId:3609, pred rating:3.411863327026367, actual rating:4.5
# userId:199, movieId:793, pred rating:3.785320997238159, actual rating:3.5
# userId:67, movieId:6619, pred rating:2.4896771907806396, actual rating:2.0
# userId:605, movieId:5345, pred rating:2.8746445178985596, actual rating:4.0
# userId:545, movieId:328, pred rating:3.26581072807312, actual rating:4.0
# userId:602, movieId:2183, pred rating:3.674532413482666, actual rating:3.0
# userId:482, movieId:898, pred rating:4.416070938110352, actual rating:5.0
# userId:338, movieId:8449, pred rating:3.7698516845703125, actual rating:3.5
# userId:56, movieId:2817, pred rating:2.720944404602051, actual rating:4.0
# userId:284, movieId:8464, pred rating:3.4085447788238525, actual rating:3.5
# userId:461, movieId:866, pred rating:2.931382894515991, actual rating:3.5
# userId:338, movieId:6869, pred rating:3.3977105617523193, actual rating:4.0
# userId:152, movieId:3191, pred rating:2.4487812519073486, actual rating:3.0
# userId:609, movieId:8480, pred rating:3.6518678665161133, actual rating:4.0
# userId:151, movieId:659, pred rating:4.202958106994629, actual rating:5.0
# userId:488, movieId:2543, pred rating:3.358006477355957, actual rating:3.0
# userId:599, movieId:2192, pred rating:3.501796245574951, actual rating:2.0
# userId:433, movieId:0, pred rating:3.2013797760009766, actual rating:4.0
# userId:483, movieId:6721, pred rating:2.958059072494507, actual rating:4.5
# userId:473, movieId:3021, pred rating:3.344038486480713, actual rating:4.0
# userId:216, movieId:2218, pred rating:2.7536051273345947, actual rating:3.0
# userId:540, movieId:263, pred rating:3.008040428161621, actual rating:3.0
# userId:570, movieId:1456, pred rating:2.5717720985412598, actual rating:2.0
# userId:88, movieId:2895, pred rating:3.6520400047302246, actual rating:2.0
# userId:607, movieId:472, pred rating:3.16586971282959, actual rating:2.5
# userId:62, movieId:7749, pred rating:3.4500086307525635, actual rating:0.5
# userId:461, movieId:2151, pred rating:3.2373995780944824, actual rating:3.5
# userId:413, movieId:948, pred rating:4.302891254425049, actual rating:5.0
# userId:377, movieId:7987, pred rating:3.328947067260742, actual rating:3.5
# userId:273, movieId:2709, pred rating:3.0198793411254883, actual rating:4.0
# userId:595, movieId:7888, pred rating:3.3348026275634766, actual rating:4.0
# userId:474, movieId:5331, pred rating:2.798055648803711, actual rating:3.5
# userId:72, movieId:6993, pred rating:4.2305145263671875, actual rating:5.0
# userId:602, movieId:1033, pred rating:2.96256160736084, actual rating:4.0
# userId:598, movieId:8326, pred rating:2.597688913345337, actual rating:3.5
# userId:609, movieId:2804, pred rating:3.5097362995147705, actual rating:3.5
# userId:273, movieId:2021, pred rating:3.2471280097961426, actual rating:3.5
# userId:558, movieId:618, pred rating:2.8957583904266357, actual rating:4.0
# userId:607, movieId:2839, pred rating:2.770345449447632, actual rating:2.0
# userId:337, movieId:46, pred rating:3.654850959777832, actual rating:4.5
# userId:595, movieId:6396, pred rating:3.055819034576416, actual rating:3.0
# userId:488, movieId:6460, pred rating:3.456446409225464, actual rating:3.0
# userId:298, movieId:2485, pred rating:2.798211097717285, actual rating:3.0
# userId:389, movieId:5388, pred rating:3.1612586975097656, actual rating:5.0
# userId:104, movieId:7928, pred rating:3.9484219551086426, actual rating:4.0
# userId:273, movieId:2019, pred rating:3.851221799850464, actual rating:2.5
# userId:287, movieId:2345, pred rating:3.2277684211730957, actual rating:3.0
# userId:300, movieId:315, pred rating:3.4740543365478516, actual rating:2.5
# userId:366, movieId:1153, pred rating:3.3426668643951416, actual rating:1.0
# userId:338, movieId:7627, pred rating:3.3607311248779297, actual rating:3.5
# userId:592, movieId:965, pred rating:3.6735260486602783, actual rating:4.0
# userId:473, movieId:5674, pred rating:3.5392208099365234, actual rating:3.5
# userId:551, movieId:2988, pred rating:3.2791411876678467, actual rating:3.0
# userId:508, movieId:5899, pred rating:3.4061574935913086, actual rating:4.0
# userId:83, movieId:46, pred rating:4.074726581573486, actual rating:4.0
# userId:155, movieId:1403, pred rating:3.6783082485198975, actual rating:4.0
# userId:165, movieId:2257, pred rating:4.090217590332031, actual rating:4.5
# userId:476, movieId:6529, pred rating:3.2270655632019043, actual rating:4.0
# userId:413, movieId:6951, pred rating:2.898059606552124, actual rating:3.0
# userId:461, movieId:3613, pred rating:3.3753838539123535, actual rating:4.0
# userId:423, movieId:4013, pred rating:3.212773084640503, actual rating:4.0
# userId:138, movieId:4355, pred rating:2.872936964035034, actual rating:2.0
# userId:385, movieId:415, pred rating:2.0752224922180176, actual rating:3.0
# userId:104, movieId:267, pred rating:4.227810859680176, actual rating:4.5
# userId:67, movieId:622, pred rating:2.620128870010376, actual rating:1.0
# userId:521, movieId:322, pred rating:3.9445607662200928, actual rating:3.0
# userId:570, movieId:1014, pred rating:3.2682111263275146, actual rating:2.0
# userId:181, movieId:2456, pred rating:3.397181749343872, actual rating:4.5
# userId:488, movieId:6501, pred rating:2.9224536418914795, actual rating:3.0
# userId:290, movieId:4070, pred rating:3.898207426071167, actual rating:5.0
# userId:139, movieId:2576, pred rating:3.2038183212280273, actual rating:4.0
# userId:18, movieId:2867, pred rating:2.7697532176971436, actual rating:1.0
# userId:67, movieId:4620, pred rating:3.1378302574157715, actual rating:3.5
# userId:90, movieId:1986, pred rating:3.2808306217193604, actual rating:3.5
# userId:135, movieId:138, pred rating:3.0733628273010254, actual rating:5.0
# userId:447, movieId:5333, pred rating:3.451139450073242, actual rating:3.5
# userId:488, movieId:3147, pred rating:3.2046868801116943, actual rating:1.5
# userId:447, movieId:8347, pred rating:2.8116278648376465, actual rating:1.5
# userId:444, movieId:266, pred rating:4.080811500549316, actual rating:4.0
# userId:294, movieId:694, pred rating:4.0843424797058105, actual rating:4.0
# userId:6, movieId:1266, pred rating:3.9477596282958984, actual rating:3.0
# userId:65, movieId:945, pred rating:4.212970733642578, actual rating:5.0
# userId:338, movieId:7701, pred rating:3.3623597621917725, actual rating:4.5
# userId:168, movieId:1881, pred rating:4.2593536376953125, actual rating:5.0
# userId:110, movieId:4092, pred rating:3.0862817764282227, actual rating:4.0
# userId:300, movieId:3136, pred rating:4.047846794128418, actual rating:4.0
# userId:110, movieId:6756, pred rating:3.017094135284424, actual rating:4.0
# userId:16, movieId:1297, pred rating:3.913461208343506, actual rating:5.0
# userId:452, movieId:3146, pred rating:3.729461669921875, actual rating:4.0
# userId:199, movieId:3617, pred rating:4.210962295532227, actual rating:5.0
# userId:110, movieId:6204, pred rating:3.2775518894195557, actual rating:3.0
# userId:170, movieId:3668, pred rating:4.446524620056152, actual rating:4.0
# userId:540, movieId:514, pred rating:3.628716230392456, actual rating:3.0
# userId:99, movieId:5250, pred rating:4.359005928039551, actual rating:4.5
# userId:56, movieId:1495, pred rating:3.2488627433776855, actual rating:2.0
# userId:473, movieId:1443, pred rating:3.494729518890381, actual rating:3.0
# userId:447, movieId:7658, pred rating:3.264955520629883, actual rating:2.0
# userId:473, movieId:4064, pred rating:2.992584466934204, actual rating:4.0
# userId:186, movieId:1927, pred rating:3.576066493988037, actual rating:4.5
# userId:185, movieId:2000, pred rating:3.8557581901550293, actual rating:4.0
# userId:602, movieId:976, pred rating:4.3065876960754395, actual rating:5.0
# userId:317, movieId:7919, pred rating:3.5679931640625, actual rating:3.0
# userId:108, movieId:30, pred rating:2.810682535171509, actual rating:3.0
# userId:260, movieId:7439, pred rating:3.3791370391845703, actual rating:4.5
# userId:409, movieId:1528, pred rating:3.9965896606445312, actual rating:5.0
# userId:197, movieId:3623, pred rating:3.7112374305725098, actual rating:1.0
# userId:413, movieId:6016, pred rating:3.3201746940612793, actual rating:3.5
# userId:31, movieId:606, pred rating:3.360522508621216, actual rating:4.0
# userId:303, movieId:1318, pred rating:3.904691219329834, actual rating:4.0
# userId:185, movieId:3827, pred rating:3.8767902851104736, actual rating:4.0
# userId:473, movieId:4335, pred rating:3.3865232467651367, actual rating:3.5
# userId:110, movieId:2224, pred rating:4.198282718658447, actual rating:5.0
# userId:596, movieId:3668, pred rating:4.150584697723389, actual rating:5.0
# userId:606, movieId:2742, pred rating:3.108064651489258, actual rating:3.0
# userId:220, movieId:1070, pred rating:3.3294172286987305, actual rating:4.0
# userId:286, movieId:4974, pred rating:2.4752466678619385, actual rating:0.5
# userId:73, movieId:4089, pred rating:3.760333776473999, actual rating:4.0
# userId:337, movieId:5682, pred rating:3.6482467651367188, actual rating:4.0
# userId:505, movieId:6321, pred rating:3.6872003078460693, actual rating:3.5
# userId:274, movieId:889, pred rating:3.4318668842315674, actual rating:5.0
# userId:161, movieId:509, pred rating:4.25174617767334, actual rating:4.0
# userId:5, movieId:545, pred rating:3.686715602874756, actual rating:4.0
# userId:270, movieId:3296, pred rating:3.0919878482818604, actual rating:3.0
# userId:176, movieId:1392, pred rating:2.6384451389312744, actual rating:3.0
# userId:526, movieId:695, pred rating:4.743086814880371, actual rating:4.0
# userId:447, movieId:8175, pred rating:3.223255157470703, actual rating:2.5
# userId:437, movieId:5354, pred rating:3.583568572998047, actual rating:5.0
# userId:408, movieId:1873, pred rating:3.3198208808898926, actual rating:4.0
# userId:609, movieId:6645, pred rating:3.4692423343658447, actual rating:4.0
# userId:267, movieId:906, pred rating:4.029537200927734, actual rating:3.0
# userId:62, movieId:7043, pred rating:3.8369438648223877, actual rating:4.0
# userId:143, movieId:0, pred rating:3.7917160987854004, actual rating:3.5
# userId:27, movieId:2543, pred rating:3.215632915496826, actual rating:3.0
# userId:554, movieId:1080, pred rating:3.381324291229248, actual rating:3.0
# userId:607, movieId:2576, pred rating:2.9850616455078125, actual rating:3.5
# userId:118, movieId:5255, pred rating:4.673900604248047, actual rating:4.0
# userId:181, movieId:944, pred rating:3.9219069480895996, actual rating:4.5
# userId:384, movieId:925, pred rating:4.193212985992432, actual rating:3.0
# userId:291, movieId:3740, pred rating:2.9943253993988037, actual rating:4.0
# userId:378, movieId:43, pred rating:3.488391399383545, actual rating:3.0
# userId:63, movieId:4402, pred rating:4.25916862487793, actual rating:4.5
# userId:194, movieId:485, pred rating:3.893082618713379, actual rating:4.0
# userId:413, movieId:4509, pred rating:3.5692873001098633, actual rating:4.0
# userId:33, movieId:2832, pred rating:3.373969078063965, actual rating:5.0
# userId:380, movieId:3498, pred rating:3.555225133895874, actual rating:5.0
# userId:447, movieId:2942, pred rating:3.2809481620788574, actual rating:3.0
# userId:609, movieId:2691, pred rating:3.7827470302581787, actual rating:2.0
# userId:244, movieId:2341, pred rating:2.4686391353607178, actual rating:1.0
# userId:109, movieId:827, pred rating:3.764573574066162, actual rating:4.0
# userId:104, movieId:5955, pred rating:4.055241107940674, actual rating:3.0
# userId:410, movieId:340, pred rating:2.552217960357666, actual rating:2.0
# userId:602, movieId:1167, pred rating:3.8881640434265137, actual rating:4.0
# userId:371, movieId:818, pred rating:3.6135756969451904, actual rating:4.0
# userId:473, movieId:5036, pred rating:3.8431191444396973, actual rating:3.5
# userId:61, movieId:7749, pred rating:3.717385768890381, actual rating:4.0
# userId:287, movieId:545, pred rating:3.3258113861083984, actual rating:3.0
# userId:411, movieId:1903, pred rating:3.2961807250976562, actual rating:2.0
# userId:367, movieId:2921, pred rating:2.247220516204834, actual rating:1.0
# userId:524, movieId:6501, pred rating:2.958415985107422, actual rating:3.0
# userId:609, movieId:4471, pred rating:3.0063295364379883, actual rating:3.0
# userId:61, movieId:8008, pred rating:3.659574508666992, actual rating:4.5
# userId:576, movieId:948, pred rating:3.9085140228271484, actual rating:5.0
# userId:566, movieId:2377, pred rating:2.0836291313171387, actual rating:2.0
# userId:483, movieId:325, pred rating:3.295783042907715, actual rating:3.0
# userId:435, movieId:138, pred rating:2.9785807132720947, actual rating:3.0
# userId:607, movieId:1208, pred rating:3.173647165298462, actual rating:3.0
# userId:130, movieId:895, pred rating:3.76157283782959, actual rating:3.5
# userId:135, movieId:97, pred rating:3.7127585411071777, actual rating:5.0
# userId:605, movieId:4570, pred rating:3.4324636459350586, actual rating:2.5
# userId:147, movieId:8050, pred rating:3.4565083980560303, actual rating:3.0
# userId:110, movieId:9585, pred rating:3.483048915863037, actual rating:4.0
# userId:291, movieId:2864, pred rating:2.9646716117858887, actual rating:4.5
# userId:479, movieId:4936, pred rating:2.6107115745544434, actual rating:3.0
# userId:604, movieId:1485, pred rating:2.9755094051361084, actual rating:4.0
# userId:52, movieId:419, pred rating:4.558749198913574, actual rating:5.0
# userId:399, movieId:2941, pred rating:4.4451117515563965, actual rating:5.0
# userId:18, movieId:1872, pred rating:2.441490411758423, actual rating:4.0
# userId:386, movieId:828, pred rating:3.572462558746338, actual rating:3.5
# userId:209, movieId:7516, pred rating:4.309613227844238, actual rating:4.0
# userId:506, movieId:395, pred rating:3.6637182235717773, actual rating:3.0
# userId:447, movieId:2687, pred rating:3.0891246795654297, actual rating:1.0
# userId:344, movieId:1274, pred rating:3.6771464347839355, actual rating:4.0
# userId:90, movieId:504, pred rating:3.1300458908081055, actual rating:2.0
# userId:461, movieId:2144, pred rating:3.6105751991271973, actual rating:3.5
# userId:589, movieId:5025, pred rating:3.183685302734375, actual rating:4.0
# userId:473, movieId:2430, pred rating:3.20098876953125, actual rating:3.5
# userId:225, movieId:3694, pred rating:3.053180456161499, actual rating:4.0
# userId:593, movieId:1116, pred rating:3.4839441776275635, actual rating:4.5
# userId:522, movieId:314, pred rating:5.0000433921813965, actual rating:4.5
# userId:286, movieId:5245, pred rating:2.1462717056274414, actual rating:4.5
# userId:65, movieId:4778, pred rating:3.7392656803131104, actual rating:3.5
# userId:297, movieId:2485, pred rating:1.969588279724121, actual rating:1.0
# userId:100, movieId:2083, pred rating:3.382479429244995, actual rating:2.0
# userId:578, movieId:1796, pred rating:3.9069571495056152, actual rating:5.0
# userId:607, movieId:919, pred rating:3.4293177127838135, actual rating:3.0
# userId:17, movieId:2586, pred rating:3.353968381881714, actual rating:4.0
# userId:360, movieId:6350, pred rating:2.9586896896362305, actual rating:1.5
# userId:581, movieId:6993, pred rating:4.437471389770508, actual rating:4.0
# userId:424, movieId:3573, pred rating:2.8849892616271973, actual rating:4.0
# userId:83, movieId:471, pred rating:3.5029149055480957, actual rating:3.0
# userId:248, movieId:8674, pred rating:4.529629707336426, actual rating:4.5
# userId:225, movieId:963, pred rating:3.757645606994629, actual rating:4.0
# userId:413, movieId:134, pred rating:3.905182123184204, actual rating:3.0
# userId:263, movieId:785, pred rating:3.870518684387207, actual rating:5.0
# userId:589, movieId:33, pred rating:3.574021816253662, actual rating:3.5
# userId:501, movieId:41, pred rating:3.244133949279785, actual rating:3.5
# userId:562, movieId:44, pred rating:3.046612024307251, actual rating:3.5
# userId:112, movieId:189, pred rating:3.3648271560668945, actual rating:4.0
# userId:523, movieId:932, pred rating:3.650517463684082, actual rating:5.0
# userId:483, movieId:6780, pred rating:3.5459604263305664, actual rating:3.0
# userId:317, movieId:6028, pred rating:4.042270660400391, actual rating:4.0
# userId:427, movieId:3666, pred rating:3.045773983001709, actual rating:3.5
# userId:606, movieId:1398, pred rating:3.3655142784118652, actual rating:4.0
# userId:589, movieId:509, pred rating:3.1649577617645264, actual rating:3.5
# userId:375, movieId:2078, pred rating:3.93500018119812, actual rating:4.0
# userId:476, movieId:4352, pred rating:2.874765634536743, actual rating:4.5
# userId:197, movieId:1401, pred rating:4.066257953643799, actual rating:2.0
# userId:434, movieId:1497, pred rating:3.8926749229431152, actual rating:5.0
# userId:199, movieId:5920, pred rating:2.824371337890625, actual rating:2.5
# userId:596, movieId:2083, pred rating:3.3816561698913574, actual rating:2.0
# userId:273, movieId:7133, pred rating:3.2213001251220703, actual rating:2.5
# userId:63, movieId:1080, pred rating:3.368844509124756, actual rating:4.0
# userId:379, movieId:7961, pred rating:4.178194046020508, actual rating:3.0
# userId:44, movieId:506, pred rating:4.459310054779053, actual rating:5.0
# userId:27, movieId:954, pred rating:3.143840789794922, actual rating:4.0
# userId:159, movieId:2194, pred rating:2.7434372901916504, actual rating:2.0
# userId:165, movieId:2380, pred rating:3.7201220989227295, actual rating:4.0
# userId:598, movieId:489, pred rating:2.7852940559387207, actual rating:2.0
# userId:40, movieId:8005, pred rating:2.849306583404541, actual rating:4.0
# userId:237, movieId:3602, pred rating:3.2184090614318848, actual rating:3.0
# userId:38, movieId:1075, pred rating:3.4295177459716797, actual rating:3.0
# userId:598, movieId:845, pred rating:2.457404613494873, actual rating:3.0
# userId:589, movieId:140, pred rating:2.7660179138183594, actual rating:3.0
# userId:581, movieId:8354, pred rating:3.95525860786438, actual rating:4.0
# userId:605, movieId:2599, pred rating:3.5061049461364746, actual rating:3.5
# userId:287, movieId:383, pred rating:3.0859813690185547, actual rating:3.5
# userId:452, movieId:3152, pred rating:4.081024646759033, actual rating:5.0
# userId:97, movieId:6753, pred rating:3.4692630767822266, actual rating:4.0
# userId:479, movieId:5589, pred rating:2.700756072998047, actual rating:4.0
# userId:248, movieId:9415, pred rating:4.036498546600342, actual rating:5.0
# userId:367, movieId:2760, pred rating:2.6623425483703613, actual rating:3.0
# userId:413, movieId:1861, pred rating:3.721879005432129, actual rating:4.0
# userId:46, movieId:4604, pred rating:3.217268705368042, actual rating:3.5
# userId:413, movieId:782, pred rating:3.2280592918395996, actual rating:4.0
# userId:541, movieId:2941, pred rating:4.129057884216309, actual rating:4.0
# userId:598, movieId:2173, pred rating:2.9786384105682373, actual rating:3.5
# userId:304, movieId:895, pred rating:4.436522483825684, actual rating:5.0
# userId:381, movieId:6593, pred rating:3.6593363285064697, actual rating:3.0
# userId:421, movieId:2963, pred rating:2.972167730331421, actual rating:3.0
# userId:312, movieId:1149, pred rating:2.6761834621429443, actual rating:4.0
# userId:589, movieId:4131, pred rating:3.7132155895233154, actual rating:5.0
# userId:138, movieId:6153, pred rating:2.5913455486297607, actual rating:2.5
# userId:589, movieId:6539, pred rating:3.5558674335479736, actual rating:3.0
# userId:121, movieId:961, pred rating:4.53159236907959, actual rating:5.0
# userId:110, movieId:3820, pred rating:2.727322578430176, actual rating:3.0
# userId:605, movieId:1264, pred rating:3.3618502616882324, actual rating:4.5
# userId:287, movieId:1488, pred rating:3.05914306640625, actual rating:2.0
# userId:293, movieId:1768, pred rating:2.0586929321289062, actual rating:1.0
# userId:355, movieId:5293, pred rating:3.5707857608795166, actual rating:5.0
# userId:482, movieId:792, pred rating:4.143733024597168, actual rating:3.5
# userId:379, movieId:7969, pred rating:4.152353763580322, actual rating:2.0
# userId:473, movieId:644, pred rating:3.329522132873535, actual rating:2.0
# userId:216, movieId:2042, pred rating:2.5407934188842773, actual rating:3.0
# userId:264, movieId:1292, pred rating:2.805384397506714, actual rating:3.0
# userId:124, movieId:9351, pred rating:2.8932673931121826, actual rating:3.0
# userId:132, movieId:46, pred rating:3.2097389698028564, actual rating:3.0
# userId:381, movieId:224, pred rating:4.1585822105407715, actual rating:5.0
# userId:555, movieId:7261, pred rating:3.078855514526367, actual rating:4.0
# userId:278, movieId:8045, pred rating:4.169424057006836, actual rating:4.0
# userId:67, movieId:2578, pred rating:3.317401170730591, actual rating:2.5
# userId:500, movieId:545, pred rating:3.1404566764831543, actual rating:4.0
# userId:305, movieId:3979, pred rating:2.9514055252075195, actual rating:3.5
# userId:566, movieId:7723, pred rating:2.812436819076538, actual rating:2.5
# userId:537, movieId:2729, pred rating:4.850811004638672, actual rating:4.5
# userId:63, movieId:659, pred rating:4.321648120880127, actual rating:5.0
# userId:103, movieId:7403, pred rating:3.742480993270874, actual rating:4.0
# userId:605, movieId:3047, pred rating:3.755418062210083, actual rating:2.5
# userId:146, movieId:513, pred rating:3.165179491043091, actual rating:3.0
# userId:476, movieId:904, pred rating:4.2283244132995605, actual rating:4.0
# userId:330, movieId:5719, pred rating:3.5794856548309326, actual rating:3.5
# userId:427, movieId:906, pred rating:3.4637975692749023, actual rating:4.5
# userId:386, movieId:418, pred rating:3.4603629112243652, actual rating:3.0
# userId:0, movieId:2019, pred rating:4.612777233123779, actual rating:5.0
# userId:124, movieId:4421, pred rating:3.7420129776000977, actual rating:4.0
# userId:226, movieId:6241, pred rating:3.7039899826049805, actual rating:4.0
# userId:327, movieId:771, pred rating:3.3000853061676025, actual rating:2.0
# userId:533, movieId:9378, pred rating:3.484355926513672, actual rating:5.0
# userId:297, movieId:4519, pred rating:2.8086507320404053, actual rating:3.0
# userId:379, movieId:5681, pred rating:3.395404577255249, actual rating:3.0
# userId:473, movieId:6229, pred rating:3.1831307411193848, actual rating:4.0
# userId:215, movieId:2977, pred rating:3.476970672607422, actual rating:1.0
# userId:379, movieId:4545, pred rating:3.451317310333252, actual rating:4.0
# userId:317, movieId:6192, pred rating:3.6094069480895996, actual rating:3.5
# userId:231, movieId:118, pred rating:3.5857176780700684, actual rating:3.5
# userId:609, movieId:8237, pred rating:3.911728858947754, actual rating:4.0
# userId:0, movieId:1234, pred rating:3.540445327758789, actual rating:3.0
# userId:473, movieId:3303, pred rating:2.9192841053009033, actual rating:2.0
# userId:12, movieId:514, pred rating:3.568354606628418, actual rating:3.0
# userId:379, movieId:8315, pred rating:3.882951259613037, actual rating:3.0
# userId:411, movieId:929, pred rating:3.9833953380584717, actual rating:4.0
# userId:281, movieId:3136, pred rating:4.4153218269348145, actual rating:4.5
# userId:273, movieId:2962, pred rating:2.456878185272217, actual rating:2.0
# userId:598, movieId:2432, pred rating:2.14849853515625, actual rating:3.0
# userId:243, movieId:621, pred rating:3.6786153316497803, actual rating:4.0
# userId:474, movieId:8358, pred rating:4.321455955505371, actual rating:4.0
# userId:248, movieId:4355, pred rating:4.390638828277588, actual rating:4.0
# userId:605, movieId:1803, pred rating:2.703465461730957, actual rating:2.0
# userId:371, movieId:994, pred rating:3.7255821228027344, actual rating:4.0
# userId:344, movieId:4028, pred rating:3.19926381111145, actual rating:3.5
# userId:509, movieId:1070, pred rating:2.37139892578125, actual rating:0.5
# userId:56, movieId:706, pred rating:3.7372260093688965, actual rating:5.0
# userId:211, movieId:3189, pred rating:3.606448173522949, actual rating:4.0
# userId:88, movieId:7058, pred rating:3.9426140785217285, actual rating:2.5
# userId:452, movieId:97, pred rating:4.270539283752441, actual rating:5.0
# userId:368, movieId:326, pred rating:3.0745577812194824, actual rating:3.0
# userId:20, movieId:8782, pred rating:2.9073612689971924, actual rating:3.0
# userId:367, movieId:2473, pred rating:2.7717180252075195, actual rating:4.0
# userId:287, movieId:2832, pred rating:3.46366286277771, actual rating:3.5
# userId:591, movieId:136, pred rating:3.862821340560913, actual rating:5.0
# userId:82, movieId:706, pred rating:3.433253765106201, actual rating:5.0
# userId:596, movieId:965, pred rating:4.522851943969727, actual rating:5.0
# userId:407, movieId:277, pred rating:4.7223429679870605, actual rating:4.5
# userId:11, movieId:315, pred rating:3.7861249446868896, actual rating:3.5
# userId:482, movieId:1157, pred rating:3.9301083087921143, actual rating:3.5
# userId:211, movieId:4342, pred rating:3.7852325439453125, actual rating:4.0
# userId:473, movieId:2967, pred rating:2.7609703540802, actual rating:4.5
# userId:368, movieId:5876, pred rating:2.659783124923706, actual rating:3.5
# userId:596, movieId:249, pred rating:3.944326877593994, actual rating:3.0
# userId:598, movieId:7669, pred rating:2.634216070175171, actual rating:2.5
# userId:338, movieId:7449, pred rating:4.121067047119141, actual rating:4.0
# userId:598, movieId:1056, pred rating:2.9851458072662354, actual rating:3.0
# userId:231, movieId:3442, pred rating:3.5281004905700684, actual rating:3.0
# userId:452, movieId:31, pred rating:4.453732490539551, actual rating:5.0
# userId:559, movieId:920, pred rating:3.862283229827881, actual rating:3.5
# userId:566, movieId:8658, pred rating:2.853036403656006, actual rating:0.5
# userId:413, movieId:3359, pred rating:3.4143829345703125, actual rating:3.0
# userId:292, movieId:0, pred rating:3.2665698528289795, actual rating:3.0
# userId:216, movieId:452, pred rating:2.4197418689727783, actual rating:4.0
# userId:158, movieId:6911, pred rating:2.9085710048675537, actual rating:4.0
# userId:62, movieId:1297, pred rating:3.6470022201538086, actual rating:0.5
# userId:62, movieId:7756, pred rating:3.201037883758545, actual rating:4.0
# userId:136, movieId:910, pred rating:4.351471900939941, actual rating:3.0
# userId:569, movieId:134, pred rating:3.414031744003296, actual rating:3.0
# userId:67, movieId:9415, pred rating:3.2813448905944824, actual rating:4.5
# userId:413, movieId:4159, pred rating:4.071488380432129, actual rating:4.5
# userId:331, movieId:963, pred rating:3.7199759483337402, actual rating:5.0
# userId:121, movieId:2544, pred rating:4.620436668395996, actual rating:4.0
# userId:353, movieId:5719, pred rating:3.934492349624634, actual rating:4.0
# userId:510, movieId:8045, pred rating:4.380130290985107, actual rating:4.0
# userId:124, movieId:2144, pred rating:3.859652280807495, actual rating:5.0
# userId:297, movieId:6164, pred rating:1.9213016033172607, actual rating:2.5
# userId:231, movieId:1544, pred rating:3.225066661834717, actual rating:2.5
# userId:3, movieId:890, pred rating:3.423820972442627, actual rating:5.0
# userId:380, movieId:6320, pred rating:3.4369266033172607, actual rating:3.5
# userId:194, movieId:835, pred rating:3.773531198501587, actual rating:3.0
# userId:473, movieId:1, pred rating:3.174837827682495, actual rating:3.0
# userId:413, movieId:6209, pred rating:3.966644287109375, actual rating:3.0
# userId:589, movieId:134, pred rating:3.4188952445983887, actual rating:4.0
# userId:333, movieId:5938, pred rating:3.672609329223633, actual rating:4.0
# userId:50, movieId:1951, pred rating:3.5783615112304688, actual rating:3.0
# userId:118, movieId:4791, pred rating:4.765250205993652, actual rating:5.0
# userId:308, movieId:257, pred rating:3.938683032989502, actual rating:3.5
# userId:186, movieId:6223, pred rating:3.7844104766845703, actual rating:4.0
# userId:67, movieId:2822, pred rating:3.584559679031372, actual rating:3.0
# userId:473, movieId:5095, pred rating:2.994133949279785, actual rating:3.0
# userId:447, movieId:7723, pred rating:3.487863540649414, actual rating:4.0
# userId:241, movieId:508, pred rating:3.9511260986328125, actual rating:3.0
# userId:343, movieId:2994, pred rating:3.7360219955444336, actual rating:2.5
# userId:535, movieId:123, pred rating:3.6310715675354004, actual rating:5.0
# userId:386, movieId:3498, pred rating:3.0389492511749268, actual rating:3.0
# userId:339, movieId:508, pred rating:4.257195472717285, actual rating:5.0
# userId:473, movieId:4636, pred rating:3.945059299468994, actual rating:3.5
# userId:381, movieId:5880, pred rating:3.6587700843811035, actual rating:4.5
# userId:216, movieId:938, pred rating:3.2454605102539062, actual rating:2.0
# userId:317, movieId:7356, pred rating:3.7030534744262695, actual rating:4.0
# userId:158, movieId:9256, pred rating:2.9025826454162598, actual rating:4.5
# userId:475, movieId:511, pred rating:3.433666944503784, actual rating:4.0
# userId:5, movieId:316, pred rating:2.681513547897339, actual rating:3.0
# userId:435, movieId:32, pred rating:3.6429972648620605, actual rating:5.0
# userId:605, movieId:1835, pred rating:3.3804445266723633, actual rating:4.0
# userId:131, movieId:4783, pred rating:3.2665646076202393, actual rating:4.0
# userId:589, movieId:1629, pred rating:3.0444211959838867, actual rating:3.5
# userId:488, movieId:1622, pred rating:3.1762032508850098, actual rating:3.0
# userId:159, movieId:991, pred rating:2.509302854537964, actual rating:3.0
# userId:273, movieId:5929, pred rating:3.7603509426116943, actual rating:4.5
# userId:280, movieId:5156, pred rating:4.054892063140869, actual rating:4.0
# userId:164, movieId:2441, pred rating:3.136963367462158, actual rating:4.0
# userId:176, movieId:6338, pred rating:3.0083417892456055, actual rating:4.0
# userId:609, movieId:8416, pred rating:3.57140851020813, actual rating:3.5
# userId:220, movieId:901, pred rating:4.316449165344238, actual rating:5.0
# userId:18, movieId:2013, pred rating:2.6973886489868164, actual rating:3.0
# userId:139, movieId:940, pred rating:3.8124561309814453, actual rating:3.0
# userId:124, movieId:249, pred rating:3.6038355827331543, actual rating:5.0
# userId:190, movieId:275, pred rating:3.674663543701172, actual rating:1.0
# userId:273, movieId:2284, pred rating:3.402966022491455, actual rating:3.5
# userId:473, movieId:3553, pred rating:3.995699882507324, actual rating:2.0
# userId:61, movieId:6469, pred rating:3.074815511703491, actual rating:1.0
# userId:541, movieId:1242, pred rating:3.88777494430542, actual rating:4.5
# userId:67, movieId:4791, pred rating:3.5238075256347656, actual rating:4.5
# userId:437, movieId:2713, pred rating:2.7958974838256836, actual rating:2.5
# userId:306, movieId:1403, pred rating:2.859797716140747, actual rating:3.0
# userId:115, movieId:507, pred rating:3.417144536972046, actual rating:4.0
# userId:304, movieId:7449, pred rating:4.212109565734863, actual rating:4.0
# userId:603, movieId:322, pred rating:4.018511772155762, actual rating:4.0
# userId:81, movieId:1153, pred rating:2.9825854301452637, actual rating:3.5
# userId:559, movieId:7627, pred rating:3.1631293296813965, actual rating:4.5
# userId:297, movieId:7052, pred rating:2.071877956390381, actual rating:0.5
# userId:90, movieId:1819, pred rating:4.110912322998047, actual rating:3.5
# userId:413, movieId:6057, pred rating:3.3575167655944824, actual rating:4.0
# userId:248, movieId:8035, pred rating:4.044501781463623, actual rating:4.5
# userId:487, movieId:3189, pred rating:4.151491165161133, actual rating:5.0
# userId:63, movieId:867, pred rating:4.573404312133789, actual rating:4.0
# userId:364, movieId:7378, pred rating:3.472836971282959, actual rating:2.5
# userId:589, movieId:224, pred rating:3.600264549255371, actual rating:5.0
# userId:355, movieId:6755, pred rating:4.251389026641846, actual rating:3.5
# userId:380, movieId:1477, pred rating:3.7679057121276855, actual rating:3.0
# userId:31, movieId:485, pred rating:4.244755268096924, actual rating:3.0
# userId:413, movieId:3623, pred rating:3.98968505859375, actual rating:5.0
# userId:447, movieId:8114, pred rating:2.8845713138580322, actual rating:1.0
# userId:110, movieId:8219, pred rating:3.5218334197998047, actual rating:2.5
# userId:223, movieId:2557, pred rating:3.831681966781616, actual rating:2.0
# userId:585, movieId:6522, pred rating:3.4747369289398193, actual rating:4.5
# userId:225, movieId:2746, pred rating:3.1014881134033203, actual rating:3.5
# userId:237, movieId:3164, pred rating:1.8730130195617676, actual rating:3.0
# userId:524, movieId:2855, pred rating:2.5742990970611572, actual rating:3.0
# userId:418, movieId:913, pred rating:3.796046257019043, actual rating:4.0
# userId:63, movieId:4221, pred rating:3.7702479362487793, actual rating:0.5
# userId:386, movieId:483, pred rating:3.4300856590270996, actual rating:3.5
# userId:293, movieId:1061, pred rating:2.447859764099121, actual rating:1.0
# userId:3, movieId:41, pred rating:2.950481414794922, actual rating:3.0
# userId:609, movieId:6512, pred rating:3.873880624771118, actual rating:4.0
# userId:473, movieId:2928, pred rating:3.3444578647613525, actual rating:4.0
# userId:452, movieId:1622, pred rating:3.9882917404174805, actual rating:4.0
# userId:412, movieId:7987, pred rating:4.323393821716309, actual rating:5.0
# userId:437, movieId:4070, pred rating:3.5897421836853027, actual rating:4.0
# userId:233, movieId:546, pred rating:3.86586332321167, actual rating:4.0
# userId:273, movieId:1474, pred rating:3.585712432861328, actual rating:3.0
# userId:17, movieId:4842, pred rating:3.855783700942993, actual rating:4.5
# userId:563, movieId:7088, pred rating:3.670681953430176, actual rating:4.5
# userId:98, movieId:378, pred rating:3.892289638519287, actual rating:3.0
# userId:392, movieId:602, pred rating:3.7368083000183105, actual rating:5.0
# userId:146, movieId:274, pred rating:2.782331705093384, actual rating:2.0
# userId:578, movieId:1345, pred rating:3.101851463317871, actual rating:3.0
# userId:413, movieId:9329, pred rating:3.430935859680176, actual rating:3.5
# userId:598, movieId:403, pred rating:2.669872999191284, actual rating:2.0
# userId:356, movieId:5865, pred rating:3.2326972484588623, actual rating:5.0
# userId:551, movieId:897, pred rating:4.012002944946289, actual rating:5.0
# userId:99, movieId:508, pred rating:4.480800628662109, actual rating:4.0
# userId:482, movieId:2454, pred rating:3.4838240146636963, actual rating:2.5
# userId:421, movieId:3119, pred rating:2.7513933181762695, actual rating:4.0
# userId:366, movieId:2489, pred rating:4.082557678222656, actual rating:1.0
# userId:67, movieId:6399, pred rating:2.6125991344451904, actual rating:3.5
# userId:18, movieId:2723, pred rating:2.86112380027771, actual rating:3.0
# userId:289, movieId:930, pred rating:4.027317047119141, actual rating:4.0
# userId:579, movieId:4786, pred rating:3.1733288764953613, actual rating:4.0
# userId:569, movieId:2832, pred rating:3.4020447731018066, actual rating:4.0
# userId:67, movieId:1082, pred rating:2.8430607318878174, actual rating:2.5
# userId:134, movieId:418, pred rating:3.705928325653076, actual rating:5.0
# userId:143, movieId:16, pred rating:3.8547744750976562, actual rating:4.0
# userId:500, movieId:576, pred rating:2.8495981693267822, actual rating:4.0
# userId:508, movieId:6629, pred rating:3.692483425140381, actual rating:3.0
# userId:317, movieId:4131, pred rating:4.461339950561523, actual rating:3.5
# userId:176, movieId:7620, pred rating:3.201597213745117, actual rating:3.0
# userId:329, movieId:2192, pred rating:3.4970011711120605, actual rating:4.0
# userId:201, movieId:2290, pred rating:4.021488189697266, actual rating:4.0
# userId:331, movieId:7675, pred rating:3.868195056915283, actual rating:2.5
# userId:131, movieId:2013, pred rating:2.7009642124176025, actual rating:3.5
# userId:475, movieId:10, pred rating:3.3264975547790527, actual rating:3.0
# userId:62, movieId:6513, pred rating:3.5992960929870605, actual rating:4.0
# userId:361, movieId:375, pred rating:4.2811665534973145, actual rating:4.0
# userId:67, movieId:6153, pred rating:3.353893756866455, actual rating:4.0
# userId:576, movieId:961, pred rating:3.390611171722412, actual rating:4.0
# userId:181, movieId:3229, pred rating:3.229320526123047, actual rating:3.0
# userId:90, movieId:4775, pred rating:3.408431053161621, actual rating:4.0
# userId:273, movieId:136, pred rating:3.4538538455963135, actual rating:3.5
# userId:473, movieId:6238, pred rating:2.8826777935028076, actual rating:3.5
# userId:598, movieId:733, pred rating:2.926642894744873, actual rating:3.5
# userId:287, movieId:2076, pred rating:3.7488462924957275, actual rating:4.0
# userId:598, movieId:9264, pred rating:2.631584644317627, actual rating:1.5
# userId:504, movieId:780, pred rating:3.881471633911133, actual rating:4.0
# userId:478, movieId:3835, pred rating:4.129194259643555, actual rating:3.0
# userId:533, movieId:32, pred rating:4.259650707244873, actual rating:4.0
# userId:304, movieId:7958, pred rating:3.7915871143341064, actual rating:4.0
# userId:595, movieId:8844, pred rating:3.3797426223754883, actual rating:4.0
# userId:600, movieId:1397, pred rating:3.556730031967163, actual rating:4.0
# userId:598, movieId:1478, pred rating:2.6241416931152344, actual rating:3.5
# userId:138, movieId:4328, pred rating:2.4626970291137695, actual rating:2.5
# userId:546, movieId:997, pred rating:3.7143502235412598, actual rating:5.0
# userId:503, movieId:257, pred rating:4.299134731292725, actual rating:4.0
# userId:414, movieId:1271, pred rating:3.3172125816345215, actual rating:4.0
# userId:550, movieId:1397, pred rating:3.4927854537963867, actual rating:4.0
# userId:605, movieId:901, pred rating:3.974524974822998, actual rating:3.5
# userId:37, movieId:512, pred rating:2.92970871925354, actual rating:4.0
# userId:524, movieId:4360, pred rating:3.6343154907226562, actual rating:4.0
# userId:473, movieId:1640, pred rating:3.414523124694824, actual rating:3.5
# userId:599, movieId:1112, pred rating:3.118652820587158, actual rating:4.0
# userId:73, movieId:1484, pred rating:4.156538963317871, actual rating:4.0
# userId:108, movieId:145, pred rating:2.453240156173706, actual rating:2.0
# userId:245, movieId:1497, pred rating:3.9844717979431152, actual rating:3.0
# userId:367, movieId:1066, pred rating:3.0632643699645996, actual rating:5.0
# userId:301, movieId:520, pred rating:4.267244815826416, actual rating:5.0
# userId:572, movieId:8141, pred rating:4.168300628662109, actual rating:5.0
# userId:326, movieId:2043, pred rating:4.029083251953125, actual rating:2.0
# userId:287, movieId:1502, pred rating:3.8648276329040527, actual rating:3.5
# userId:476, movieId:7289, pred rating:3.481222629547119, actual rating:4.5
# userId:293, movieId:43, pred rating:2.740795373916626, actual rating:2.0
# userId:598, movieId:778, pred rating:2.248910665512085, actual rating:2.5
# userId:221, movieId:6746, pred rating:2.4281203746795654, actual rating:2.0
# userId:447, movieId:3956, pred rating:3.2419114112854004, actual rating:2.0
# userId:247, movieId:1938, pred rating:3.882033586502075, actual rating:4.0
# userId:442, movieId:895, pred rating:4.446372032165527, actual rating:4.0
# userId:317, movieId:6848, pred rating:3.8198294639587402, actual rating:3.5
# userId:311, movieId:627, pred rating:3.468761444091797, actual rating:4.0
# userId:609, movieId:5856, pred rating:3.7125864028930664, actual rating:3.5
# userId:155, movieId:937, pred rating:3.8778417110443115, actual rating:4.0
# userId:452, movieId:197, pred rating:3.4240922927856445, actual rating:5.0
# userId:436, movieId:117, pred rating:3.714005708694458, actual rating:4.0
# userId:267, movieId:1434, pred rating:3.8694684505462646, actual rating:2.0
# userId:62, movieId:5856, pred rating:3.388000726699829, actual rating:3.5
# userId:559, movieId:8287, pred rating:3.7826247215270996, actual rating:4.0
# userId:482, movieId:1052, pred rating:3.671102285385132, actual rating:4.0
# userId:479, movieId:307, pred rating:3.3445847034454346, actual rating:3.0
# userId:407, movieId:7750, pred rating:4.335585594177246, actual rating:4.0
# userId:413, movieId:2035, pred rating:3.5812292098999023, actual rating:4.0
# userId:447, movieId:4065, pred rating:2.5841267108917236, actual rating:2.0
# userId:576, movieId:1056, pred rating:3.535161018371582, actual rating:3.0
# userId:351, movieId:5999, pred rating:4.534562110900879, actual rating:3.5
# userId:199, movieId:2994, pred rating:3.6912436485290527, actual rating:4.0
# userId:607, movieId:1176, pred rating:3.3696324825286865, actual rating:4.0
# userId:72, movieId:4354, pred rating:3.890418767929077, actual rating:4.5
# userId:19, movieId:3726, pred rating:2.691194534301758, actual rating:2.0
# userId:287, movieId:1307, pred rating:3.1845717430114746, actual rating:2.0
# userId:447, movieId:7438, pred rating:3.239410400390625, actual rating:3.5
# userId:194, movieId:828, pred rating:3.6905338764190674, actual rating:5.0
# userId:83, movieId:852, pred rating:3.339346408843994, actual rating:5.0
# userId:447, movieId:2036, pred rating:3.0747900009155273, actual rating:2.0
# userId:439, movieId:888, pred rating:3.640951633453369, actual rating:3.0
# userId:304, movieId:8260, pred rating:3.772278308868408, actual rating:4.0
# userId:317, movieId:1540, pred rating:4.197310447692871, actual rating:4.0
# userId:482, movieId:7378, pred rating:4.111201286315918, actual rating:3.0
# userId:559, movieId:2998, pred rating:3.0596187114715576, actual rating:3.5
# userId:273, movieId:2028, pred rating:2.5665671825408936, actual rating:2.5
# userId:371, movieId:811, pred rating:3.3553404808044434, actual rating:3.0
# userId:376, movieId:7604, pred rating:3.875246524810791, actual rating:4.0
# userId:218, movieId:302, pred rating:2.5683605670928955, actual rating:4.0
# userId:598, movieId:2443, pred rating:2.541229486465454, actual rating:2.5
# userId:447, movieId:8944, pred rating:3.138941764831543, actual rating:1.5
# userId:297, movieId:7818, pred rating:1.435754418373108, actual rating:1.5
# userId:220, movieId:659, pred rating:4.434847831726074, actual rating:4.5
# userId:163, movieId:3275, pred rating:3.6764097213745117, actual rating:5.0
# userId:545, movieId:1452, pred rating:2.496804714202881, actual rating:4.0
# userId:274, movieId:1230, pred rating:4.132379531860352, actual rating:3.0
# userId:609, movieId:8240, pred rating:3.7977547645568848, actual rating:3.5
# userId:479, movieId:4851, pred rating:3.2732489109039307, actual rating:3.0
# userId:181, movieId:520, pred rating:4.060850620269775, actual rating:5.0
# userId:445, movieId:326, pred rating:3.384434461593628, actual rating:3.0
# userId:341, movieId:2183, pred rating:3.08078670501709, actual rating:1.0
# userId:558, movieId:431, pred rating:3.4233264923095703, actual rating:3.0
# userId:589, movieId:2565, pred rating:3.576761245727539, actual rating:4.0
# userId:525, movieId:257, pred rating:4.605215072631836, actual rating:4.0
# userId:413, movieId:8528, pred rating:4.085272789001465, actual rating:3.5
# userId:602, movieId:1565, pred rating:3.182455539703369, actual rating:4.0
# userId:400, movieId:7195, pred rating:3.3745598793029785, actual rating:3.0
# userId:531, movieId:461, pred rating:3.811767101287842, actual rating:5.0
# userId:473, movieId:3260, pred rating:3.0430662631988525, actual rating:3.5
# userId:534, movieId:2019, pred rating:3.270556926727295, actual rating:5.0
# userId:218, movieId:546, pred rating:3.095332145690918, actual rating:4.5
# userId:356, movieId:1082, pred rating:3.2027804851531982, actual rating:3.5
# userId:609, movieId:6436, pred rating:3.2445905208587646, actual rating:4.0
# userId:482, movieId:6737, pred rating:2.799534320831299, actual rating:3.5
# userId:5, movieId:494, pred rating:3.228990077972412, actual rating:4.0
# userId:607, movieId:1730, pred rating:3.177424907684326, actual rating:2.5
# userId:229, movieId:337, pred rating:2.145848274230957, actual rating:3.0
# userId:67, movieId:6277, pred rating:3.300182819366455, actual rating:4.5
# userId:97, movieId:8008, pred rating:3.4973607063293457, actual rating:4.0
# userId:158, movieId:7505, pred rating:2.436284303665161, actual rating:3.0
# userId:516, movieId:1, pred rating:2.045665740966797, actual rating:3.0
# userId:123, movieId:224, pred rating:4.033212184906006, actual rating:4.0
# userId:524, movieId:8998, pred rating:3.010554790496826, actual rating:4.5
# userId:90, movieId:2696, pred rating:2.852910041809082, actual rating:2.0
# userId:225, movieId:3885, pred rating:3.876919746398926, actual rating:4.0
# userId:596, movieId:934, pred rating:4.067143440246582, actual rating:5.0
# userId:338, movieId:7694, pred rating:3.1157519817352295, actual rating:4.5
# userId:481, movieId:1532, pred rating:3.299437999725342, actual rating:0.5
# userId:90, movieId:599, pred rating:3.8445019721984863, actual rating:3.5
# userId:178, movieId:508, pred rating:4.03866720199585, actual rating:4.0
# userId:479, movieId:5929, pred rating:3.4920880794525146, actual rating:4.0
# userId:386, movieId:2411, pred rating:3.224132537841797, actual rating:3.5
# userId:181, movieId:2505, pred rating:2.967249631881714, actual rating:4.0
# userId:595, movieId:989, pred rating:4.363868713378906, actual rating:3.5
# userId:524, movieId:7629, pred rating:3.7071239948272705, actual rating:4.0
# userId:281, movieId:3006, pred rating:4.157015800476074, actual rating:4.0
# userId:417, movieId:4574, pred rating:3.6011993885040283, actual rating:5.0
# userId:572, movieId:615, pred rating:4.172934532165527, actual rating:5.0
# userId:41, movieId:1214, pred rating:3.6411616802215576, actual rating:4.0
# userId:598, movieId:1923, pred rating:2.1227028369903564, actual rating:1.0
# userId:508, movieId:3241, pred rating:2.40545392036438, actual rating:2.5
# userId:559, movieId:9152, pred rating:3.206303596496582, actual rating:4.0
# userId:168, movieId:2044, pred rating:3.5658490657806396, actual rating:4.5
# userId:17, movieId:334, pred rating:3.3019964694976807, actual rating:2.5
# userId:155, movieId:2464, pred rating:3.185044288635254, actual rating:2.0
# userId:287, movieId:2059, pred rating:3.167804479598999, actual rating:4.0
# userId:447, movieId:2222, pred rating:2.7999825477600098, actual rating:1.0
# userId:438, movieId:4131, pred rating:4.068022727966309, actual rating:4.0
# userId:7, movieId:20, pred rating:4.193562984466553, actual rating:4.0
# userId:180, movieId:505, pred rating:2.9601855278015137, actual rating:5.0
# userId:27, movieId:800, pred rating:2.851156711578369, actual rating:3.5
# userId:46, movieId:1819, pred rating:3.5358285903930664, actual rating:3.5
# userId:220, movieId:3297, pred rating:4.014070510864258, actual rating:4.5
# userId:219, movieId:793, pred rating:3.7750065326690674, actual rating:5.0
# userId:306, movieId:404, pred rating:2.1249773502349854, actual rating:1.0
# userId:413, movieId:4098, pred rating:3.5962207317352295, actual rating:4.0
# userId:20, movieId:1390, pred rating:3.1958420276641846, actual rating:2.0
# userId:248, movieId:1116, pred rating:3.3207125663757324, actual rating:3.5
# userId:533, movieId:8187, pred rating:3.581329345703125, actual rating:3.5
# userId:108, movieId:385, pred rating:3.2677688598632812, actual rating:3.0
# userId:589, movieId:1733, pred rating:3.977405309677124, actual rating:3.0
# userId:17, movieId:6479, pred rating:3.3780813217163086, actual rating:2.5
# userId:413, movieId:1020, pred rating:4.038265705108643, actual rating:3.0
# userId:413, movieId:215, pred rating:3.2389509677886963, actual rating:3.5
# userId:413, movieId:1643, pred rating:4.105847358703613, actual rating:5.0
# userId:427, movieId:190, pred rating:3.8078880310058594, actual rating:4.0
# userId:473, movieId:6069, pred rating:3.636230707168579, actual rating:3.5
# userId:159, movieId:324, pred rating:2.414198637008667, actual rating:1.0
# userId:185, movieId:2036, pred rating:3.8740832805633545, actual rating:4.0
# userId:519, movieId:1793, pred rating:4.003529071807861, actual rating:3.5
# userId:159, movieId:706, pred rating:3.0969576835632324, actual rating:5.0
# userId:584, movieId:372, pred rating:4.296921253204346, actual rating:5.0
# userId:605, movieId:1473, pred rating:3.256920576095581, actual rating:1.5
# userId:185, movieId:276, pred rating:3.8096446990966797, actual rating:5.0
# userId:94, movieId:945, pred rating:4.3392720222473145, actual rating:4.5
# userId:58, movieId:740, pred rating:3.9516990184783936, actual rating:5.0
# userId:447, movieId:3560, pred rating:3.534919500350952, actual rating:3.0
# userId:386, movieId:1080, pred rating:2.9179575443267822, actual rating:2.5
# userId:27, movieId:4699, pred rating:3.153980255126953, actual rating:2.5
# userId:593, movieId:1052, pred rating:4.177423477172852, actual rating:4.5
# userId:28, movieId:1000, pred rating:4.181160926818848, actual rating:4.5
# userId:571, movieId:914, pred rating:4.110471725463867, actual rating:4.0
# ...
# userId:312, movieId:2804, pred rating:2.9684572219848633, actual rating:3.0
# userId:65, movieId:2338, pred rating:3.914825677871704, actual rating:4.5
# userId:104, movieId:2803, pred rating:3.5699496269226074, actual rating:3.5
# userId:158, movieId:6621, pred rating:3.529749631881714, actual rating:5.0
# userId:83, movieId:728, pred rating:3.5542845726013184, actual rating:4.0
# userId:262, movieId:2035, pred rating:3.413938522338867, actual rating:1.0
# userId:231, movieId:5988, pred rating:3.7816574573516846, actual rating:3.0
# userId:105, movieId:7197, pred rating:4.641583442687988, actual rating:5.0
# userId:297, movieId:3572, pred rating:2.142439126968384, actual rating:2.5
# userId:335, movieId:1062, pred rating:4.255356788635254, actual rating:2.5
# userId:155, movieId:920, pred rating:3.93200421333313, actual rating:3.0
# userId:228, movieId:398, pred rating:3.174668788909912, actual rating:5.0
# userId:18, movieId:1116, pred rating:2.240987539291382, actual rating:3.0
# userId:306, movieId:6604, pred rating:2.5118720531463623, actual rating:3.0
# userId:598, movieId:7062, pred rating:2.53371000289917, actual rating:2.5
# userId:589, movieId:991, pred rating:3.0729713439941406, actual rating:4.0
# userId:603, movieId:217, pred rating:3.21262264251709, actual rating:5.0
# userId:360, movieId:197, pred rating:2.3003101348876953, actual rating:3.5
# userId:72, movieId:4926, pred rating:4.138728141784668, actual rating:4.0
# userId:67, movieId:1242, pred rating:3.411393642425537, actual rating:2.5
# userId:311, movieId:1304, pred rating:3.7114810943603516, actual rating:4.0
# userId:437, movieId:4011, pred rating:3.340054512023926, actual rating:1.0
# userId:114, movieId:1061, pred rating:3.412083864212036, actual rating:5.0
# userId:605, movieId:2999, pred rating:3.800372838973999, actual rating:4.0
# userId:452, movieId:3002, pred rating:4.0597076416015625, actual rating:5.0
# userId:139, movieId:823, pred rating:4.023184776306152, actual rating:4.0
# userId:322, movieId:8565, pred rating:2.724858522415161, actual rating:4.0
# userId:225, movieId:1153, pred rating:3.12069034576416, actual rating:4.0
# userId:479, movieId:1297, pred rating:3.4346845149993896, actual rating:3.5
# userId:318, movieId:8972, pred rating:4.16558313369751, actual rating:4.5
# userId:390, movieId:989, pred rating:4.232524394989014, actual rating:4.0
# userId:40, movieId:8972, pred rating:3.1572072505950928, actual rating:4.0
# userId:289, movieId:2085, pred rating:3.9254491329193115, actual rating:3.0
# userId:473, movieId:700, pred rating:3.492852210998535, actual rating:3.5
# userId:297, movieId:2978, pred rating:2.36885142326355, actual rating:1.0
# userId:433, movieId:6310, pred rating:3.0087263584136963, actual rating:4.0
# userId:219, movieId:418, pred rating:3.8022172451019287, actual rating:5.0
# userId:413, movieId:311, pred rating:3.9501447677612305, actual rating:5.0
# userId:176, movieId:2138, pred rating:2.77311110496521, actual rating:3.0
# userId:599, movieId:97, pred rating:3.5196049213409424, actual rating:2.0
# userId:368, movieId:3565, pred rating:3.051417350769043, actual rating:4.0
# userId:194, movieId:2380, pred rating:3.616769313812256, actual rating:3.0
# userId:598, movieId:9443, pred rating:3.123584032058716, actual rating:3.0
# userId:202, movieId:1566, pred rating:3.5360429286956787, actual rating:3.0
# userId:168, movieId:291, pred rating:4.16357421875, actual rating:4.5
# userId:221, movieId:3147, pred rating:3.0160298347473145, actual rating:4.5
# userId:605, movieId:691, pred rating:3.7802860736846924, actual rating:4.0
# userId:317, movieId:5895, pred rating:3.525129795074463, actual rating:3.0
# userId:248, movieId:1370, pred rating:3.437509536743164, actual rating:3.0
# userId:519, movieId:1043, pred rating:4.115153789520264, actual rating:5.0
# userId:311, movieId:461, pred rating:4.062079429626465, actual rating:5.0
# userId:61, movieId:9627, pred rating:3.456225872039795, actual rating:3.5
# userId:262, movieId:4326, pred rating:3.991062641143799, actual rating:3.5
# userId:598, movieId:7325, pred rating:2.3619446754455566, actual rating:2.0
# userId:579, movieId:5879, pred rating:3.0530498027801514, actual rating:5.0
# userId:248, movieId:1885, pred rating:4.12086296081543, actual rating:3.0
# userId:409, movieId:1573, pred rating:3.616086721420288, actual rating:4.0
# userId:447, movieId:454, pred rating:2.7279608249664307, actual rating:2.0
# userId:473, movieId:5072, pred rating:3.60250186920166, actual rating:3.5
# userId:606, movieId:1673, pred rating:2.9620394706726074, actual rating:3.0
# userId:139, movieId:5992, pred rating:3.1098616123199463, actual rating:4.0
# userId:522, movieId:5885, pred rating:3.859632730484009, actual rating:4.5
# userId:104, movieId:6225, pred rating:4.04331636428833, actual rating:3.0
# userId:50, movieId:4070, pred rating:3.4929888248443604, actual rating:5.0
# userId:416, movieId:1223, pred rating:3.8171873092651367, actual rating:4.5
# userId:308, movieId:5124, pred rating:3.6973772048950195, actual rating:4.0
# userId:413, movieId:3371, pred rating:3.5628159046173096, actual rating:3.0
# userId:361, movieId:540, pred rating:3.868391513824463, actual rating:1.5
# userId:508, movieId:4342, pred rating:3.6092710494995117, actual rating:3.5
# userId:67, movieId:907, pred rating:3.908752918243408, actual rating:3.0
# userId:118, movieId:7591, pred rating:4.30089807510376, actual rating:3.5
# userId:442, movieId:6294, pred rating:3.7939000129699707, actual rating:4.0
# userId:498, movieId:1741, pred rating:3.4600586891174316, actual rating:4.0
# userId:368, movieId:1515, pred rating:3.127798318862915, actual rating:3.0
# userId:67, movieId:6377, pred rating:3.2511322498321533, actual rating:3.5
# userId:287, movieId:131, pred rating:2.5477700233459473, actual rating:2.0
# userId:41, movieId:3355, pred rating:3.1212809085845947, actual rating:5.0
# userId:114, movieId:508, pred rating:4.058614730834961, actual rating:3.0
# userId:176, movieId:4696, pred rating:3.2966582775115967, actual rating:2.5
# userId:306, movieId:6173, pred rating:1.8326117992401123, actual rating:0.5
# userId:596, movieId:1283, pred rating:4.633819103240967, actual rating:5.0
# userId:273, movieId:5648, pred rating:3.6979196071624756, actual rating:3.0
# userId:595, movieId:3979, pred rating:3.7289724349975586, actual rating:4.5
# userId:287, movieId:474, pred rating:3.6019930839538574, actual rating:4.0
# userId:488, movieId:3569, pred rating:3.671541213989258, actual rating:3.5
# userId:198, movieId:1085, pred rating:3.6976566314697266, actual rating:4.0
# userId:106, movieId:133, pred rating:3.282291889190674, actual rating:4.0
# userId:18, movieId:1510, pred rating:2.4332892894744873, actual rating:2.0
# userId:605, movieId:5696, pred rating:3.2867774963378906, actual rating:2.5
# userId:291, movieId:8528, pred rating:3.3559727668762207, actual rating:4.0
# userId:364, movieId:7825, pred rating:3.1614367961883545, actual rating:2.5
# userId:312, movieId:2567, pred rating:2.9318196773529053, actual rating:1.0
# userId:119, movieId:609, pred rating:3.2890443801879883, actual rating:3.0
# userId:452, movieId:2832, pred rating:4.22376823425293, actual rating:3.0
# userId:478, movieId:2898, pred rating:3.5816650390625, actual rating:1.0
# userId:609, movieId:8277, pred rating:4.076128005981445, actual rating:4.0
# userId:473, movieId:3925, pred rating:3.4286739826202393, actual rating:4.0
# userId:157, movieId:831, pred rating:3.6139979362487793, actual rating:3.0
# userId:272, movieId:512, pred rating:3.8194046020507812, actual rating:5.0
# userId:427, movieId:8, pred rating:2.370687961578369, actual rating:2.0
# userId:35, movieId:1687, pred rating:1.9186809062957764, actual rating:3.0
# userId:413, movieId:4930, pred rating:3.7284183502197266, actual rating:3.0
# userId:431, movieId:7505, pred rating:3.2058515548706055, actual rating:4.0
# userId:577, movieId:6670, pred rating:4.126822471618652, actual rating:4.5
# userId:524, movieId:1601, pred rating:3.2079708576202393, actual rating:4.0
# userId:579, movieId:2392, pred rating:2.9938573837280273, actual rating:4.0
# userId:88, movieId:4498, pred rating:4.7757158279418945, actual rating:3.5
# userId:72, movieId:5922, pred rating:3.6668152809143066, actual rating:4.5
# userId:461, movieId:929, pred rating:3.6082963943481445, actual rating:4.5
# userId:479, movieId:2441, pred rating:3.1217398643493652, actual rating:3.0
# userId:218, movieId:2218, pred rating:3.075930118560791, actual rating:3.0
# userId:589, movieId:2439, pred rating:2.937072992324829, actual rating:3.0
# userId:67, movieId:3910, pred rating:2.97863507270813, actual rating:3.5
# userId:83, movieId:978, pred rating:3.732834577560425, actual rating:5.0
# userId:317, movieId:613, pred rating:4.258313179016113, actual rating:4.0
# userId:602, movieId:2664, pred rating:3.131666660308838, actual rating:4.0
# userId:542, movieId:7784, pred rating:4.201961994171143, actual rating:5.0
# userId:109, movieId:2077, pred rating:3.995455265045166, actual rating:3.0
# userId:476, movieId:908, pred rating:4.11020565032959, actual rating:5.0
# userId:520, movieId:649, pred rating:3.474134683609009, actual rating:4.0
# userId:159, movieId:4320, pred rating:2.2748594284057617, actual rating:1.0
# userId:53, movieId:512, pred rating:2.7099194526672363, actual rating:3.0
# userId:287, movieId:751, pred rating:3.3691318035125732, actual rating:3.0
# userId:368, movieId:2194, pred rating:3.3049097061157227, actual rating:3.5
# userId:447, movieId:476, pred rating:3.5093131065368652, actual rating:4.0
# userId:331, movieId:2832, pred rating:3.7572765350341797, actual rating:3.5
# userId:104, movieId:9519, pred rating:3.3899359703063965, actual rating:5.0
# userId:305, movieId:7911, pred rating:2.525773525238037, actual rating:3.0
# userId:218, movieId:5380, pred rating:2.876316547393799, actual rating:3.0
# userId:201, movieId:890, pred rating:3.803206443786621, actual rating:4.0
# userId:278, movieId:6314, pred rating:3.8061418533325195, actual rating:4.5
# userId:355, movieId:92, pred rating:3.641731023788452, actual rating:3.0
# userId:561, movieId:4068, pred rating:3.9581539630889893, actual rating:5.0
# userId:273, movieId:6497, pred rating:3.7302603721618652, actual rating:3.5
# userId:353, movieId:3814, pred rating:3.38043212890625, actual rating:4.0
# userId:51, movieId:4607, pred rating:4.557525634765625, actual rating:4.5
# userId:216, movieId:816, pred rating:2.6521682739257812, actual rating:2.0
# userId:607, movieId:645, pred rating:3.078866481781006, actual rating:3.5
# userId:199, movieId:3006, pred rating:3.960256576538086, actual rating:4.0
# userId:50, movieId:4402, pred rating:4.140460968017578, actual rating:5.0
# userId:155, movieId:760, pred rating:3.4372828006744385, actual rating:4.0
# userId:473, movieId:1170, pred rating:3.057616949081421, actual rating:3.5
# userId:473, movieId:6345, pred rating:3.0197858810424805, actual rating:3.0
# userId:74, movieId:897, pred rating:4.0440874099731445, actual rating:4.5
# userId:560, movieId:1729, pred rating:3.883824586868286, actual rating:3.5
# userId:433, movieId:615, pred rating:2.8101260662078857, actual rating:2.5
# userId:485, movieId:507, pred rating:4.337742805480957, actual rating:5.0
# userId:429, movieId:6780, pred rating:3.5869662761688232, actual rating:4.5
# userId:605, movieId:3592, pred rating:3.478793144226074, actual rating:4.0
# userId:229, movieId:5922, pred rating:2.477792739868164, actual rating:4.5
# userId:26, movieId:945, pred rating:3.4848272800445557, actual rating:2.0
# userId:479, movieId:2509, pred rating:3.352198600769043, actual rating:4.0
# userId:341, movieId:2044, pred rating:2.5857107639312744, actual rating:3.0
# userId:356, movieId:461, pred rating:3.9447104930877686, actual rating:5.0
# userId:598, movieId:6569, pred rating:2.7758121490478516, actual rating:3.0
# userId:168, movieId:3645, pred rating:4.388716697692871, actual rating:4.5
# userId:407, movieId:9415, pred rating:3.9695658683776855, actual rating:4.0
# userId:41, movieId:377, pred rating:3.3012423515319824, actual rating:4.0
# userId:598, movieId:2760, pred rating:2.500825881958008, actual rating:3.5
# userId:431, movieId:4786, pred rating:3.611889600753784, actual rating:4.5
# userId:609, movieId:3226, pred rating:3.060431480407715, actual rating:2.0
# userId:297, movieId:7289, pred rating:2.4982266426086426, actual rating:2.0
# userId:303, movieId:1480, pred rating:3.5879034996032715, actual rating:4.0
# userId:595, movieId:287, pred rating:3.8359084129333496, actual rating:3.0
# userId:216, movieId:1583, pred rating:2.0987491607666016, actual rating:2.0
# userId:262, movieId:599, pred rating:3.6996850967407227, actual rating:5.0
# userId:67, movieId:6758, pred rating:2.636380910873413, actual rating:3.5
# userId:253, movieId:4256, pred rating:3.6297478675842285, actual rating:1.5
# userId:572, movieId:3189, pred rating:4.496646881103516, actual rating:4.5
# userId:408, movieId:2029, pred rating:3.582841396331787, actual rating:3.0
# userId:110, movieId:8926, pred rating:3.4028382301330566, actual rating:2.0
# userId:71, movieId:46, pred rating:4.017636775970459, actual rating:4.5
# userId:185, movieId:546, pred rating:4.260873317718506, actual rating:4.0
# userId:248, movieId:6820, pred rating:3.3733468055725098, actual rating:1.0
# userId:139, movieId:3393, pred rating:3.398287534713745, actual rating:4.0
# userId:293, movieId:1711, pred rating:2.759756326675415, actual rating:5.0
# userId:183, movieId:7307, pred rating:3.1183669567108154, actual rating:3.0
# userId:273, movieId:1205, pred rating:3.390103578567505, actual rating:3.0
# userId:413, movieId:3765, pred rating:3.485994338989258, actual rating:5.0
# userId:274, movieId:2326, pred rating:4.470197677612305, actual rating:5.0
# userId:604, movieId:7288, pred rating:2.184283971786499, actual rating:2.5
# userId:338, movieId:4054, pred rating:3.653240442276001, actual rating:4.0
# userId:427, movieId:62, pred rating:3.2344489097595215, actual rating:3.0
# userId:384, movieId:952, pred rating:3.8882594108581543, actual rating:4.0
# userId:118, movieId:5245, pred rating:4.096732139587402, actual rating:3.5
# userId:437, movieId:4930, pred rating:3.7877707481384277, actual rating:3.0
# userId:331, movieId:3189, pred rating:3.685702323913574, actual rating:4.5
# userId:27, movieId:2263, pred rating:2.615428924560547, actual rating:2.5
# userId:90, movieId:1627, pred rating:3.461016893386841, actual rating:4.0
# userId:602, movieId:818, pred rating:4.024320602416992, actual rating:4.0
# userId:395, movieId:40, pred rating:2.9681036472320557, actual rating:2.0
# userId:598, movieId:2444, pred rating:2.078456163406372, actual rating:3.0
# userId:356, movieId:6505, pred rating:4.0389862060546875, actual rating:4.5
# userId:218, movieId:6539, pred rating:3.4199700355529785, actual rating:4.5
# userId:416, movieId:249, pred rating:3.850861072540283, actual rating:4.0
# userId:27, movieId:134, pred rating:3.2812936305999756, actual rating:3.0
# userId:602, movieId:1805, pred rating:4.032777309417725, actual rating:2.0
# userId:413, movieId:4238, pred rating:4.314082145690918, actual rating:3.0
# userId:18, movieId:1382, pred rating:2.3399529457092285, actual rating:2.0
# userId:526, movieId:2576, pred rating:3.824604034423828, actual rating:5.0
# userId:545, movieId:2699, pred rating:3.1773154735565186, actual rating:4.0
# userId:15, movieId:4791, pred rating:3.8598930835723877, actual rating:3.5
# userId:437, movieId:4416, pred rating:2.922088861465454, actual rating:3.0
# userId:533, movieId:7741, pred rating:4.2576904296875, actual rating:4.0
# userId:185, movieId:815, pred rating:4.393406391143799, actual rating:5.0
# userId:181, movieId:3431, pred rating:3.405467987060547, actual rating:4.0
# userId:433, movieId:2144, pred rating:3.295165777206421, actual rating:5.0
# userId:609, movieId:6022, pred rating:3.318044900894165, actual rating:2.5
# userId:414, movieId:1153, pred rating:3.3439817428588867, actual rating:3.5
# userId:65, movieId:956, pred rating:4.527634620666504, actual rating:4.0
# userId:83, movieId:1066, pred rating:3.7722766399383545, actual rating:4.0
# userId:381, movieId:9153, pred rating:2.841712713241577, actual rating:2.5
# userId:512, movieId:925, pred rating:3.7510950565338135, actual rating:5.0

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            0        0     4.0   964982703
# 1            0        2     4.0   964981247
# 2            0        5     4.0   964982224
# 3            0       43     5.0   964983815
# 4            0       46     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     609     9416     4.0  1493848402
# 100832     609     9443     5.0  1493850091
# 100833     609     9444     5.0  1494273047
# 100834     609     9445     5.0  1493846352
# 100835     609     9485     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
with torch.no_grad():
    precisions=dict()
    recalls=dict()
    k=100
    threshhold=3.5
    
    for uid,user_ratings in users_dict.items():
        
        user_ratings.sort(key=lambda x:x[0],reverse=True)
        
        n_rel=sum((true_rating>=threshhold) for (_,true_rating) in user_ratings)
        n_rec_k=sum((estimated>=threshhold) for (estimated,_) in user_ratings[:k])
        
        n_rel_and_rec_k=sum((true_rating>=threshhold)and(estimated>=threshhold) for (estimated,true_rating) in user_ratings)
        
        print(f'userId:{uid} n_rel:{n_rel} n_rec_k:{n_rec_k} n_rel_and_rec_k:{n_rel_and_rec_k}')
        
        precisions[uid]=n_rel_and_rec_k/n_rec_k if n_rec_k !=0 else 0
        recalls[uid]=n_rel_and_rec_k/n_rel if n_rel !=0 else 0
# Out:
# userId:371 n_rel:21 n_rec_k:20 n_rel_and_rec_k:12
# userId:368 n_rel:18 n_rec_k:7 n_rel_and_rec_k:3
# userId:524 n_rel:77 n_rec_k:20 n_rel_and_rec_k:20
# userId:199 n_rel:52 n_rec_k:38 n_rel_and_rec_k:36
# userId:67 n_rel:146 n_rec_k:51 n_rel_and_rec_k:31
# userId:605 n_rel:182 n_rec_k:100 n_rel_and_rec_k:88
# userId:545 n_rel:10 n_rec_k:0 n_rel_and_rec_k:0
# userId:602 n_rel:114 n_rec_k:100 n_rel_and_rec_k:78
# userId:482 n_rel:124 n_rec_k:100 n_rel_and_rec_k:87
# userId:338 n_rel:63 n_rec_k:60 n_rel_and_rec_k:50
# userId:56 n_rel:50 n_rec_k:19 n_rel_and_rec_k:16
# userId:284 n_rel:7 n_rec_k:7 n_rel_and_rec_k:6
# userId:461 n_rel:61 n_rec_k:25 n_rel_and_rec_k:18
# userId:152 n_rel:14 n_rec_k:0 n_rel_and_rec_k:0
# userId:609 n_rel:182 n_rec_k:100 n_rel_and_rec_k:146
# userId:151 n_rel:13 n_rec_k:10 n_rel_and_rec_k:10
# userId:488 n_rel:71 n_rec_k:22 n_rel_and_rec_k:18
# userId:599 n_rel:65 n_rec_k:30 n_rel_and_rec_k:18
# userId:433 n_rel:34 n_rec_k:4 n_rel_and_rec_k:4
# userId:483 n_rel:50 n_rec_k:25 n_rel_and_rec_k:17
# userId:473 n_rel:273 n_rec_k:100 n_rel_and_rec_k:135
# userId:216 n_rel:20 n_rec_k:0 n_rel_and_rec_k:0
# userId:540 n_rel:8 n_rec_k:9 n_rel_and_rec_k:7
# userId:570 n_rel:5 n_rec_k:1 n_rel_and_rec_k:1
# userId:88 n_rel:55 n_rec_k:80 n_rel_and_rec_k:46
# userId:607 n_rel:87 n_rec_k:29 n_rel_and_rec_k:21
# userId:62 n_rel:49 n_rec_k:42 n_rel_and_rec_k:33
# userId:413 n_rel:313 n_rec_k:100 n_rel_and_rec_k:204
# userId:377 n_rel:8 n_rec_k:5 n_rel_and_rec_k:5
# userId:273 n_rel:155 n_rec_k:99 n_rel_and_rec_k:76
# userId:595 n_rel:58 n_rec_k:63 n_rel_and_rec_k:48
# userId:474 n_rel:40 n_rec_k:32 n_rel_and_rec_k:32
# userId:72 n_rel:36 n_rec_k:33 n_rel_and_rec_k:27
# userId:598 n_rel:106 n_rec_k:2 n_rel_and_rec_k:1
# userId:558 n_rel:7 n_rec_k:4 n_rel_and_rec_k:3
# userId:337 n_rel:7 n_rec_k:5 n_rel_and_rec_k:5
# userId:298 n_rel:3 n_rec_k:0 n_rel_and_rec_k:0
# userId:389 n_rel:16 n_rec_k:7 n_rel_and_rec_k:6
# userId:104 n_rel:120 n_rec_k:100 n_rel_and_rec_k:104
# userId:287 n_rel:84 n_rec_k:29 n_rel_and_rec_k:24
# userId:300 n_rel:13 n_rec_k:12 n_rel_and_rec_k:10
# userId:366 n_rel:36 n_rec_k:31 n_rel_and_rec_k:24
# userId:592 n_rel:7 n_rec_k:4 n_rel_and_rec_k:3
# userId:551 n_rel:20 n_rec_k:12 n_rel_and_rec_k:8
# userId:508 n_rel:46 n_rec_k:10 n_rel_and_rec_k:7
# userId:83 n_rel:34 n_rec_k:37 n_rel_and_rec_k:27
# userId:155 n_rel:53 n_rec_k:54 n_rel_and_rec_k:40
# userId:165 n_rel:33 n_rec_k:31 n_rel_and_rec_k:28
# userId:476 n_rel:94 n_rec_k:47 n_rel_and_rec_k:44
# userId:423 n_rel:16 n_rec_k:9 n_rel_and_rec_k:6
# userId:138 n_rel:3 n_rec_k:0 n_rel_and_rec_k:0
# userId:385 n_rel:3 n_rec_k:0 n_rel_and_rec_k:0
# userId:521 n_rel:31 n_rec_k:36 n_rel_and_rec_k:27
# userId:181 n_rel:126 n_rec_k:77 n_rel_and_rec_k:56
# userId:290 n_rel:5 n_rec_k:5 n_rel_and_rec_k:5
# userId:139 n_rel:50 n_rec_k:39 n_rel_and_rec_k:24
# userId:18 n_rel:18 n_rec_k:2 n_rel_and_rec_k:1
# userId:90 n_rel:65 n_rec_k:73 n_rel_and_rec_k:43
# userId:135 n_rel:15 n_rec_k:11 n_rel_and_rec_k:7
# userId:447 n_rel:121 n_rec_k:67 n_rel_and_rec_k:43
# userId:444 n_rel:14 n_rec_k:16 n_rel_and_rec_k:13
# userId:294 n_rel:6 n_rec_k:5 n_rel_and_rec_k:5
# userId:6 n_rel:19 n_rec_k:18 n_rel_and_rec_k:12
# userId:65 n_rel:55 n_rec_k:45 n_rel_and_rec_k:38
# userId:168 n_rel:51 n_rec_k:51 n_rel_and_rec_k:49
# userId:110 n_rel:77 n_rec_k:25 n_rel_and_rec_k:15
# userId:16 n_rel:25 n_rec_k:24 n_rel_and_rec_k:24
# userId:452 n_rel:52 n_rec_k:59 n_rel_and_rec_k:44
# userId:170 n_rel:7 n_rec_k:8 n_rel_and_rec_k:7
# userId:99 n_rel:30 n_rec_k:30 n_rel_and_rec_k:29
# userId:186 n_rel:37 n_rec_k:51 n_rel_and_rec_k:36
# userId:185 n_rel:38 n_rec_k:41 n_rel_and_rec_k:37
# userId:317 n_rel:127 n_rec_k:100 n_rel_and_rec_k:118
# userId:108 n_rel:2 n_rec_k:3 n_rel_and_rec_k:0
# userId:260 n_rel:11 n_rec_k:4 n_rel_and_rec_k:4
# userId:409 n_rel:25 n_rec_k:30 n_rel_and_rec_k:22
# userId:197 n_rel:22 n_rec_k:22 n_rel_and_rec_k:12
# userId:31 n_rel:12 n_rec_k:14 n_rel_and_rec_k:9
# userId:303 n_rel:39 n_rec_k:46 n_rel_and_rec_k:35
# userId:596 n_rel:62 n_rec_k:69 n_rel_and_rec_k:54
# userId:606 n_rel:20 n_rec_k:21 n_rel_and_rec_k:12
# userId:220 n_rel:61 n_rec_k:60 n_rel_and_rec_k:58
# userId:286 n_rel:16 n_rec_k:0 n_rel_and_rec_k:0
# userId:73 n_rel:38 n_rec_k:36 n_rel_and_rec_k:36
# userId:505 n_rel:3 n_rec_k:7 n_rel_and_rec_k:3
# userId:274 n_rel:50 n_rec_k:64 n_rel_and_rec_k:48
# userId:161 n_rel:6 n_rec_k:9 n_rel_and_rec_k:6
# userId:5 n_rel:36 n_rec_k:23 n_rel_and_rec_k:18
# userId:270 n_rel:4 n_rec_k:6 n_rel_and_rec_k:2
# userId:176 n_rel:81 n_rec_k:21 n_rel_and_rec_k:15
# userId:526 n_rel:23 n_rec_k:28 n_rel_and_rec_k:22
# userId:437 n_rel:76 n_rec_k:68 n_rel_and_rec_k:46
# userId:408 n_rel:8 n_rec_k:7 n_rel_and_rec_k:5
# userId:267 n_rel:10 n_rec_k:15 n_rel_and_rec_k:8
# userId:143 n_rel:26 n_rec_k:22 n_rel_and_rec_k:18
# userId:27 n_rel:45 n_rec_k:12 n_rel_and_rec_k:4
# userId:554 n_rel:48 n_rec_k:61 n_rel_and_rec_k:35
# userId:118 n_rel:44 n_rec_k:45 n_rel_and_rec_k:42
# userId:384 n_rel:13 n_rec_k:30 n_rel_and_rec_k:11
# userId:291 n_rel:47 n_rec_k:2 n_rel_and_rec_k:1
# userId:378 n_rel:4 n_rec_k:3 n_rel_and_rec_k:2
# userId:63 n_rel:91 n_rec_k:87 n_rel_and_rec_k:75
# userId:194 n_rel:30 n_rec_k:30 n_rel_and_rec_k:24
# userId:33 n_rel:14 n_rec_k:3 n_rel_and_rec_k:2
# userId:380 n_rel:66 n_rec_k:68 n_rel_and_rec_k:53
# userId:244 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:109 n_rel:7 n_rec_k:6 n_rel_and_rec_k:5
# userId:410 n_rel:14 n_rec_k:7 n_rel_and_rec_k:6
# userId:61 n_rel:54 n_rec_k:49 n_rel_and_rec_k:45
# userId:411 n_rel:13 n_rec_k:14 n_rel_and_rec_k:13
# userId:367 n_rel:17 n_rec_k:1 n_rel_and_rec_k:1
# userId:576 n_rel:20 n_rec_k:17 n_rel_and_rec_k:9
# userId:566 n_rel:18 n_rec_k:0 n_rel_and_rec_k:0
# userId:435 n_rel:6 n_rec_k:6 n_rel_and_rec_k:4
# userId:130 n_rel:10 n_rec_k:7 n_rel_and_rec_k:6
# userId:147 n_rel:6 n_rec_k:6 n_rel_and_rec_k:4
# userId:479 n_rel:86 n_rec_k:37 n_rel_and_rec_k:28
# userId:604 n_rel:33 n_rec_k:5 n_rel_and_rec_k:3
# userId:52 n_rel:7 n_rec_k:7 n_rel_and_rec_k:7
# userId:399 n_rel:13 n_rec_k:13 n_rel_and_rec_k:13
# userId:386 n_rel:113 n_rec_k:48 n_rel_and_rec_k:41
# userId:209 n_rel:22 n_rec_k:27 n_rel_and_rec_k:21
# userId:506 n_rel:0 n_rec_k:4 n_rel_and_rec_k:0
# userId:344 n_rel:10 n_rec_k:8 n_rel_and_rec_k:7
# userId:589 n_rel:84 n_rec_k:31 n_rel_and_rec_k:26
# userId:225 n_rel:52 n_rec_k:41 n_rel_and_rec_k:31
# userId:593 n_rel:37 n_rec_k:37 n_rel_and_rec_k:30
# userId:522 n_rel:16 n_rec_k:17 n_rel_and_rec_k:16
# userId:297 n_rel:31 n_rec_k:0 n_rel_and_rec_k:0
# userId:100 n_rel:7 n_rec_k:8 n_rel_and_rec_k:6
# userId:578 n_rel:15 n_rec_k:12 n_rel_and_rec_k:12
# userId:17 n_rel:89 n_rec_k:78 n_rel_and_rec_k:71
# userId:360 n_rel:12 n_rec_k:0 n_rel_and_rec_k:0
# userId:581 n_rel:10 n_rec_k:10 n_rel_and_rec_k:10
# userId:424 n_rel:37 n_rec_k:15 n_rel_and_rec_k:11
# userId:248 n_rel:149 n_rec_k:100 n_rel_and_rec_k:134
# userId:263 n_rel:9 n_rec_k:12 n_rel_and_rec_k:7
# userId:501 n_rel:7 n_rec_k:4 n_rel_and_rec_k:4
# userId:562 n_rel:27 n_rec_k:20 n_rel_and_rec_k:14
# userId:112 n_rel:16 n_rec_k:11 n_rel_and_rec_k:7
# userId:523 n_rel:17 n_rec_k:7 n_rel_and_rec_k:5
# userId:427 n_rel:15 n_rec_k:9 n_rel_and_rec_k:4
# userId:375 n_rel:23 n_rec_k:22 n_rel_and_rec_k:22
# userId:434 n_rel:6 n_rec_k:6 n_rel_and_rec_k:6
# userId:379 n_rel:132 n_rec_k:100 n_rel_and_rec_k:125
# userId:44 n_rel:46 n_rec_k:62 n_rel_and_rec_k:44
# userId:159 n_rel:33 n_rec_k:0 n_rel_and_rec_k:0
# userId:40 n_rel:20 n_rec_k:6 n_rel_and_rec_k:5
# userId:237 n_rel:4 n_rec_k:0 n_rel_and_rec_k:0
# userId:38 n_rel:14 n_rec_k:18 n_rel_and_rec_k:12
# userId:97 n_rel:14 n_rec_k:7 n_rel_and_rec_k:7
# userId:46 n_rel:9 n_rec_k:3 n_rel_and_rec_k:2
# userId:541 n_rel:17 n_rec_k:18 n_rel_and_rec_k:14
# userId:304 n_rel:123 n_rec_k:100 n_rel_and_rec_k:99
# userId:381 n_rel:37 n_rec_k:29 n_rel_and_rec_k:25
# userId:421 n_rel:15 n_rec_k:8 n_rel_and_rec_k:7
# userId:312 n_rel:35 n_rec_k:15 n_rel_and_rec_k:10
# userId:121 n_rel:62 n_rec_k:61 n_rel_and_rec_k:61
# userId:293 n_rel:20 n_rec_k:0 n_rel_and_rec_k:0
# userId:355 n_rel:49 n_rec_k:55 n_rel_and_rec_k:48
# userId:264 n_rel:9 n_rec_k:6 n_rel_and_rec_k:4
# userId:124 n_rel:58 n_rec_k:40 n_rel_and_rec_k:33
# userId:132 n_rel:5 n_rec_k:1 n_rel_and_rec_k:1
# userId:555 n_rel:7 n_rec_k:3 n_rel_and_rec_k:3
# userId:278 n_rel:23 n_rec_k:27 n_rel_and_rec_k:18
# userId:500 n_rel:6 n_rec_k:1 n_rel_and_rec_k:0
# userId:305 n_rel:11 n_rec_k:1 n_rel_and_rec_k:0
# userId:537 n_rel:7 n_rec_k:8 n_rel_and_rec_k:7
# userId:103 n_rel:37 n_rec_k:36 n_rel_and_rec_k:25
# userId:146 n_rel:4 n_rec_k:0 n_rel_and_rec_k:0
# userId:330 n_rel:25 n_rec_k:18 n_rel_and_rec_k:16
# userId:0 n_rel:52 n_rec_k:58 n_rel_and_rec_k:51
# userId:226 n_rel:19 n_rec_k:19 n_rel_and_rec_k:18
# userId:327 n_rel:28 n_rec_k:23 n_rel_and_rec_k:14
# userId:533 n_rel:76 n_rec_k:66 n_rel_and_rec_k:58
# userId:215 n_rel:24 n_rec_k:23 n_rel_and_rec_k:17
# userId:231 n_rel:84 n_rec_k:93 n_rel_and_rec_k:64
# userId:12 n_rel:5 n_rec_k:4 n_rel_and_rec_k:3
# userId:281 n_rel:36 n_rec_k:36 n_rel_and_rec_k:30
# userId:243 n_rel:9 n_rec_k:10 n_rel_and_rec_k:8
# userId:509 n_rel:9 n_rec_k:1 n_rel_and_rec_k:0
# userId:211 n_rel:35 n_rec_k:26 n_rel_and_rec_k:20
# userId:20 n_rel:50 n_rec_k:20 n_rel_and_rec_k:10
# userId:591 n_rel:9 n_rec_k:11 n_rel_and_rec_k:5
# userId:82 n_rel:18 n_rec_k:2 n_rel_and_rec_k:1
# userId:407 n_rel:31 n_rec_k:31 n_rel_and_rec_k:28
# userId:11 n_rel:5 n_rec_k:2 n_rel_and_rec_k:2
# userId:559 n_rel:71 n_rec_k:57 n_rel_and_rec_k:44
# userId:292 n_rel:0 n_rec_k:0 n_rel_and_rec_k:0
# userId:158 n_rel:12 n_rec_k:2 n_rel_and_rec_k:2
# userId:136 n_rel:32 n_rec_k:34 n_rel_and_rec_k:29
# userId:569 n_rel:26 n_rec_k:10 n_rel_and_rec_k:9
# userId:331 n_rel:33 n_rec_k:36 n_rel_and_rec_k:28
# userId:353 n_rel:42 n_rec_k:31 n_rel_and_rec_k:28
# userId:510 n_rel:9 n_rec_k:10 n_rel_and_rec_k:9
# userId:3 n_rel:26 n_rec_k:11 n_rel_and_rec_k:9
# userId:333 n_rel:16 n_rec_k:2 n_rel_and_rec_k:1
# userId:50 n_rel:46 n_rec_k:31 n_rel_and_rec_k:23
# userId:308 n_rel:16 n_rec_k:10 n_rel_and_rec_k:9
# userId:241 n_rel:2 n_rec_k:4 n_rel_and_rec_k:1
# userId:343 n_rel:7 n_rec_k:8 n_rel_and_rec_k:4
# userId:535 n_rel:2 n_rec_k:2 n_rel_and_rec_k:1
# userId:339 n_rel:4 n_rec_k:4 n_rel_and_rec_k:4
# userId:475 n_rel:7 n_rec_k:1 n_rel_and_rec_k:1
# userId:131 n_rel:29 n_rec_k:1 n_rel_and_rec_k:0
# userId:280 n_rel:3 n_rec_k:2 n_rel_and_rec_k:2
# userId:164 n_rel:5 n_rec_k:5 n_rel_and_rec_k:4
# userId:190 n_rel:9 n_rec_k:9 n_rel_and_rec_k:7
# userId:306 n_rel:56 n_rec_k:2 n_rel_and_rec_k:1
# userId:115 n_rel:14 n_rec_k:5 n_rel_and_rec_k:4
# userId:603 n_rel:11 n_rec_k:15 n_rel_and_rec_k:8
# userId:81 n_rel:27 n_rec_k:11 n_rel_and_rec_k:10
# userId:487 n_rel:13 n_rec_k:24 n_rel_and_rec_k:13
# userId:364 n_rel:13 n_rec_k:3 n_rel_and_rec_k:2
# userId:223 n_rel:8 n_rec_k:10 n_rel_and_rec_k:8
# userId:585 n_rel:30 n_rec_k:32 n_rel_and_rec_k:29
# userId:418 n_rel:28 n_rec_k:12 n_rel_and_rec_k:10
# userId:412 n_rel:14 n_rec_k:15 n_rel_and_rec_k:14
# userId:233 n_rel:24 n_rec_k:20 n_rel_and_rec_k:14
# userId:563 n_rel:26 n_rec_k:27 n_rel_and_rec_k:23
# userId:98 n_rel:6 n_rec_k:12 n_rel_and_rec_k:6
# userId:392 n_rel:22 n_rec_k:11 n_rel_and_rec_k:8
# userId:356 n_rel:62 n_rec_k:61 n_rel_and_rec_k:51
# userId:289 n_rel:46 n_rec_k:48 n_rel_and_rec_k:41
# userId:579 n_rel:52 n_rec_k:32 n_rel_and_rec_k:28
# userId:134 n_rel:34 n_rec_k:32 n_rel_and_rec_k:21
# userId:329 n_rel:39 n_rec_k:21 n_rel_and_rec_k:16
# userId:201 n_rel:54 n_rec_k:48 n_rel_and_rec_k:40
# userId:361 n_rel:19 n_rec_k:21 n_rel_and_rec_k:19
# userId:504 n_rel:5 n_rec_k:5 n_rel_and_rec_k:5
# userId:478 n_rel:20 n_rec_k:34 n_rel_and_rec_k:18
# userId:600 n_rel:21 n_rec_k:20 n_rel_and_rec_k:20
# userId:546 n_rel:3 n_rec_k:4 n_rel_and_rec_k:3
# userId:503 n_rel:12 n_rec_k:11 n_rel_and_rec_k:10
# userId:414 n_rel:21 n_rec_k:17 n_rel_and_rec_k:17
# userId:550 n_rel:22 n_rec_k:24 n_rel_and_rec_k:20
# userId:37 n_rel:4 n_rec_k:0 n_rel_and_rec_k:0
# userId:245 n_rel:33 n_rec_k:37 n_rel_and_rec_k:33
# userId:301 n_rel:8 n_rec_k:8 n_rel_and_rec_k:8
# userId:572 n_rel:48 n_rec_k:57 n_rel_and_rec_k:47
# userId:326 n_rel:15 n_rec_k:14 n_rel_and_rec_k:13
# userId:221 n_rel:36 n_rec_k:7 n_rel_and_rec_k:6
# userId:247 n_rel:11 n_rec_k:7 n_rel_and_rec_k:6
# userId:442 n_rel:12 n_rec_k:12 n_rel_and_rec_k:11
# userId:311 n_rel:32 n_rec_k:27 n_rel_and_rec_k:24
# userId:436 n_rel:14 n_rec_k:21 n_rel_and_rec_k:14
# userId:351 n_rel:37 n_rec_k:46 n_rel_and_rec_k:36
# userId:19 n_rel:38 n_rec_k:31 n_rel_and_rec_k:27
# userId:439 n_rel:5 n_rec_k:4 n_rel_and_rec_k:2
# userId:376 n_rel:20 n_rec_k:21 n_rel_and_rec_k:17
# userId:218 n_rel:50 n_rec_k:6 n_rel_and_rec_k:4
# userId:163 n_rel:4 n_rec_k:5 n_rel_and_rec_k:4
# userId:445 n_rel:2 n_rec_k:4 n_rel_and_rec_k:1
# userId:341 n_rel:3 n_rec_k:1 n_rel_and_rec_k:0
# userId:525 n_rel:7 n_rec_k:6 n_rel_and_rec_k:6
# userId:400 n_rel:12 n_rec_k:2 n_rel_and_rec_k:2
# userId:531 n_rel:9 n_rec_k:8 n_rel_and_rec_k:7
# userId:534 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:229 n_rel:11 n_rec_k:0 n_rel_and_rec_k:0
# userId:516 n_rel:20 n_rec_k:0 n_rel_and_rec_k:0
# userId:123 n_rel:7 n_rec_k:7 n_rel_and_rec_k:6
# userId:481 n_rel:18 n_rec_k:13 n_rel_and_rec_k:11
# userId:178 n_rel:10 n_rec_k:10 n_rel_and_rec_k:8
# userId:417 n_rel:12 n_rec_k:13 n_rel_and_rec_k:11
# userId:41 n_rel:56 n_rec_k:58 n_rel_and_rec_k:44
# userId:438 n_rel:6 n_rec_k:6 n_rel_and_rec_k:6
# userId:7 n_rel:6 n_rec_k:7 n_rel_and_rec_k:5
# userId:180 n_rel:5 n_rec_k:0 n_rel_and_rec_k:0
# userId:219 n_rel:30 n_rec_k:22 n_rel_and_rec_k:18
# userId:519 n_rel:34 n_rec_k:40 n_rel_and_rec_k:33
# userId:584 n_rel:11 n_rec_k:11 n_rel_and_rec_k:11
# userId:94 n_rel:32 n_rec_k:29 n_rel_and_rec_k:28
# userId:58 n_rel:17 n_rec_k:21 n_rel_and_rec_k:17
# userId:28 n_rel:18 n_rec_k:18 n_rel_and_rec_k:17
# userId:571 n_rel:30 n_rec_k:36 n_rel_and_rec_k:29
# userId:494 n_rel:45 n_rec_k:43 n_rel_and_rec_k:37
# userId:502 n_rel:11 n_rec_k:9 n_rel_and_rec_k:6
# userId:85 n_rel:13 n_rec_k:10 n_rel_and_rec_k:10
# userId:22 n_rel:19 n_rec_k:17 n_rel_and_rec_k:13
# userId:49 n_rel:22 n_rec_k:4 n_rel_and_rec_k:4
# userId:529 n_rel:4 n_rec_k:3 n_rel_and_rec_k:2
# userId:32 n_rel:14 n_rec_k:26 n_rel_and_rec_k:14
# userId:39 n_rel:13 n_rec_k:19 n_rel_and_rec_k:11
# userId:257 n_rel:4 n_rec_k:5 n_rel_and_rec_k:4
# userId:173 n_rel:7 n_rec_k:7 n_rel_and_rec_k:4
# userId:307 n_rel:14 n_rec_k:0 n_rel_and_rec_k:0
# userId:222 n_rel:7 n_rec_k:2 n_rel_and_rec_k:1
# userId:238 n_rel:55 n_rec_k:46 n_rel_and_rec_k:43
# userId:397 n_rel:10 n_rec_k:11 n_rel_and_rec_k:9
# userId:466 n_rel:1 n_rec_k:3 n_rel_and_rec_k:0
# userId:114 n_rel:16 n_rec_k:8 n_rel_and_rec_k:5
# userId:547 n_rel:1 n_rec_k:2 n_rel_and_rec_k:1
# userId:369 n_rel:14 n_rec_k:10 n_rel_and_rec_k:8
# userId:469 n_rel:10 n_rec_k:16 n_rel_and_rec_k:9
# userId:426 n_rel:9 n_rec_k:0 n_rel_and_rec_k:0
# userId:560 n_rel:56 n_rec_k:36 n_rel_and_rec_k:28
# userId:75 n_rel:14 n_rec_k:0 n_rel_and_rec_k:0
# userId:234 n_rel:7 n_rec_k:1 n_rel_and_rec_k:1
# userId:70 n_rel:2 n_rec_k:3 n_rel_and_rec_k:1
# userId:561 n_rel:43 n_rec_k:49 n_rel_and_rec_k:43
# userId:490 n_rel:12 n_rec_k:14 n_rel_and_rec_k:12
# userId:480 n_rel:1 n_rec_k:1 n_rel_and_rec_k:1
# userId:128 n_rel:25 n_rec_k:14 n_rel_and_rec_k:13
# userId:154 n_rel:4 n_rec_k:2 n_rel_and_rec_k:2
# userId:255 n_rel:37 n_rec_k:33 n_rel_and_rec_k:31
# userId:92 n_rel:17 n_rec_k:16 n_rel_and_rec_k:16
# userId:122 n_rel:10 n_rec_k:10 n_rel_and_rec_k:10
# userId:172 n_rel:2 n_rec_k:2 n_rel_and_rec_k:0
# userId:313 n_rel:6 n_rec_k:1 n_rel_and_rec_k:1
# userId:513 n_rel:47 n_rec_k:19 n_rel_and_rec_k:17
# userId:390 n_rel:49 n_rec_k:67 n_rel_and_rec_k:45
# userId:316 n_rel:26 n_rec_k:39 n_rel_and_rec_k:26
# userId:402 n_rel:3 n_rec_k:0 n_rel_and_rec_k:0
# userId:192 n_rel:4 n_rec_k:4 n_rel_and_rec_k:3
# userId:210 n_rel:14 n_rec_k:15 n_rel_and_rec_k:11
# userId:288 n_rel:3 n_rec_k:1 n_rel_and_rec_k:1
# userId:48 n_rel:4 n_rec_k:4 n_rel_and_rec_k:4
# userId:486 n_rel:4 n_rec_k:2 n_rel_and_rec_k:1
# userId:26 n_rel:13 n_rec_k:4 n_rel_and_rec_k:3
# userId:586 n_rel:20 n_rec_k:25 n_rel_and_rec_k:20
# userId:246 n_rel:21 n_rec_k:27 n_rel_and_rec_k:20
# userId:404 n_rel:29 n_rec_k:26 n_rel_and_rec_k:25
# userId:296 n_rel:4 n_rec_k:1 n_rel_and_rec_k:0
# userId:347 n_rel:14 n_rec_k:14 n_rel_and_rec_k:14
# userId:149 n_rel:0 n_rec_k:0 n_rel_and_rec_k:0
# userId:472 n_rel:2 n_rec_k:1 n_rel_and_rec_k:1
# userId:456 n_rel:2 n_rec_k:8 n_rel_and_rec_k:2
# userId:552 n_rel:14 n_rec_k:15 n_rel_and_rec_k:14
# userId:232 n_rel:15 n_rec_k:3 n_rel_and_rec_k:3
# userId:51 n_rel:19 n_rec_k:20 n_rel_and_rec_k:19
# userId:230 n_rel:5 n_rec_k:6 n_rel_and_rec_k:5
# userId:491 n_rel:12 n_rec_k:19 n_rel_and_rec_k:10
# userId:91 n_rel:6 n_rec_k:2 n_rel_and_rec_k:2
# userId:140 n_rel:20 n_rec_k:19 n_rel_and_rec_k:16
# userId:318 n_rel:10 n_rec_k:10 n_rel_and_rec_k:10
# userId:182 n_rel:6 n_rec_k:10 n_rel_and_rec_k:6
# userId:253 n_rel:28 n_rec_k:26 n_rel_and_rec_k:23
# userId:542 n_rel:17 n_rec_k:16 n_rel_and_rec_k:15
# userId:496 n_rel:4 n_rec_k:5 n_rel_and_rec_k:3
# userId:582 n_rel:6 n_rec_k:1 n_rel_and_rec_k:0
# userId:13 n_rel:4 n_rec_k:3 n_rel_and_rec_k:2
# userId:374 n_rel:5 n_rec_k:3 n_rel_and_rec_k:3
# userId:45 n_rel:4 n_rec_k:3 n_rel_and_rec_k:3
# userId:352 n_rel:7 n_rec_k:7 n_rel_and_rec_k:5
# userId:346 n_rel:4 n_rec_k:2 n_rel_and_rec_k:0
# userId:458 n_rel:4 n_rec_k:4 n_rel_and_rec_k:4
# userId:518 n_rel:4 n_rec_k:3 n_rel_and_rec_k:3
# userId:166 n_rel:27 n_rec_k:27 n_rel_and_rec_k:21
# userId:451 n_rel:52 n_rec_k:53 n_rel_and_rec_k:51
# userId:15 n_rel:21 n_rec_k:21 n_rel_and_rec_k:19
# userId:322 n_rel:11 n_rec_k:4 n_rel_and_rec_k:4
# userId:464 n_rel:24 n_rec_k:23 n_rel_and_rec_k:21
# userId:175 n_rel:7 n_rec_k:4 n_rel_and_rec_k:4
# userId:309 n_rel:8 n_rec_k:0 n_rel_and_rec_k:0
# userId:271 n_rel:8 n_rec_k:8 n_rel_and_rec_k:8
# userId:21 n_rel:6 n_rec_k:0 n_rel_and_rec_k:0
# userId:252 n_rel:9 n_rec_k:10 n_rel_and_rec_k:9
# userId:557 n_rel:8 n_rec_k:5 n_rel_and_rec_k:4
# userId:431 n_rel:32 n_rec_k:30 n_rel_and_rec_k:24
# userId:102 n_rel:50 n_rec_k:39 n_rel_and_rec_k:35
# userId:183 n_rel:25 n_rec_k:16 n_rel_and_rec_k:15
# userId:320 n_rel:3 n_rec_k:3 n_rel_and_rec_k:1
# userId:55 n_rel:9 n_rec_k:8 n_rel_and_rec_k:6
# userId:60 n_rel:8 n_rec_k:8 n_rel_and_rec_k:8
# userId:265 n_rel:21 n_rec_k:20 n_rel_and_rec_k:16
# userId:324 n_rel:32 n_rec_k:26 n_rel_and_rec_k:20
# userId:47 n_rel:6 n_rec_k:8 n_rel_and_rec_k:6
# userId:532 n_rel:11 n_rec_k:13 n_rel_and_rec_k:11
# userId:492 n_rel:8 n_rec_k:6 n_rel_and_rec_k:4
# userId:107 n_rel:11 n_rec_k:11 n_rel_and_rec_k:9
# userId:93 n_rel:1 n_rec_k:1 n_rel_and_rec_k:0
# userId:536 n_rel:10 n_rec_k:11 n_rel_and_rec_k:10
# userId:468 n_rel:53 n_rec_k:82 n_rel_and_rec_k:49
# userId:395 n_rel:7 n_rec_k:4 n_rel_and_rec_k:4
# userId:383 n_rel:6 n_rec_k:1 n_rel_and_rec_k:1
# userId:57 n_rel:7 n_rec_k:8 n_rel_and_rec_k:4
# userId:429 n_rel:11 n_rec_k:12 n_rel_and_rec_k:10
# userId:14 n_rel:16 n_rec_k:10 n_rel_and_rec_k:8
# userId:315 n_rel:4 n_rec_k:0 n_rel_and_rec_k:0
# userId:262 n_rel:32 n_rec_k:25 n_rel_and_rec_k:19
# userId:2 n_rel:4 n_rec_k:0 n_rel_and_rec_k:0
# userId:499 n_rel:6 n_rec_k:0 n_rel_and_rec_k:0
# userId:463 n_rel:16 n_rec_k:18 n_rel_and_rec_k:11
# userId:471 n_rel:5 n_rec_k:6 n_rel_and_rec_k:5
# userId:321 n_rel:11 n_rec_k:7 n_rel_and_rec_k:5
# userId:283 n_rel:8 n_rec_k:11 n_rel_and_rec_k:6
# userId:465 n_rel:20 n_rec_k:14 n_rel_and_rec_k:13
# userId:145 n_rel:2 n_rec_k:3 n_rel_and_rec_k:2
# userId:325 n_rel:29 n_rec_k:33 n_rel_and_rec_k:27
# userId:394 n_rel:4 n_rec_k:0 n_rel_and_rec_k:0
# userId:450 n_rel:7 n_rec_k:6 n_rel_and_rec_k:5
# userId:198 n_rel:37 n_rec_k:36 n_rel_and_rec_k:28
# userId:567 n_rel:3 n_rec_k:5 n_rel_and_rec_k:3
# userId:126 n_rel:1 n_rec_k:3 n_rel_and_rec_k:1
# userId:77 n_rel:7 n_rec_k:11 n_rel_and_rec_k:6
# userId:30 n_rel:3 n_rec_k:1 n_rel_and_rec_k:1
# userId:583 n_rel:10 n_rec_k:14 n_rel_and_rec_k:10
# userId:142 n_rel:7 n_rec_k:8 n_rel_and_rec_k:3
# userId:212 n_rel:7 n_rec_k:6 n_rel_and_rec_k:4
# userId:43 n_rel:9 n_rec_k:3 n_rel_and_rec_k:3
# userId:507 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:141 n_rel:3 n_rec_k:2 n_rel_and_rec_k:2
# userId:477 n_rel:3 n_rec_k:0 n_rel_and_rec_k:0
# userId:345 n_rel:28 n_rec_k:25 n_rel_and_rec_k:21
# userId:425 n_rel:12 n_rec_k:4 n_rel_and_rec_k:4
# userId:588 n_rel:5 n_rec_k:9 n_rel_and_rec_k:5
# userId:189 n_rel:12 n_rec_k:7 n_rel_and_rec_k:6
# userId:512 n_rel:6 n_rec_k:5 n_rel_and_rec_k:4
# userId:419 n_rel:35 n_rec_k:25 n_rel_and_rec_k:22
# userId:23 n_rel:13 n_rec_k:13 n_rel_and_rec_k:10
# userId:196 n_rel:2 n_rec_k:4 n_rel_and_rec_k:2
# userId:96 n_rel:7 n_rec_k:5 n_rel_and_rec_k:4
# userId:358 n_rel:8 n_rec_k:1 n_rel_and_rec_k:1
# userId:191 n_rel:2 n_rec_k:1 n_rel_and_rec_k:1
# userId:372 n_rel:5 n_rec_k:1 n_rel_and_rec_k:1
# userId:167 n_rel:19 n_rec_k:20 n_rel_and_rec_k:19
# userId:259 n_rel:21 n_rec_k:12 n_rel_and_rec_k:9
# userId:236 n_rel:6 n_rec_k:3 n_rel_and_rec_k:3
# userId:174 n_rel:5 n_rec_k:2 n_rel_and_rec_k:2
# userId:340 n_rel:6 n_rec_k:3 n_rel_and_rec_k:3
# userId:302 n_rel:4 n_rec_k:6 n_rel_and_rec_k:4
# userId:515 n_rel:2 n_rec_k:1 n_rel_and_rec_k:1
# userId:54 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:125 n_rel:5 n_rec_k:5 n_rel_and_rec_k:3
# userId:120 n_rel:9 n_rec_k:0 n_rel_and_rec_k:0
# userId:357 n_rel:5 n_rec_k:4 n_rel_and_rec_k:3
# userId:203 n_rel:17 n_rec_k:17 n_rel_and_rec_k:15
# userId:363 n_rel:4 n_rec_k:1 n_rel_and_rec_k:1
# userId:111 n_rel:10 n_rec_k:3 n_rel_and_rec_k:3
# userId:403 n_rel:2 n_rec_k:1 n_rel_and_rec_k:1
# userId:116 n_rel:11 n_rec_k:12 n_rel_and_rec_k:7
# userId:213 n_rel:0 n_rec_k:0 n_rel_and_rec_k:0
# userId:462 n_rel:5 n_rec_k:2 n_rel_and_rec_k:2
# userId:101 n_rel:3 n_rec_k:2 n_rel_and_rec_k:1
# userId:601 n_rel:13 n_rec_k:0 n_rel_and_rec_k:0
# userId:285 n_rel:16 n_rec_k:14 n_rel_and_rec_k:11
# userId:553 n_rel:15 n_rec_k:22 n_rel_and_rec_k:13
# userId:68 n_rel:12 n_rec_k:15 n_rel_and_rec_k:12
# userId:86 n_rel:4 n_rec_k:5 n_rel_and_rec_k:4
# userId:538 n_rel:3 n_rec_k:2 n_rel_and_rec_k:2
# userId:350 n_rel:17 n_rec_k:20 n_rel_and_rec_k:15
# userId:590 n_rel:4 n_rec_k:3 n_rel_and_rec_k:1
# userId:597 n_rel:3 n_rec_k:1 n_rel_and_rec_k:0
# userId:336 n_rel:12 n_rec_k:13 n_rel_and_rec_k:9
# userId:310 n_rel:4 n_rec_k:0 n_rel_and_rec_k:0
# userId:117 n_rel:0 n_rec_k:1 n_rel_and_rec_k:0
# userId:575 n_rel:3 n_rec_k:0 n_rel_and_rec_k:0
# userId:87 n_rel:8 n_rec_k:9 n_rel_and_rec_k:8
# userId:459 n_rel:14 n_rec_k:12 n_rel_and_rec_k:12
# userId:53 n_rel:0 n_rec_k:0 n_rel_and_rec_k:0
# userId:187 n_rel:7 n_rec_k:7 n_rel_and_rec_k:7
# userId:249 n_rel:2 n_rec_k:3 n_rel_and_rec_k:2
# userId:489 n_rel:9 n_rec_k:2 n_rel_and_rec_k:2
# userId:188 n_rel:8 n_rec_k:8 n_rel_and_rec_k:8
# userId:342 n_rel:13 n_rec_k:10 n_rel_and_rec_k:10
# userId:74 n_rel:6 n_rec_k:3 n_rel_and_rec_k:3
# userId:568 n_rel:4 n_rec_k:3 n_rel_and_rec_k:2
# userId:177 n_rel:9 n_rec_k:12 n_rel_and_rec_k:9
# userId:443 n_rel:3 n_rec_k:2 n_rel_and_rec_k:2
# userId:359 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:269 n_rel:5 n_rec_k:2 n_rel_and_rec_k:1
# userId:76 n_rel:3 n_rec_k:7 n_rel_and_rec_k:2
# userId:282 n_rel:7 n_rec_k:3 n_rel_and_rec_k:3
# userId:574 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:113 n_rel:5 n_rec_k:6 n_rel_and_rec_k:4
# userId:556 n_rel:5 n_rec_k:2 n_rel_and_rec_k:2
# userId:485 n_rel:5 n_rec_k:10 n_rel_and_rec_k:5
# userId:454 n_rel:3 n_rec_k:4 n_rel_and_rec_k:2
# userId:64 n_rel:6 n_rec_k:6 n_rel_and_rec_k:6
# userId:184 n_rel:6 n_rec_k:4 n_rel_and_rec_k:4
# userId:42 n_rel:10 n_rec_k:12 n_rel_and_rec_k:10
# userId:79 n_rel:28 n_rec_k:28 n_rel_and_rec_k:28
# userId:129 n_rel:5 n_rec_k:4 n_rel_and_rec_k:4
# userId:335 n_rel:13 n_rec_k:14 n_rel_and_rec_k:13
# userId:251 n_rel:7 n_rec_k:5 n_rel_and_rec_k:5
# userId:295 n_rel:3 n_rec_k:4 n_rel_and_rec_k:3
# userId:25 n_rel:1 n_rec_k:3 n_rel_and_rec_k:1
# userId:105 n_rel:9 n_rec_k:10 n_rel_and_rec_k:9
# userId:539 n_rel:4 n_rec_k:3 n_rel_and_rec_k:3
# userId:279 n_rel:26 n_rec_k:12 n_rel_and_rec_k:11
# userId:35 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:453 n_rel:7 n_rec_k:10 n_rel_and_rec_k:7
# userId:4 n_rel:4 n_rec_k:4 n_rel_and_rec_k:2
# userId:446 n_rel:8 n_rec_k:16 n_rel_and_rec_k:8
# userId:169 n_rel:3 n_rec_k:6 n_rel_and_rec_k:3
# userId:528 n_rel:0 n_rec_k:1 n_rel_and_rec_k:0
# userId:527 n_rel:9 n_rec_k:3 n_rel_and_rec_k:3
# userId:422 n_rel:3 n_rec_k:2 n_rel_and_rec_k:2
# userId:511 n_rel:3 n_rec_k:3 n_rel_and_rec_k:3
# userId:457 n_rel:11 n_rec_k:11 n_rel_and_rec_k:10
# userId:228 n_rel:9 n_rec_k:3 n_rel_and_rec_k:3
# userId:261 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:370 n_rel:10 n_rec_k:10 n_rel_and_rec_k:10
# userId:432 n_rel:2 n_rec_k:2 n_rel_and_rec_k:2
# userId:573 n_rel:3 n_rec_k:4 n_rel_and_rec_k:3
# userId:398 n_rel:7 n_rec_k:8 n_rel_and_rec_k:6
# userId:24 n_rel:9 n_rec_k:9 n_rel_and_rec_k:9
# userId:144 n_rel:1 n_rec_k:1 n_rel_and_rec_k:1
# userId:179 n_rel:3 n_rec_k:2 n_rel_and_rec_k:2
# userId:150 n_rel:11 n_rec_k:3 n_rel_and_rec_k:2
# userId:84 n_rel:4 n_rec_k:3 n_rel_and_rec_k:3
# userId:275 n_rel:2 n_rec_k:4 n_rel_and_rec_k:2
# userId:239 n_rel:11 n_rec_k:17 n_rel_and_rec_k:9
# userId:214 n_rel:9 n_rec_k:10 n_rel_and_rec_k:6
# userId:10 n_rel:7 n_rec_k:7 n_rel_and_rec_k:5
# userId:387 n_rel:4 n_rec_k:6 n_rel_and_rec_k:4
# userId:415 n_rel:6 n_rec_k:0 n_rel_and_rec_k:0
# userId:266 n_rel:13 n_rec_k:13 n_rel_and_rec_k:13
# userId:69 n_rel:12 n_rec_k:12 n_rel_and_rec_k:11
# userId:470 n_rel:4 n_rec_k:3 n_rel_and_rec_k:2
# userId:235 n_rel:1 n_rec_k:1 n_rel_and_rec_k:1
# userId:467 n_rel:3 n_rec_k:0 n_rel_and_rec_k:0
# userId:202 n_rel:8 n_rec_k:10 n_rel_and_rec_k:8
# userId:334 n_rel:3 n_rec_k:3 n_rel_and_rec_k:3
# userId:200 n_rel:22 n_rec_k:21 n_rel_and_rec_k:19
# userId:89 n_rel:10 n_rec_k:8 n_rel_and_rec_k:8
# userId:493 n_rel:3 n_rec_k:4 n_rel_and_rec_k:3
# userId:206 n_rel:3 n_rec_k:1 n_rel_and_rec_k:1
# userId:106 n_rel:5 n_rec_k:1 n_rel_and_rec_k:1
# userId:59 n_rel:2 n_rec_k:2 n_rel_and_rec_k:2
# userId:36 n_rel:4 n_rec_k:3 n_rel_and_rec_k:3
# userId:240 n_rel:14 n_rec_k:10 n_rel_and_rec_k:9
# userId:242 n_rel:4 n_rec_k:9 n_rel_and_rec_k:4
# userId:498 n_rel:6 n_rec_k:4 n_rel_and_rec_k:4
# userId:328 n_rel:2 n_rec_k:3 n_rel_and_rec_k:1
# userId:354 n_rel:6 n_rec_k:7 n_rel_and_rec_k:6
# userId:272 n_rel:11 n_rec_k:10 n_rel_and_rec_k:9
# userId:382 n_rel:7 n_rec_k:7 n_rel_and_rec_k:6
# userId:448 n_rel:5 n_rec_k:0 n_rel_and_rec_k:0
# userId:171 n_rel:4 n_rec_k:3 n_rel_and_rec_k:2
# userId:420 n_rel:9 n_rec_k:10 n_rel_and_rec_k:9
# userId:193 n_rel:4 n_rec_k:4 n_rel_and_rec_k:3
# userId:441 n_rel:0 n_rec_k:0 n_rel_and_rec_k:0
# userId:258 n_rel:1 n_rec_k:2 n_rel_and_rec_k:1
# userId:127 n_rel:4 n_rec_k:7 n_rel_and_rec_k:4
# userId:71 n_rel:8 n_rec_k:6 n_rel_and_rec_k:6
# userId:401 n_rel:7 n_rec_k:5 n_rel_and_rec_k:3
# userId:396 n_rel:3 n_rec_k:4 n_rel_and_rec_k:3
# userId:428 n_rel:8 n_rec_k:10 n_rel_and_rec_k:8
# userId:9 n_rel:7 n_rec_k:10 n_rel_and_rec_k:4
# userId:314 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:227 n_rel:6 n_rec_k:4 n_rel_and_rec_k:3
# userId:80 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:549 n_rel:4 n_rec_k:2 n_rel_and_rec_k:2
# userId:276 n_rel:2 n_rec_k:3 n_rel_and_rec_k:1
# userId:95 n_rel:7 n_rec_k:10 n_rel_and_rec_k:7
# userId:208 n_rel:5 n_rec_k:5 n_rel_and_rec_k:5
# userId:565 n_rel:8 n_rec_k:9 n_rel_and_rec_k:6
# userId:608 n_rel:2 n_rec_k:2 n_rel_and_rec_k:1
# userId:250 n_rel:2 n_rec_k:2 n_rel_and_rec_k:2
# userId:497 n_rel:3 n_rec_k:6 n_rel_and_rec_k:3
# userId:365 n_rel:2 n_rec_k:3 n_rel_and_rec_k:2
# userId:349 n_rel:3 n_rec_k:3 n_rel_and_rec_k:3
# userId:34 n_rel:1 n_rec_k:1 n_rel_and_rec_k:0
# userId:587 n_rel:3 n_rec_k:5 n_rel_and_rec_k:3
# userId:157 n_rel:3 n_rec_k:4 n_rel_and_rec_k:2
# userId:580 n_rel:6 n_rec_k:6 n_rel_and_rec_k:6
# userId:332 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:8 n_rel:7 n_rec_k:1 n_rel_and_rec_k:1
# userId:391 n_rel:1 n_rec_k:3 n_rel_and_rec_k:1
# userId:323 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:268 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:319 n_rel:2 n_rec_k:2 n_rel_and_rec_k:2
# userId:78 n_rel:9 n_rec_k:13 n_rel_and_rec_k:9
# userId:416 n_rel:13 n_rec_k:14 n_rel_and_rec_k:13
# userId:362 n_rel:2 n_rec_k:1 n_rel_and_rec_k:1
# userId:405 n_rel:1 n_rec_k:1 n_rel_and_rec_k:0
# userId:195 n_rel:6 n_rec_k:5 n_rel_and_rec_k:5
# userId:148 n_rel:7 n_rec_k:0 n_rel_and_rec_k:0
# userId:205 n_rel:2 n_rec_k:3 n_rel_and_rec_k:2
# userId:137 n_rel:4 n_rec_k:0 n_rel_and_rec_k:0
# userId:217 n_rel:1 n_rec_k:3 n_rel_and_rec_k:0
# userId:224 n_rel:7 n_rec_k:10 n_rel_and_rec_k:6
# userId:66 n_rel:6 n_rec_k:6 n_rel_and_rec_k:5
# userId:460 n_rel:5 n_rec_k:0 n_rel_and_rec_k:0
# userId:254 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:156 n_rel:0 n_rec_k:0 n_rel_and_rec_k:0
# userId:440 n_rel:8 n_rec_k:8 n_rel_and_rec_k:8
# userId:162 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:449 n_rel:6 n_rec_k:5 n_rel_and_rec_k:5
# userId:517 n_rel:0 n_rec_k:1 n_rel_and_rec_k:0
# userId:29 n_rel:6 n_rec_k:7 n_rel_and_rec_k:6
# userId:133 n_rel:2 n_rec_k:3 n_rel_and_rec_k:2
# userId:207 n_rel:1 n_rec_k:0 n_rel_and_rec_k:0
# userId:388 n_rel:3 n_rec_k:3 n_rel_and_rec_k:2
# userId:393 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:160 n_rel:7 n_rec_k:10 n_rel_and_rec_k:7
# userId:406 n_rel:4 n_rec_k:6 n_rel_and_rec_k:4
# userId:455 n_rel:3 n_rec_k:4 n_rel_and_rec_k:1
# userId:495 n_rel:3 n_rec_k:1 n_rel_and_rec_k:1
# userId:153 n_rel:6 n_rec_k:6 n_rel_and_rec_k:6
# userId:119 n_rel:2 n_rec_k:3 n_rel_and_rec_k:1
# userId:484 n_rel:3 n_rec_k:5 n_rel_and_rec_k:2
# userId:277 n_rel:2 n_rec_k:3 n_rel_and_rec_k:2
# userId:299 n_rel:5 n_rec_k:5 n_rel_and_rec_k:5
# userId:348 n_rel:1 n_rec_k:1 n_rel_and_rec_k:1
# userId:514 n_rel:4 n_rec_k:4 n_rel_and_rec_k:4
# userId:544 n_rel:4 n_rec_k:1 n_rel_and_rec_k:0
# userId:204 n_rel:3 n_rec_k:4 n_rel_and_rec_k:3
# userId:530 n_rel:1 n_rec_k:1 n_rel_and_rec_k:1
# userId:594 n_rel:3 n_rec_k:1 n_rel_and_rec_k:1
# userId:543 n_rel:4 n_rec_k:5 n_rel_and_rec_k:4
# userId:520 n_rel:4 n_rec_k:5 n_rel_and_rec_k:3
# userId:256 n_rel:2 n_rec_k:1 n_rel_and_rec_k:0
# userId:1 n_rel:2 n_rec_k:4 n_rel_and_rec_k:2
# userId:548 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:577 n_rel:6 n_rec_k:5 n_rel_and_rec_k:5
# userId:430 n_rel:2 n_rec_k:0 n_rel_and_rec_k:0
# userId:373 n_rel:2 n_rec_k:1 n_rel_and_rec_k:1
# userId:564 n_rel:1 n_rec_k:1 n_rel_and_rec_k:1

# %%
print(f"precision @{k}:{sum(prec for prec in precisions.values())/len(precisions)}")

print(f"recall @{k}:{sum(rec for rec in recalls.values())/len(recalls)}")
# Out:
# precision @100:0.6892594242119588
# recall @100:0.60359463626069

# %%
def recommend_movies(user_id, model, all_movie_ids, users_label, movies_label, top_k=10):

    model.eval()

    if user_id not in users_label.classes_:
        print(f"User ID {user_id} not found in dataset.")
        return []
    
    user_idx = users_label.transform([user_id])[0]
    movie_indices = movies_label.transform(all_movie_ids)

  
    user_tensor = torch.tensor([user_idx] * len(movie_indices), dtype=torch.long)
    movie_tensor = torch.tensor(movie_indices, dtype=torch.long)
   
        
    with torch.no_grad():
        predicted_ratings = model(user_tensor, movie_tensor).squeeze()

    probabilities = torch.nn.functional.softmax(predicted_ratings, dim=0)
    print(probabilities)
    top_indices = torch.multinomial(probabilities, num_samples=top_k)
    print(top_indices)
    sorted_movies = [movies_label.inverse_transform([i])[0] for i in top_indices]
    print(sorted_movies)
    
    return sorted_movies

# %%
all_movie_ids = ratings["movieId"].unique().tolist()
recommended_movies_idx = recommend_movies(
    user_id=30, 
    model=model,
    all_movie_ids=all_movie_ids,
    users_label=users_label,
    movies_label=movies_label,
    top_k=5
)

rec_movies=movies[movies["movieId"].isin(recommended_movies_idx)]
rec_movies
# Out:
# tensor([1.5246e-04, 8.2561e-05, 2.1126e-04,  ..., 1.0987e-04, 6.3598e-05,
#         8.1398e-05])
# tensor([ 432, 5483, 3581, 9191, 2453])
# [432, 5483, 3581, 9191, 2453]
#       Unnamed: 0  movieId                                              title  \
# 428          428      432  City Slickers II: The Legend of Curly's Gold (...
# 2368        2368     2453                      Boy Who Could Fly, The (1986)
# 3490        3490     3581                               Human Traffic (1999)
# 5386        5386     5483               Kid Stays in the Picture, The (2002)
#
#                         genres  imdbId   tmdbId
# 428   Adventure|Comedy|Western  109439  11310.0
# 2368             Drama|Fantasy   90768  24086.0
# 3490                    Comedy  188674  11129.0
# 5386               Documentary  303353  29047.0

# %%
all_movie_ids = ratings["movieId"].unique().tolist()

recommended_movies_idx = recommend_movies(
    user_id=89, 
    model=model,
    all_movie_ids=all_movie_ids,
    users_label=users_label,
    movies_label=movies_label,
    top_k=5
)

rec_movies=movies[movies["movieId"].isin(recommended_movies_idx)]
rec_movies
# Out:
# tensor([1.8950e-04, 6.1560e-05, 1.7699e-04,  ..., 5.3108e-05, 9.9334e-05,
#         6.9759e-05])
# tensor([4475, 3957, 1293, 6321, 5652])
# [4475, 3957, 1293, 6321, 5652]
#       movieId                                  title         genres  imdbId  \
# 1265     1293                          Gandhi (1982)          Drama   83987
# 3863     3957                      Billy Jack (1971)   Action|Drama   66832
# 4380     4475  Beast of War, The (Beast, The) (1988)      Drama|War   94716
# 5553     5652              Claire of the Moon (1992)  Drama|Romance  103977
# 6222     6321                          Stella (1990)          Drama  100691
#
#        tmdbId
# 1265    783.0
# 3863  21142.0
# 4380  15267.0
# 5553  53049.0
# 6222  47329.0

# %%
movies.to_csv("dataset/movies.csv")

# %%
torch.save(model.state_dict(),"recommendation_model.pth")

# %%
import pickle

with open("label_encoders.pkl", "wb") as f:
    pickle.dump({"users_label": users_label, "movies_label": movies_label}, f)

# %%
ratings.to_csv("dataset/ratings.csv")

# %%
import pandas as pd 
movies=pd.read_csv("dataset/movies.csv")

# %%
movies[movies["movieId"].isin([2,5,48])].to_dict(orient="records")
# Out:
# [{'Unnamed: 0': 1,
#   'movieId': 2,
#   'title': 'Jumanji (1995)',
#   'genres': 'Adventure|Children|Fantasy',
#   'imdbId': 113497,
#   'tmdbId': 8844.0},
#  {'Unnamed: 0': 4,
#   'movieId': 5,
#   'title': 'Father of the Bride Part II (1995)',
#   'genres': 'Comedy',
#   'imdbId': 113041,
#   'tmdbId': 11862.0},
#  {'Unnamed: 0': 47,
#   'movieId': 48,
#   'title': 'Pocahontas (1995)',
#   'genres': 'Animation|Children|Drama|Musical|Romance',
#   'imdbId': 114148,
#   'tmdbId': 10530.0}]
